# %% [markdown]
# ## Predicting the sales prices of used buldozers

# %%
# to handle datasets
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
% matplotlib inline

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler

# for tree binarisation
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score


# to build the models
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb

# to evaluate the models
from sklearn.metrics import mean_squared_error

pd.pandas.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset 1

# %%
# load dataset 1
data1 = pd.read_csv('Train.csv')

# %%
data1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate fiModelDesc  \
# 0                      68.0       Low  11/16/2006 0:00        521D
# 1                    4640.0       Low   3/26/2004 0:00      950FII
# 2                    2838.0      High   2/26/2004 0:00         226
# 3                    3486.0      High   5/19/2011 0:00    PC120-6E
# 4                     722.0    Medium   7/23/2009 0:00        S175
#
#   fiBaseModel fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0         521               D           NaN               NaN         NaN
# 1         950               F            II               NaN      Medium
# 2         226             NaN           NaN               NaN         NaN
# 3       PC120             NaN           -6E               NaN       Small
# 4        S175             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls
# 0          Standard      Conventional
# 1          Standard      Conventional
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN

# %% [markdown]
# ## Variable Types - Dataset 1 Training set

# %%
# let's inspect the type of variables in pandas
data1.dtypes
# Out:
# SalesID                       int64
# SalePrice                     int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                float64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# dtype: object

# %% [markdown]
# The House Price dataset is bigger than the Titanic dataset. It contains more variables for each one of the houses. Thus, manual inspection of each one of them is a bit time demanding. Therefore, here instead of deciding variable by variable what is the best way to proceed, I will try to automate the feature engineering pipeline, making some a priori decisions on when I will apply one technique or the other, and then expanding them to the entire dataset.

# %% [markdown]
# ## Investigating Duplicate sales

# %%
data1.SalesID.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Dataset 2

# %%
# load dataset 2
data2 = pd.read_csv('Machine_Appendix.csv')

# %%
data2.head()
# Out:
#    MachineID  ModelID fiModelDesc fiBaseModel fiSecondaryDesc fiModelSeries  \
# 0        113     1355        350L         350             NaN           NaN
# 1        434     3538        416C         416               C           NaN
# 2        534     3538        416C         416               C           NaN
# 3        718     3538        416C         416               C           NaN
# 4       1753     1580      D5GLGP          D5               G           NaN
#
#   fiModelDescriptor                                 fiProductClassDesc  \
# 0                 L  Hydraulic Excavator, Track - 50.0 to 66.0 Metr...
# 1               NaN  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# 2               NaN  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# 3               NaN  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# 4               LGP  Track Type Tractor, Dozer - 85.0 to 105.0 Hors...
#
#   ProductGroup     ProductGroupDesc  MfgYear  fiManufacturerID  \
# 0          TEX     Track Excavators   1994.0                26
# 1           BL      Backhoe Loaders   1997.0                26
# 2           BL      Backhoe Loaders   1998.0                26
# 3           BL      Backhoe Loaders   2000.0                26
# 4          TTT  Track Type Tractors   2006.0                26
#
#   fiManufacturerDesc             PrimarySizeBasis  PrimaryLower  PrimaryUpper
# 0        Caterpillar         Weight - Metric Tons          50.0          66.0
# 1        Caterpillar  Standard Digging Depth - Ft          14.0          15.0
# 2        Caterpillar  Standard Digging Depth - Ft          14.0          15.0
# 3        Caterpillar  Standard Digging Depth - Ft          14.0          15.0
# 4        Caterpillar                   Horsepower          85.0         105.0

# %% [markdown]
# ## Variable Types - Dataset 2 -Test set

# %%
# let's inspect the type of variables in pandas
data2.dtypes
# Out:
# MachineID               int64
# ModelID                 int64
# fiModelDesc            object
# fiBaseModel            object
# fiSecondaryDesc        object
# fiModelSeries          object
# fiModelDescriptor      object
# fiProductClassDesc     object
# ProductGroup           object
# ProductGroupDesc       object
# MfgYear               float64
# fiManufacturerID        int64
# fiManufacturerDesc     object
# PrimarySizeBasis       object
# PrimaryLower          float64
# PrimaryUpper          float64
# dtype: object

# %%
# Extracting relevant variables from dataset 2
dataset2_rel = ['MachineID','ModelID', 'PrimarySizeBasis']

# %%
data2_rev = data2[dataset2_rel]

# %%
# Checking revised dataset 
data2_rev.head()
# Out:
#    MachineID  ModelID             PrimarySizeBasis
# 0        113     1355         Weight - Metric Tons
# 1        434     3538  Standard Digging Depth - Ft
# 2        534     3538  Standard Digging Depth - Ft
# 3        718     3538  Standard Digging Depth - Ft
# 4       1753     1580                   Horsepower

# %%
# let's inspect the type of variables in pandas for dataset 2 revised
data2_rev.dtypes
# Out:
# MachineID            int64
# ModelID              int64
# PrimarySizeBasis    object
# dtype: object

# %%
# checking dimensions of dataset 1 -Test set
data1.shape
# Out:
# (401125, 53)

# %%
# checking dimensions of dataset 2
data2_rev.shape
# Out:
# (358593, 3)

# %% [markdown]
# ## Merging the two datasets - data1 and data2_rev - test

# %%
 data_new1 = pd.merge(data1,data2_rev, how='left', on=['MachineID', 'ModelID'])

# %%
# Checking types of variables in the merged datasets
data_new1.dtypes
# Out:
# SalesID                       int64
# SalePrice                     int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                float64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# PrimarySizeBasis             object
# dtype: object

# %%
# Examing the top 5 rows of the merged dataset
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate fiModelDesc  \
# 0                      68.0       Low  11/16/2006 0:00        521D
# 1                    4640.0       Low   3/26/2004 0:00      950FII
# 2                    2838.0      High   2/26/2004 0:00         226
# 3                    3486.0      High   5/19/2011 0:00    PC120-6E
# 4                     722.0    Medium   7/23/2009 0:00        S175
#
#   fiBaseModel fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0         521               D           NaN               NaN         NaN
# 1         950               F            II               NaN      Medium
# 2         226             NaN           NaN               NaN         NaN
# 3       PC120             NaN           -6E               NaN       Small
# 4        S175             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls          PrimarySizeBasis
# 0          Standard      Conventional                Horsepower
# 1          Standard      Conventional                Horsepower
# 2               NaN               NaN  Operating Capacity - Lbs
# 3               NaN               NaN                       NaN
# 4               NaN               NaN  Operating Capacity - Lbs

# %%
# Checking dimensions of the merged dataset
data_new1.shape
# Out:
# (401125, 54)

# %% [markdown]
# *There are a mixture of categorical and numerical variables. Numerical are those of type int and float. Categorical those of type object.*

# %%
print('Number of Sales Id labels in the Training Dataset: ', len(data_new1.SalesID.unique()))
print('Number of Sales in the Training Dataset: ', len(data_new1))
# Out:
# Number of Sales Id labels in the Training Dataset:  401125
# Number of Sales in the Training Dataset:  401125

# %% [markdown]
# ## Merging test data

# %%
# load test dataset 1
data_test = pd.read_csv('Test.csv')

# %%
data_test.shape
# Out:
# (12457, 52)

# %%
# let's inspect the type of variables in pandas test data
data_test.dtypes
# Out:
# SalesID                       int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                  int64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# dtype: object

# %%
# merging test data with machine_appendix data
data_test_mer = pd.merge(data_test,data2_rev, how='left', on=['MachineID', 'ModelID'])

# %%
data_test_mer.shape
# Out:
# (12457, 53)

# %%
print('Number of Sales Id labels in the Test Dataset: ', len(data_test_mer.SalesID.unique()))
print('Number of Sales in the Test Dataset: ', len(data_test_mer))
# Out:
# Number of Sales Id labels in the Test Dataset:  12457
# Number of Sales in the Test Dataset:  12457

# %%
data_test_mer.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand        saledate fiModelDesc fiBaseModel  \
# 0                    3688.0       Low   5/3/2012 0:00        580G         580
# 1                   28555.0      High  5/10/2012 0:00         936         936
# 2                    6038.0    Medium  5/10/2012 0:00    EC210BLC       EC210
# 3                    8940.0      High  5/10/2012 0:00       330CL         330
# 4                    2286.0       Low  5/10/2012 0:00        650K         650
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor     ProductSize  \
# 0               G           NaN               NaN             NaN
# 1             NaN           NaN               NaN          Medium
# 2               B           NaN                LC  Large / Medium
# 3               C           NaN                 L  Large / Medium
# 4               K           NaN               NaN             NaN
#
#                                   fiProductClassDesc       state ProductGroup  \
# 0  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...     Wyoming           BL
# 1           Wheel Loader - 135.0 to 150.0 Horsepower    Virginia           WL
# 2  Hydraulic Excavator, Track - 21.0 to 24.0 Metr...  New Jersey          TEX
# 3  Hydraulic Excavator, Track - 33.0 to 40.0 Metr...  New Jersey          TEX
# 4  Track Type Tractor, Dozer - 20.0 to 75.0 Horse...     Florida          TTT
#
#       ProductGroupDesc     Drive_System   Enclosure Forks  \
# 0      Backhoe Loaders  Two Wheel Drive       OROPS   Yes
# 1         Wheel Loader              NaN       EROPS   Yes
# 2     Track Excavators              NaN  EROPS w AC   NaN
# 3     Track Excavators              NaN  EROPS w AC   NaN
# 4  Track Type Tractors              NaN       OROPS   NaN
#
#               Pad_Type         Ride_Control     Stick Transmission  \
# 0  None or Unspecified                   No  Standard     Standard
# 1                  NaN  None or Unspecified       NaN          NaN
# 2                  NaN                  NaN       NaN          NaN
# 3                  NaN                  NaN       NaN          NaN
# 4                  NaN                  NaN       NaN  Hydrostatic
#
#           Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  None or Unspecified             NaN         NaN            NaN
# 1                  NaN             NaN         NaN            NaN
# 2                  NaN             NaN         NaN            NaN
# 3                  NaN             NaN         NaN            NaN
# 4                  NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock               Ripper Scarifier  \
# 0               NaN        NaN       NaN                  NaN       NaN
# 1               NaN    2 Valve       NaN                  NaN       NaN
# 2               NaN  Auxiliary       NaN                  NaN       NaN
# 3               NaN   Standard       NaN                  NaN       NaN
# 4               NaN    2 Valve       NaN  None or Unspecified       NaN
#
#   Tip_Control Tire_Size              Coupler Coupler_System Grouser_Tracks  \
# 0         NaN       NaN                  NaN            NaN            NaN
# 1         NaN      20.5  None or Unspecified            NaN            NaN
# 2         NaN       NaN  None or Unspecified            NaN            NaN
# 3         NaN       NaN  None or Unspecified            NaN            NaN
# 4         NaN       NaN                  NaN            NaN            NaN
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width         Stick_Length  \
# 0             NaN        NaN                     NaN                  NaN
# 1             NaN        NaN                     NaN                  NaN
# 2             NaN      Steel     None or Unspecified                9' 6"
# 3             NaN      Steel     None or Unspecified  None or Unspecified
# 4             NaN        NaN                     NaN                  NaN
#
#     Thumb      Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0     NaN                  NaN          NaN                  NaN        NaN
# 1     NaN                  NaN          NaN                  NaN        NaN
# 2  Manual  None or Unspecified       Double                  NaN        NaN
# 3  Manual                  Yes       Triple                  NaN        NaN
# 4     NaN                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis
# 0  Standard Digging Depth - Ft
# 1                   Horsepower
# 2         Weight - Metric Tons
# 3         Weight - Metric Tons
# 4                          NaN

# %% [markdown]
# ## Creating an Age variable for the Training dataset

# %%
# Extracting the year from a time object
data_new1['saledate'] = pd.to_datetime(data_new1['saledate'])

# %%
#use the datetime attribute dt to access the datetime components
data_new1['yearsold'] = data_new1['saledate'].dt.year

# %%
#Checking if the new variable was created
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                      68.0       Low 2006-11-16        521D         521
# 1                    4640.0       Low 2004-03-26      950FII         950
# 2                    2838.0      High 2004-02-26         226         226
# 3                    3486.0      High 2011-05-19    PC120-6E       PC120
# 4                     722.0    Medium 2009-07-23        S175        S175
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0               D           NaN               NaN         NaN
# 1               F            II               NaN      Medium
# 2             NaN           NaN               NaN         NaN
# 3             NaN           -6E               NaN       Small
# 4             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls          PrimarySizeBasis  yearsold
# 0          Standard      Conventional                Horsepower      2006
# 1          Standard      Conventional                Horsepower      2004
# 2               NaN               NaN  Operating Capacity - Lbs      2004
# 3               NaN               NaN                       NaN      2011
# 4               NaN               NaN  Operating Capacity - Lbs      2009

# %%
data_new1.yearsold.dtypes, data_new1.YearMade.dtypes
# Out:
# (dtype('int64'), dtype('int64'))

# %%
# Creating an Age variable
data_new1['MachineAge'] = data_new1['yearsold'] - data_new1['YearMade']

# %%
# Checking if the new MachineAge variable was created
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                      68.0       Low 2006-11-16        521D         521
# 1                    4640.0       Low 2004-03-26      950FII         950
# 2                    2838.0      High 2004-02-26         226         226
# 3                    3486.0      High 2011-05-19    PC120-6E       PC120
# 4                     722.0    Medium 2009-07-23        S175        S175
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0               D           NaN               NaN         NaN
# 1               F            II               NaN      Medium
# 2             NaN           NaN               NaN         NaN
# 3             NaN           -6E               NaN       Small
# 4             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls          PrimarySizeBasis  yearsold  \
# 0          Standard      Conventional                Horsepower      2006
# 1          Standard      Conventional                Horsepower      2004
# 2               NaN               NaN  Operating Capacity - Lbs      2004
# 3               NaN               NaN                       NaN      2011
# 4               NaN               NaN  Operating Capacity - Lbs      2009
#
#    MachineAge
# 0           2
# 1           8
# 2           3
# 3          10
# 4           2

# %% [markdown]
#  Some of the variables are superfluous and will be removed from the analysis:
#     . SalesID
#     . datasource
#     . auctioneerID
#     . YearMade
#     . saledate
#     . fiModelDesc
#     . fiModelDescriptor
#     . fiProductClassDesc
#     . yearsold
#     . PrimaryUpper
#     . PrimaryLower

# %% [markdown]
# ## Creating an Age variable for the Test dataset

# %%
# Extracting the year from a time object
data_test_mer['saledate'] = pd.to_datetime(data_test_mer['saledate'])

# %%
#use the datetime attribute dt to access the datetime components
data_test_mer['yearsold'] = data_test_mer['saledate'].dt.year

# %%
#Checking if the new variable was created
data_test_mer.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                    3688.0       Low 2012-05-03        580G         580
# 1                   28555.0      High 2012-05-10         936         936
# 2                    6038.0    Medium 2012-05-10    EC210BLC       EC210
# 3                    8940.0      High 2012-05-10       330CL         330
# 4                    2286.0       Low 2012-05-10        650K         650
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor     ProductSize  \
# 0               G           NaN               NaN             NaN
# 1             NaN           NaN               NaN          Medium
# 2               B           NaN                LC  Large / Medium
# 3               C           NaN                 L  Large / Medium
# 4               K           NaN               NaN             NaN
#
#                                   fiProductClassDesc       state ProductGroup  \
# 0  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...     Wyoming           BL
# 1           Wheel Loader - 135.0 to 150.0 Horsepower    Virginia           WL
# 2  Hydraulic Excavator, Track - 21.0 to 24.0 Metr...  New Jersey          TEX
# 3  Hydraulic Excavator, Track - 33.0 to 40.0 Metr...  New Jersey          TEX
# 4  Track Type Tractor, Dozer - 20.0 to 75.0 Horse...     Florida          TTT
#
#       ProductGroupDesc     Drive_System   Enclosure Forks  \
# 0      Backhoe Loaders  Two Wheel Drive       OROPS   Yes
# 1         Wheel Loader              NaN       EROPS   Yes
# 2     Track Excavators              NaN  EROPS w AC   NaN
# 3     Track Excavators              NaN  EROPS w AC   NaN
# 4  Track Type Tractors              NaN       OROPS   NaN
#
#               Pad_Type         Ride_Control     Stick Transmission  \
# 0  None or Unspecified                   No  Standard     Standard
# 1                  NaN  None or Unspecified       NaN          NaN
# 2                  NaN                  NaN       NaN          NaN
# 3                  NaN                  NaN       NaN          NaN
# 4                  NaN                  NaN       NaN  Hydrostatic
#
#           Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  None or Unspecified             NaN         NaN            NaN
# 1                  NaN             NaN         NaN            NaN
# 2                  NaN             NaN         NaN            NaN
# 3                  NaN             NaN         NaN            NaN
# 4                  NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock               Ripper Scarifier  \
# 0               NaN        NaN       NaN                  NaN       NaN
# 1               NaN    2 Valve       NaN                  NaN       NaN
# 2               NaN  Auxiliary       NaN                  NaN       NaN
# 3               NaN   Standard       NaN                  NaN       NaN
# 4               NaN    2 Valve       NaN  None or Unspecified       NaN
#
#   Tip_Control Tire_Size              Coupler Coupler_System Grouser_Tracks  \
# 0         NaN       NaN                  NaN            NaN            NaN
# 1         NaN      20.5  None or Unspecified            NaN            NaN
# 2         NaN       NaN  None or Unspecified            NaN            NaN
# 3         NaN       NaN  None or Unspecified            NaN            NaN
# 4         NaN       NaN                  NaN            NaN            NaN
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width         Stick_Length  \
# 0             NaN        NaN                     NaN                  NaN
# 1             NaN        NaN                     NaN                  NaN
# 2             NaN      Steel     None or Unspecified                9' 6"
# 3             NaN      Steel     None or Unspecified  None or Unspecified
# 4             NaN        NaN                     NaN                  NaN
#
#     Thumb      Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0     NaN                  NaN          NaN                  NaN        NaN
# 1     NaN                  NaN          NaN                  NaN        NaN
# 2  Manual  None or Unspecified       Double                  NaN        NaN
# 3  Manual                  Yes       Triple                  NaN        NaN
# 4     NaN                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  yearsold
# 0  Standard Digging Depth - Ft      2012
# 1                   Horsepower      2012
# 2         Weight - Metric Tons      2012
# 3         Weight - Metric Tons      2012
# 4                          NaN      2012

# %%
data_test_mer.yearsold.dtypes, data_test_mer.YearMade.dtypes
# Out:
# (dtype('int64'), dtype('int64'))

# %%
# Creating an Age variable
data_test_mer['MachineAge'] = data_test_mer['yearsold'] - data_test_mer['YearMade']

# %%
#Checking if the new variable was created
data_test_mer.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                    3688.0       Low 2012-05-03        580G         580
# 1                   28555.0      High 2012-05-10         936         936
# 2                    6038.0    Medium 2012-05-10    EC210BLC       EC210
# 3                    8940.0      High 2012-05-10       330CL         330
# 4                    2286.0       Low 2012-05-10        650K         650
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor     ProductSize  \
# 0               G           NaN               NaN             NaN
# 1             NaN           NaN               NaN          Medium
# 2               B           NaN                LC  Large / Medium
# 3               C           NaN                 L  Large / Medium
# 4               K           NaN               NaN             NaN
#
#                                   fiProductClassDesc       state ProductGroup  \
# 0  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...     Wyoming           BL
# 1           Wheel Loader - 135.0 to 150.0 Horsepower    Virginia           WL
# 2  Hydraulic Excavator, Track - 21.0 to 24.0 Metr...  New Jersey          TEX
# 3  Hydraulic Excavator, Track - 33.0 to 40.0 Metr...  New Jersey          TEX
# 4  Track Type Tractor, Dozer - 20.0 to 75.0 Horse...     Florida          TTT
#
#       ProductGroupDesc     Drive_System   Enclosure Forks  \
# 0      Backhoe Loaders  Two Wheel Drive       OROPS   Yes
# 1         Wheel Loader              NaN       EROPS   Yes
# 2     Track Excavators              NaN  EROPS w AC   NaN
# 3     Track Excavators              NaN  EROPS w AC   NaN
# 4  Track Type Tractors              NaN       OROPS   NaN
#
#               Pad_Type         Ride_Control     Stick Transmission  \
# 0  None or Unspecified                   No  Standard     Standard
# 1                  NaN  None or Unspecified       NaN          NaN
# 2                  NaN                  NaN       NaN          NaN
# 3                  NaN                  NaN       NaN          NaN
# 4                  NaN                  NaN       NaN  Hydrostatic
#
#           Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  None or Unspecified             NaN         NaN            NaN
# 1                  NaN             NaN         NaN            NaN
# 2                  NaN             NaN         NaN            NaN
# 3                  NaN             NaN         NaN            NaN
# 4                  NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock               Ripper Scarifier  \
# 0               NaN        NaN       NaN                  NaN       NaN
# 1               NaN    2 Valve       NaN                  NaN       NaN
# 2               NaN  Auxiliary       NaN                  NaN       NaN
# 3               NaN   Standard       NaN                  NaN       NaN
# 4               NaN    2 Valve       NaN  None or Unspecified       NaN
#
#   Tip_Control Tire_Size              Coupler Coupler_System Grouser_Tracks  \
# 0         NaN       NaN                  NaN            NaN            NaN
# 1         NaN      20.5  None or Unspecified            NaN            NaN
# 2         NaN       NaN  None or Unspecified            NaN            NaN
# 3         NaN       NaN  None or Unspecified            NaN            NaN
# 4         NaN       NaN                  NaN            NaN            NaN
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width         Stick_Length  \
# 0             NaN        NaN                     NaN                  NaN
# 1             NaN        NaN                     NaN                  NaN
# 2             NaN      Steel     None or Unspecified                9' 6"
# 3             NaN      Steel     None or Unspecified  None or Unspecified
# 4             NaN        NaN                     NaN                  NaN
#
#     Thumb      Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0     NaN                  NaN          NaN                  NaN        NaN
# 1     NaN                  NaN          NaN                  NaN        NaN
# 2  Manual  None or Unspecified       Double                  NaN        NaN
# 3  Manual                  Yes       Triple                  NaN        NaN
# 4     NaN                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  yearsold  MachineAge
# 0  Standard Digging Depth - Ft      2012          13
# 1                   Horsepower      2012        1012
# 2         Weight - Metric Tons      2012           8
# 3         Weight - Metric Tons      2012           6
# 4                          NaN      2012           7

# %% [markdown]
# ## Examing the Training dataset

# %%
# find categorical variables
categorical = [var for var in data_new1.columns if data_new1[var].dtype=='O']
print('There are {} categorical variables in the Training dataset'.format(len(categorical)))
# Out:
# There are 45 categorical variables in the Training dataset

# %%
# find numerical variables
numerical = [var for var in data_new1.columns if data_new1[var].dtype!='O']
print('There are {} numerical variables in the Training dataset'.format(len(numerical)))
# Out:
# There are 11 numerical variables in the Training dataset

# %% [markdown]
# **We will drop unnecessary variables such as salesdate, yearmade and yearsold.**

# %% [markdown]
# ## Examing the Test dataset

# %%
# find categorical variables
categorical = [var for var in data_test_mer.columns if data_test_mer[var].dtype=='O']
print('There are {} categorical variables in the Test dataset'.format(len(categorical)))
# Out:
# There are 45 categorical variables in the Test dataset

# %%
# find numerical variables
numerical = [var for var in data_test_mer.columns if data_test_mer[var].dtype!='O']
print('There are {} numerical variables in the Test dataset'.format(len(numerical)))
# Out:
# There are 10 numerical variables in the Test dataset

# %% [markdown]
# #### Find discrete variables in the training dataset
#
# To identify discrete variables, I will select from all the numerical ones, those that contain a finite and small number of distinct values. See below.

# %%
discrete = []
for var in numerical:
    if len(data_new1[var].unique())<20:
        print(var, ' values: ', data_new1[var].unique())
        discrete.append(var)
        
print('There are {} discrete variables in the Training dataset'.format(len(discrete)))
# Out:
# datasource  values:  [121 132 136 149 172]
# There are 1 discrete variables in the Training dataset

# %% [markdown]
# **The variable "datasource" is not very meaningful and will be remove from the analysis.**

# %% [markdown]
# ### Types of problems within the variables in the Training dataset

# %% [markdown]
# ## Missing values

# %%
# let's visualise the percentage of missing values in the Training dataset
for var in data_new1.columns:
    if data_new1[var].isnull().sum()>0:
        print(var, data_new1[var].isnull().mean())
# Out:
# auctioneerID 0.0501988158305
# MachineHoursCurrentMeter 0.644088501091
# UsageBand 0.826390775943
# fiSecondaryDesc 0.342015581178
# fiModelSeries 0.858129012153
# fiModelDescriptor 0.820706762231
# ProductSize 0.525459644749
# Drive_System 0.73982923029
# Enclosure 0.000810221252727
# Forks 0.521154253662
# Pad_Type 0.802719850421
# Ride_Control 0.629526955438
# Stick 0.802719850421
# Transmission 0.543209722655
# Turbocharged 0.802719850421
# Blade_Extension 0.937129323777
# Blade_Width 0.937129323777
# Enclosure_Type 0.937129323777
# Engine_Horsepower 0.937129323777
# Hydraulics 0.200822686195
# Pushblock 0.937129323777
# Ripper 0.740387659707
# Scarifier 0.937101900904
# Tip_Control 0.937129323777
# Tire_Size 0.763869118105
# Coupler 0.466620130882
# Coupler_System 0.891659707074
# Grouser_Tracks 0.891899033967
# Hydraulics_Flow 0.891899033967
# Track_Type 0.752812714241
# Undercarriage_Pad_Width 0.751020255531
# Stick_Length 0.752650669991
# Thumb 0.752476160798
# Pattern_Changer 0.752650669991
# Grouser_Type 0.752812714241
# Backhoe_Mounting 0.803871611094
# Blade_Type 0.80097725148
# Travel_Controls 0.800974758492
# Differential_Type 0.826959177314
# Steering_Controls 0.82706388283
# PrimarySizeBasis 0.0710426924275

# %%
# let's inspect the type of those variables with a lot of missing information in the Training dataset
for var in data_new1.columns:
    if data_new1[var].isnull().mean()>0.4:
        print(var, data_new1[var].unique())
# Out:
# MachineHoursCurrentMeter [    68.   4640.   2838. ...,   8298.  35740.  12201.]
# UsageBand ['Low' 'High' 'Medium' nan]
# fiModelSeries [nan 'II' '-6E' 'LC' '-5' 'III' '-1' '5' '-2' '1' '#NAME?' '-3L' '-20' '3'
#  '15' '-12' '6' '-6' 'V' '-3' '-3PT' '-21' '-7' '7' '-3MC' 'IV' '-21A'
#  '-3LC' '-5L' '5N' '-5H' '-1L' '-8' '4' '2' '-18' '-15' '2T' '18' 'E' '-3C'
#  '-6B' '7.00E+00' 'A' '-3LK' 'ZTS' '-2N' '12' 'V-2' 'XT' '-7E' '-2C' '-8E'
#  '-6LC' '-3H' '16' 'IV-2' '-6K' '6F' '22' '3A' 'VHP' 'LGP' 'LT' '14FT' 'EX'
#  '-6C' '3C' '-7K' '17' '1970' '-2LC' 'M' 'D' 'ZX' 'LV' '-5LC' '-5E'
#  '6.00E+00' '-17' '-16' '-4' '8' '-7B' '-1C' '-11' 'L' '-6A' 'LL' -5.0 -2.0
#  -8.0 -3.0 -7.0 2.0 'G' 'WX' '-2A' '-5F' '-3M' 'D7' '7A' ' III' 'AWS' '2B'
#  '20' '-5A' '-6LK' '-2E' 'VI' 'H' '-1B' '-3EO' 'TC' 'Elite' 'WT' 'XLT'
#  'SeriesII' '-1.50E+01' 'GALEO' '6L' '6LE' '6LK' '21KomStatII' '21KomStat'
#  '7L' 'Q' 'ZHS' 'FASTRRACK']
# fiModelDescriptor [nan 'LC' '6' 'L' 'LT' 'CR' 'SB' 'XL' 'LGP' 'VHP' '7' 'Z' '2.00E+00' 'MC'
#  'H' 'E' '3' 'LK' '5' 'K' '8' 'HT' 'LX' 'XLT' 'XW' 'HSD' '2' 'XR' 'TC'
#  'LCR' 'TLB' 'WT' 'TURBO' 'U' '4WD' 'XT' 'LRC' 'ZTS' 'RTS' 'TP' 'LE' 'LRR'
#  'SA' '3C' 'SR' 'XP' '1' 'BE' '3NO' 'CRSB' 'N' 'SSR' 'DHP' 'LM' ' SUPER'
#  'KA' 'H5' 'II' 'MH' 'P' 'LU' 'DT' 'XTV' 'LR' 'ZX' 'LL' 'V' 'DELUXE' 'USLC'
#  'SU' 'SRDZ' 'C' 'PRO' 'PLUS' 'SITEMASTER' 'DINGO' '3.00E+00' ' XLT' 'LN'
#  'AE0' 'SERIES3' '7.00E+00' 'ESL' 'A' 'G' 'B' 'DLL' 'CK' 'NSUC' 'LS' 'SLGP'
#  'RR' 'WLT' 'LCRTS' 'X' 'LCH' 'T' 'NLC' 'SM' 'SE' 'TM' 'SRLC' 'CUSTOM' 'HD'
#  'DW' 'LC8' ' LGP' 'TK' 'HF' 'SUPER K' 'IV' ' XT' 'IT' 'XLVP' 'LGPVP' 'K5'
#  '3L' '7A' 'XD' 'DA' 'Y' 'S' 'M' '6K' 'LITRONIC' 'KBNA' ' 14FT' '2N' 'III'
#  'ME' 'High Lift' 'HighLift' 'VHP/AWD' 'K3' '4x4x4' ' ZX' '(BLADE RUNNER)'
#  'AVANCE' 'GALEO' 'LongReach']
# ProductSize [nan 'Medium' 'Small' 'Large / Medium' 'Mini' 'Large' 'Compact']
# Drive_System [nan 'Four Wheel Drive' 'Two Wheel Drive' 'No' 'All Wheel Drive']
# Forks ['None or Unspecified' nan 'Yes']
# Pad_Type [nan 'None or Unspecified' 'Reversible' 'Street' 'Grouser']
# Ride_Control ['None or Unspecified' nan 'No' 'Yes']
# Stick [nan 'Extended' 'Standard']
# Transmission [nan 'Powershuttle' 'Standard' 'Powershift' 'None or Unspecified'
#  'Hydrostatic' 'Autoshift' 'Direct Drive' 'AutoShift']
# Turbocharged [nan 'None or Unspecified' 'Yes']
# Blade_Extension [nan 'Yes' 'None or Unspecified']
# Blade_Width [nan 'None or Unspecified' "12'" "14'" "13'" "16'" "<12'"]
# Enclosure_Type [nan 'None or Unspecified' 'Low Profile' 'High Profile']
# Engine_Horsepower [nan 'No' 'Variable']
# Pushblock [nan 'None or Unspecified' 'Yes']
# Ripper [nan 'None or Unspecified' 'Yes' 'Single Shank' 'Multi Shank']
# Scarifier [nan 'Yes' 'None or Unspecified']
# Tip_Control [nan 'Sideshift & Tip' 'None or Unspecified' 'Tip']
# Tire_Size ['None or Unspecified' '23.5' nan '13"' '26.5' '29.5' '14"' '20.5' '17.5"'
#  '15.5"' '20.5"' '17.5' '7.0"' '15.5' '23.5"' '10"' '23.1"' '10 inch']
# Coupler ['None or Unspecified' nan 'Manual' 'Hydraulic']
# Coupler_System [nan 'None or Unspecified' 'Yes']
# Grouser_Tracks [nan 'None or Unspecified' 'Yes']
# Hydraulics_Flow [nan 'Standard' 'High Flow' 'None or Unspecified']
# Track_Type [nan 'Steel' 'Rubber']
# Undercarriage_Pad_Width [nan 'None or Unspecified' '16 inch' '32 inch' '28 inch' '30 inch'
#  '22 inch' '24 inch' '18 inch' '36 inch' '20 inch' '27 inch' '15 inch'
#  '26 inch' '34 inch' '33 inch' '14 inch' '31 inch' '25 inch' '31.5 inch']
# Stick_Length [nan 'None or Unspecified' '11\' 0"' '15\' 9"' '10\' 2"' '10\' 6"'
#  '9\' 10"' '10\' 10"' '9\' 6"' '9\' 7"' '12\' 8"' '8\' 2"' '8\' 6"'
#  '9\' 8"' '12\' 10"' '11\' 10"' '8\' 10"' '8\' 4"' '12\' 4"' '9\' 5"'
#  '6\' 3"' '14\' 1"' '13\' 7"' '13\' 10"' '13\' 9"' '7\' 10"' '15\' 4"'
#  '9\' 2"' '24\' 3"' '19\' 8"']
# Thumb [nan 'None or Unspecified' 'Hydraulic' 'Manual']
# Pattern_Changer [nan 'None or Unspecified' 'Yes' 'No']
# Grouser_Type [nan 'Double' 'Triple' 'Single']
# Backhoe_Mounting [nan 'None or Unspecified' 'Yes']
# Blade_Type [nan 'PAT' 'None or Unspecified' 'Semi U' 'VPAT' 'Straight' 'Angle' 'No'
#  'U' 'Landfill' 'Coal']
# Travel_Controls [nan 'None or Unspecified' 'Differential Steer' 'Lever' 'Finger Tip'
#  '2 Pedal' 'Pedal' '1 Speed']
# Differential_Type ['Standard' nan 'Limited Slip' 'No Spin' 'Locking']
# Steering_Controls ['Conventional' nan 'Command Control' 'Four Wheel Standard' 'Wheel' 'No']

# %% [markdown]
# ### Types of problems within the variables in the Test dataset

# %% [markdown]
# ## Missing Values

# %%
# let's visualise the percentage of missing values in the Test dataset
for var in data_test_mer.columns:
    if data_test_mer[var].isnull().sum()>0:
        print(var, data_test_mer[var].isnull().mean())
# Out:
# MachineHoursCurrentMeter 0.829092076744
# UsageBand 0.852773540981
# fiSecondaryDesc 0.319097696074
# fiModelSeries 0.838966043189
# fiModelDescriptor 0.757244922534
# ProductSize 0.514489845067
# Drive_System 0.778518102272
# Enclosure 0.000160552299912
# Forks 0.493618046079
# Pad_Type 0.830777875893
# Ride_Control 0.659548848037
# Stick 0.830777875893
# Transmission 0.613229509513
# Turbocharged 0.830777875893
# Blade_Extension 0.947740226379
# Blade_Width 0.947740226379
# Enclosure_Type 0.947740226379
# Engine_Horsepower 0.947740226379
# Hydraulics 0.171951513205
# Pushblock 0.947740226379
# Ripper 0.782933290519
# Scarifier 0.947740226379
# Tip_Control 0.947740226379
# Tire_Size 0.776992855423
# Coupler 0.389820984186
# Coupler_System 0.834149474191
# Grouser_Tracks 0.834149474191
# Hydraulics_Flow 0.834149474191
# Track_Type 0.72754274705
# Undercarriage_Pad_Width 0.72722164245
# Stick_Length 0.72754274705
# Thumb 0.7274624709
# Pattern_Changer 0.72754274705
# Grouser_Type 0.72754274705
# Backhoe_Mounting 0.835353616441
# Blade_Type 0.834791683391
# Travel_Controls 0.834791683391
# Differential_Type 0.829092076744
# Steering_Controls 0.829092076744
# PrimarySizeBasis 0.0398972465281

# %%
# let's inspect the type of those variables with a lot of missing information in the Test dataset
for var in data_test_mer.columns:
    if data_test_mer[var].isnull().mean()>0.1:
        print(var, data_test_mer[var].unique())
# Out:
# MachineHoursCurrentMeter [  3688.  28555.   6038. ...,   5603.   2871.   2233.]
# UsageBand ['Low' 'High' 'Medium' nan]
# fiSecondaryDesc ['G' nan 'B' 'C' 'K' 'E' 'US' 'MR' 'PX' 'LC' 'M' 'SUPER L' 'SUPER M'
#  'SUPER K' 'J' 'MXT' 'N' 'H' 'D' 'Z' 'A' 'R' 'P' 'AG' 'UU' 'F' 'SE' 'XT'
#  'LX' 'SG' 'L' 'SUPER E' 'TX' 'EX' 'SRLC' 'Q' 'CH' 'LE' 'BL' 'S' 'SUPER'
#  'HZ' 'ZTS' 'X' 'B     ' 'PT' 'PS' 'NX' 'SJ' 'SR' '7' 'HD' ' MSR SPIN ACE'
#  '5A' 'ZF' 'EST' 'C      ' 'USR' 'UR' 'U' 'XTD' '3' 'T' 'TM' 'HF' 'ZHS'
#  'HAG' 'LGP' 'WT' 'TC' 'LCM' 'W' 'SX' 'WD' ' ZTS' 'UNA' 'H      ' '-7A'
#  'BZD' 'DL' 'CS' 'DZ' 'EG']
# fiModelSeries [nan '-5' 'IV' 'LC' '8' '-6' '-3MC' '-12' '5' '6' '-1L' '-3L' '-1' 'II' 'V'
#  '-5L' '-2' '3' '-6E' 'III' '7' '2' '1' 'ZTS' '7.00E+00' '-3LK' '-7' '-3'
#  '-7E' '-15' '#NAME?' '-21' '-2C' '-16' 'LGP' 'WT' 'XT' 'L' 'XLT' '-18'
#  '6LE' '-2N' '15' '-20' '2T' 'LT' '-3C' 'E' '-5E' 'A' '4' ' III' 'IV-2'
#  'V-2' '-8' '-3PT' 'AWS' '-3EO' '-3LC' '2B' '22' 'XR' '7A' '17']
# fiModelDescriptor [nan 'LC' 'L' '2' '4WD' 'LK' 'LCR' 'LGP' 'XL' 'BE' 'LCH' 'CR' 'LT' 'XT' '3'
#  '7' 'K' '5' '6' 'SR' 'H' 'E' 'LRC' 'LE' 'XW' 'N' 'Y' 'CRSB' 'XTV' '3C'
#  'II' 'WT' 'XLT' 'VHP' 'III' 'Z' 'TC' 'ZTS' 'A' 'HT' 'C' 'AVANCE'
#  '2.00E+00' '8' 'LX' '3NO' ' LGP' 'LRR' 'TLB' 'RTS' 'ESL' 'SSR' 'LS' 'LN'
#  'LU' 'SB' 'IV' 'XP' 'W' 'DA' 'KA' 'HST' 'XR' 'MH' 'ZX' 'SRLC' 'SRDZ' 'WLT'
#  '(BLADE RUNNER)' 'CL' 'PLUS' 'XD' '1' 'MC' 'PRO']
# ProductSize [nan 'Medium' 'Large / Medium' 'Small' 'Large' 'Mini' 'Compact']
# Drive_System ['Two Wheel Drive' nan 'Four Wheel Drive' 'No' 'All Wheel Drive']
# Forks ['Yes' nan 'None or Unspecified']
# Pad_Type ['None or Unspecified' nan 'Reversible' 'Street' 'Grouser']
# Ride_Control ['No' 'None or Unspecified' nan 'Yes']
# Stick ['Standard' nan 'Extended']
# Transmission ['Standard' nan 'Hydrostatic' 'Powershift' 'Powershuttle'
#  'None or Unspecified' 'Direct Drive' 'Autoshift']
# Turbocharged ['None or Unspecified' nan 'Yes']
# Blade_Extension [nan 'None or Unspecified' 'Yes']
# Blade_Width [nan "14'" 'None or Unspecified' "12'" "<12'" "16'" "13'"]
# Enclosure_Type [nan 'None or Unspecified' 'High Profile' 'Low Profile']
# Engine_Horsepower [nan 'No' 'Variable']
# Hydraulics [nan '2 Valve' 'Auxiliary' 'Standard' '3 Valve' 'Base + 1 Function'
#  '4 Valve' 'Base + 4 Function' 'Base + 3 Function' 'Base + 2 Function'
#  'Base + 5 Function' 'Base + 6 Function']
# Pushblock [nan 'None or Unspecified' 'Yes']
# Ripper [nan 'None or Unspecified' 'Single Shank' 'Yes' 'Multi Shank']
# Scarifier [nan 'Yes' 'None or Unspecified']
# Tip_Control [nan 'None or Unspecified' 'Sideshift & Tip' 'Tip']
# Tire_Size [nan '20.5' '17.5' '23.5' '26.5' '17.5"' 'None or Unspecified' '14"' '29.5'
#  '15.5"' '13"' '20.5"' '15.5' '23.5"']
# Coupler [nan 'None or Unspecified' 'Hydraulic' 'Manual']
# Coupler_System [nan 'Yes' 'None or Unspecified']
# Grouser_Tracks [nan 'None or Unspecified' 'Yes']
# Hydraulics_Flow [nan 'Standard' 'High Flow' 'None or Unspecified']
# Track_Type [nan 'Steel' 'Rubber']
# Undercarriage_Pad_Width [nan 'None or Unspecified' '34 inch' '36 inch' '14 inch' '24 inch'
#  '32 inch' '16 inch' '20 inch' '27 inch' '28 inch' '30 inch' '31 inch'
#  '26 inch' '18 inch' '33 inch' '22 inch' '25 inch']
# Stick_Length [nan '9\' 6"' 'None or Unspecified' '9\' 8"' '9\' 10"' '10\' 2"' '11\' 0"'
#  '8\' 2"' '10\' 6"' '9\' 7"' '10\' 10"' '12\' 8"' '12\' 10"' '8\' 6"'
#  '11\' 10"' '8\' 10"' '8\' 4"' '12\' 4"' '13\' 10"' '9\' 5"' '15\' 9"']
# Thumb [nan 'Manual' 'None or Unspecified' 'Hydraulic']
# Pattern_Changer [nan 'None or Unspecified' 'Yes']
# Grouser_Type [nan 'Double' 'Triple']
# Backhoe_Mounting [nan 'None or Unspecified']
# Blade_Type [nan 'PAT' 'None or Unspecified' 'Semi U' 'Straight' 'No' 'U' 'Angle'
#  'VPAT']
# Travel_Controls [nan 'None or Unspecified' 'Differential Steer' 'Lever' '2 Pedal'
#  'Finger Tip' 'Pedal']
# Differential_Type [nan 'Standard' 'Limited Slip' 'No Spin']
# Steering_Controls [nan 'Conventional' 'Command Control' 'Four Wheel Standard']

# %% [markdown]
# ** There are alot of variables with missing data in both the Training set and Test set and the variables are all categorical**

# %% [markdown]
# ## Deleting superfluous variables from the Training and Test sets

# %%
# Deleting variables from the Training setdat
data_new1.drop(['SalesID','yearsold','MachineID','ModelID','datasource','auctioneerID','YearMade','saledate','fiModelDesc','fiModelDescriptor','fiProductClassDesc'], axis=1,inplace=True)

# %%
data_new1.head()
# Out:
#    SalePrice  MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0      66000                      68.0       Low         521               D
# 1      57000                    4640.0       Low         950               F
# 2      10000                    2838.0      High         226             NaN
# 3      38500                    3486.0      High       PC120             NaN
# 4      11000                     722.0    Medium        S175             NaN
#
#   fiModelSeries ProductSize           state ProductGroup    ProductGroupDesc  \
# 0           NaN         NaN         Alabama           WL        Wheel Loader
# 1            II      Medium  North Carolina           WL        Wheel Loader
# 2           NaN         NaN        New York          SSL  Skid Steer Loaders
# 3           -6E       Small           Texas          TEX    Track Excavators
# 4           NaN         NaN        New York          SSL  Skid Steer Loaders
#
#   Drive_System   Enclosure                Forks Pad_Type         Ride_Control  \
# 0          NaN  EROPS w AC  None or Unspecified      NaN  None or Unspecified
# 1          NaN  EROPS w AC  None or Unspecified      NaN  None or Unspecified
# 2          NaN       OROPS  None or Unspecified      NaN                  NaN
# 3          NaN  EROPS w AC                  NaN      NaN                  NaN
# 4          NaN       EROPS  None or Unspecified      NaN                  NaN
#
#   Stick Transmission Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0   NaN          NaN          NaN             NaN         NaN            NaN
# 1   NaN          NaN          NaN             NaN         NaN            NaN
# 2   NaN          NaN          NaN             NaN         NaN            NaN
# 3   NaN          NaN          NaN             NaN         NaN            NaN
# 4   NaN          NaN          NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock Ripper Scarifier Tip_Control  \
# 0               NaN    2 Valve       NaN    NaN       NaN         NaN
# 1               NaN    2 Valve       NaN    NaN       NaN         NaN
# 2               NaN  Auxiliary       NaN    NaN       NaN         NaN
# 3               NaN    2 Valve       NaN    NaN       NaN         NaN
# 4               NaN  Auxiliary       NaN    NaN       NaN         NaN
#
#              Tire_Size              Coupler       Coupler_System  \
# 0  None or Unspecified  None or Unspecified                  NaN
# 1                 23.5  None or Unspecified                  NaN
# 2                  NaN  None or Unspecified  None or Unspecified
# 3                  NaN  None or Unspecified                  NaN
# 4                  NaN  None or Unspecified  None or Unspecified
#
#         Grouser_Tracks Hydraulics_Flow Track_Type Undercarriage_Pad_Width  \
# 0                  NaN             NaN        NaN                     NaN
# 1                  NaN             NaN        NaN                     NaN
# 2  None or Unspecified        Standard        NaN                     NaN
# 3                  NaN             NaN        NaN                     NaN
# 4  None or Unspecified        Standard        NaN                     NaN
#
#   Stick_Length Thumb Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0          NaN   NaN             NaN          NaN              NaN        NaN
# 1          NaN   NaN             NaN          NaN              NaN        NaN
# 2          NaN   NaN             NaN          NaN              NaN        NaN
# 3          NaN   NaN             NaN          NaN              NaN        NaN
# 4          NaN   NaN             NaN          NaN              NaN        NaN
#
#   Travel_Controls Differential_Type Steering_Controls  \
# 0             NaN          Standard      Conventional
# 1             NaN          Standard      Conventional
# 2             NaN               NaN               NaN
# 3             NaN               NaN               NaN
# 4             NaN               NaN               NaN
#
#            PrimarySizeBasis  MachineAge
# 0                Horsepower           2
# 1                Horsepower           8
# 2  Operating Capacity - Lbs           3
# 3                       NaN          10
# 4  Operating Capacity - Lbs           2

# %%
#Deleting variables from the Test set
data_test_mer.drop(['SalesID','yearsold','MachineID','ModelID','datasource','auctioneerID','YearMade','saledate','fiModelDesc','fiModelDescriptor','fiProductClassDesc'], axis=1,inplace=True)

# %%
# Checking that it worked
data_test_mer.head()
# Out:
#    MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0                    3688.0       Low         580               G
# 1                   28555.0      High         936             NaN
# 2                    6038.0    Medium       EC210               B
# 3                    8940.0      High         330               C
# 4                    2286.0       Low         650               K
#
#   fiModelSeries     ProductSize       state ProductGroup     ProductGroupDesc  \
# 0           NaN             NaN     Wyoming           BL      Backhoe Loaders
# 1           NaN          Medium    Virginia           WL         Wheel Loader
# 2           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 3           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 4           NaN             NaN     Florida          TTT  Track Type Tractors
#
#       Drive_System   Enclosure Forks             Pad_Type  \
# 0  Two Wheel Drive       OROPS   Yes  None or Unspecified
# 1              NaN       EROPS   Yes                  NaN
# 2              NaN  EROPS w AC   NaN                  NaN
# 3              NaN  EROPS w AC   NaN                  NaN
# 4              NaN       OROPS   NaN                  NaN
#
#           Ride_Control     Stick Transmission         Turbocharged  \
# 0                   No  Standard     Standard  None or Unspecified
# 1  None or Unspecified       NaN          NaN                  NaN
# 2                  NaN       NaN          NaN                  NaN
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN  Hydrostatic                  NaN
#
#   Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower Hydraulics  \
# 0             NaN         NaN            NaN               NaN        NaN
# 1             NaN         NaN            NaN               NaN    2 Valve
# 2             NaN         NaN            NaN               NaN  Auxiliary
# 3             NaN         NaN            NaN               NaN   Standard
# 4             NaN         NaN            NaN               NaN    2 Valve
#
#   Pushblock               Ripper Scarifier Tip_Control Tire_Size  \
# 0       NaN                  NaN       NaN         NaN       NaN
# 1       NaN                  NaN       NaN         NaN      20.5
# 2       NaN                  NaN       NaN         NaN       NaN
# 3       NaN                  NaN       NaN         NaN       NaN
# 4       NaN  None or Unspecified       NaN         NaN       NaN
#
#                Coupler Coupler_System Grouser_Tracks Hydraulics_Flow  \
# 0                  NaN            NaN            NaN             NaN
# 1  None or Unspecified            NaN            NaN             NaN
# 2  None or Unspecified            NaN            NaN             NaN
# 3  None or Unspecified            NaN            NaN             NaN
# 4                  NaN            NaN            NaN             NaN
#
#   Track_Type Undercarriage_Pad_Width         Stick_Length   Thumb  \
# 0        NaN                     NaN                  NaN     NaN
# 1        NaN                     NaN                  NaN     NaN
# 2      Steel     None or Unspecified                9' 6"  Manual
# 3      Steel     None or Unspecified  None or Unspecified  Manual
# 4        NaN                     NaN                  NaN     NaN
#
#        Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0                  NaN          NaN                  NaN        NaN
# 1                  NaN          NaN                  NaN        NaN
# 2  None or Unspecified       Double                  NaN        NaN
# 3                  Yes       Triple                  NaN        NaN
# 4                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  MachineAge
# 0  Standard Digging Depth - Ft          13
# 1                   Horsepower        1012
# 2         Weight - Metric Tons           8
# 3         Weight - Metric Tons           6
# 4                          NaN           7

# %%
# Splitting the Training set in label and features
y_Train = data_new1['SalePrice']

# %%
#Checking
y_Train.shape
# Out:
# (401125,)

# %%
y_Train
# Out:
# 0         66000
# 1         57000
# 2         10000
# 3         38500
# 4         11000
# 5         26500
# 6         21000
# 7         27000
# 8         21500
# 9         65000
# 10        24000
# 11        22500
# 12        36000
# 13        30500
# 14        28000
# 15        19000
# 16        13500
# 17         9500
# 18        12500
# 19        11500
# 20        41000
# 21        34500
# 22        26000
# 23        73000
# 24        33000
# 25        12500
# 26        15500
# 27        53000
# 28        46000
# 29        89000
#           ...
# 401095    10500
# 401096    10000
# 401097     8500
# 401098    10500
# 401099    11000
# 401100    10500
# 401101    10000
# 401102    10500
# 401103    12500
# 401104    10500
# 401105    10000
# 401106    10500
# 401107    12500
# 401108    10500
# 401109    10500
# 401110    10500
# 401111    10000
# 401112    10500
# 401113    10500
# 401114    12500
# 401115    10000
# 401116     8500
# 401117    10000
# 401118     9500
# 401119     8500
# 401120    10500
# 401121    11000
# 401122    11500
# 401123     9000
# 401124     7750
# Name: SalePrice, Length: 401125, dtype: int64

# %%
#data_new1.drop(labels='SalePrice', inplace=True, axis=1)

# %%
x_Train = data_new1

# %%
x_Train.head()
# Out:
#    MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0                      68.0       Low        Rare               D
# 1                    4640.0       Low         950               F
# 2                    2838.0      High        Rare            Rare
# 3                    3486.0      High        Rare            Rare
# 4                     722.0    Medium        Rare            Rare
#
#   fiModelSeries ProductSize           state ProductGroup    ProductGroupDesc  \
# 0          Rare        Rare         Alabama           WL        Wheel Loader
# 1            II      Medium  North Carolina           WL        Wheel Loader
# 2          Rare        Rare        New York          SSL  Skid Steer Loaders
# 3          Rare       Small           Texas          TEX    Track Excavators
# 4          Rare        Rare        New York          SSL  Skid Steer Loaders
#
#   Drive_System   Enclosure                Forks Pad_Type         Ride_Control  \
# 0         Rare  EROPS w AC  None or Unspecified     Rare  None or Unspecified
# 1         Rare  EROPS w AC  None or Unspecified     Rare  None or Unspecified
# 2         Rare       OROPS  None or Unspecified     Rare                 Rare
# 3         Rare  EROPS w AC                 Rare     Rare                 Rare
# 4         Rare       EROPS  None or Unspecified     Rare                 Rare
#
#   Stick Transmission Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  Rare         Rare         Rare            Rare        Rare           Rare
# 1  Rare         Rare         Rare            Rare        Rare           Rare
# 2  Rare         Rare         Rare            Rare        Rare           Rare
# 3  Rare         Rare         Rare            Rare        Rare           Rare
# 4  Rare         Rare         Rare            Rare        Rare           Rare
#
#   Engine_Horsepower Hydraulics Pushblock Ripper Scarifier Tip_Control  \
# 0              Rare    2 Valve      Rare   Rare      Rare        Rare
# 1              Rare    2 Valve      Rare   Rare      Rare        Rare
# 2              Rare  Auxiliary      Rare   Rare      Rare        Rare
# 3              Rare    2 Valve      Rare   Rare      Rare        Rare
# 4              Rare  Auxiliary      Rare   Rare      Rare        Rare
#
#              Tire_Size              Coupler       Coupler_System  \
# 0  None or Unspecified  None or Unspecified                 Rare
# 1                 23.5  None or Unspecified                 Rare
# 2                 Rare  None or Unspecified  None or Unspecified
# 3                 Rare  None or Unspecified                 Rare
# 4                 Rare  None or Unspecified  None or Unspecified
#
#         Grouser_Tracks Hydraulics_Flow Track_Type Undercarriage_Pad_Width  \
# 0                 Rare            Rare       Rare                    Rare
# 1                 Rare            Rare       Rare                    Rare
# 2  None or Unspecified        Standard       Rare                    Rare
# 3                 Rare            Rare       Rare                    Rare
# 4  None or Unspecified        Standard       Rare                    Rare
#
#   Stick_Length Thumb Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0         Rare  Rare            Rare         Rare             Rare       Rare
# 1         Rare  Rare            Rare         Rare             Rare       Rare
# 2         Rare  Rare            Rare         Rare             Rare       Rare
# 3         Rare  Rare            Rare         Rare             Rare       Rare
# 4         Rare  Rare            Rare         Rare             Rare       Rare
#
#   Travel_Controls Differential_Type Steering_Controls  \
# 0            Rare          Standard      Conventional
# 1            Rare          Standard      Conventional
# 2            Rare              Rare              Rare
# 3            Rare              Rare              Rare
# 4            Rare              Rare              Rare
#
#            PrimarySizeBasis  MachineAge
# 0                Horsepower           2
# 1                Horsepower           8
# 2  Operating Capacity - Lbs           3
# 3                      Rare          10
# 4  Operating Capacity - Lbs           2

# %%
x_Test = data_test_mer

# %%
#Checking 
x_Test.head()
# Out:
#    MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0                    3688.0       Low         580               G
# 1                   28555.0      High         936             NaN
# 2                    6038.0    Medium       EC210               B
# 3                    8940.0      High         330               C
# 4                    2286.0       Low         650               K
#
#   fiModelSeries     ProductSize       state ProductGroup     ProductGroupDesc  \
# 0           NaN             NaN     Wyoming           BL      Backhoe Loaders
# 1           NaN          Medium    Virginia           WL         Wheel Loader
# 2           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 3           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 4           NaN             NaN     Florida          TTT  Track Type Tractors
#
#       Drive_System   Enclosure Forks             Pad_Type  \
# 0  Two Wheel Drive       OROPS   Yes  None or Unspecified
# 1              NaN       EROPS   Yes                  NaN
# 2              NaN  EROPS w AC   NaN                  NaN
# 3              NaN  EROPS w AC   NaN                  NaN
# 4              NaN       OROPS   NaN                  NaN
#
#           Ride_Control     Stick Transmission         Turbocharged  \
# 0                   No  Standard     Standard  None or Unspecified
# 1  None or Unspecified       NaN          NaN                  NaN
# 2                  NaN       NaN          NaN                  NaN
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN  Hydrostatic                  NaN
#
#   Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower Hydraulics  \
# 0             NaN         NaN            NaN               NaN        NaN
# 1             NaN         NaN            NaN               NaN    2 Valve
# 2             NaN         NaN            NaN               NaN  Auxiliary
# 3             NaN         NaN            NaN               NaN   Standard
# 4             NaN         NaN            NaN               NaN    2 Valve
#
#   Pushblock               Ripper Scarifier Tip_Control Tire_Size  \
# 0       NaN                  NaN       NaN         NaN       NaN
# 1       NaN                  NaN       NaN         NaN      20.5
# 2       NaN                  NaN       NaN         NaN       NaN
# 3       NaN                  NaN       NaN         NaN       NaN
# 4       NaN  None or Unspecified       NaN         NaN       NaN
#
#                Coupler Coupler_System Grouser_Tracks Hydraulics_Flow  \
# 0                  NaN            NaN            NaN             NaN
# 1  None or Unspecified            NaN            NaN             NaN
# 2  None or Unspecified            NaN            NaN             NaN
# 3  None or Unspecified            NaN            NaN             NaN
# 4                  NaN            NaN            NaN             NaN
#
#   Track_Type Undercarriage_Pad_Width         Stick_Length   Thumb  \
# 0        NaN                     NaN                  NaN     NaN
# 1        NaN                     NaN                  NaN     NaN
# 2      Steel     None or Unspecified                9' 6"  Manual
# 3      Steel     None or Unspecified  None or Unspecified  Manual
# 4        NaN                     NaN                  NaN     NaN
#
#        Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0                  NaN          NaN                  NaN        NaN
# 1                  NaN          NaN                  NaN        NaN
# 2  None or Unspecified       Double                  NaN        NaN
# 3                  Yes       Triple                  NaN        NaN
# 4                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  MachineAge
# 0  Standard Digging Depth - Ft          13
# 1                   Horsepower        1012
# 2         Weight - Metric Tons           8
# 3         Weight - Metric Tons           6
# 4                          NaN           7

# %%
x_Train.shape, x_Test.shape
# Out:
# ((401125, 44), (12457, 44))

# %%
x_Train.dtypes
# Out:
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# ProductSize                  object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# PrimarySizeBasis             object
# MachineAge                    int64
# dtype: object

# %%
x_Train.head()
# Out:
#    MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0                      68.0       Low         521               D
# 1                    4640.0       Low         950               F
# 2                    2838.0      High         226             NaN
# 3                    3486.0      High       PC120             NaN
# 4                     722.0    Medium        S175             NaN
#
#   fiModelSeries ProductSize           state ProductGroup    ProductGroupDesc  \
# 0           NaN         NaN         Alabama           WL        Wheel Loader
# 1            II      Medium  North Carolina           WL        Wheel Loader
# 2           NaN         NaN        New York          SSL  Skid Steer Loaders
# 3           -6E       Small           Texas          TEX    Track Excavators
# 4           NaN         NaN        New York          SSL  Skid Steer Loaders
#
#   Drive_System   Enclosure                Forks Pad_Type         Ride_Control  \
# 0          NaN  EROPS w AC  None or Unspecified      NaN  None or Unspecified
# 1          NaN  EROPS w AC  None or Unspecified      NaN  None or Unspecified
# 2          NaN       OROPS  None or Unspecified      NaN                  NaN
# 3          NaN  EROPS w AC                  NaN      NaN                  NaN
# 4          NaN       EROPS  None or Unspecified      NaN                  NaN
#
#   Stick Transmission Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0   NaN          NaN          NaN             NaN         NaN            NaN
# 1   NaN          NaN          NaN             NaN         NaN            NaN
# 2   NaN          NaN          NaN             NaN         NaN            NaN
# 3   NaN          NaN          NaN             NaN         NaN            NaN
# 4   NaN          NaN          NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock Ripper Scarifier Tip_Control  \
# 0               NaN    2 Valve       NaN    NaN       NaN         NaN
# 1               NaN    2 Valve       NaN    NaN       NaN         NaN
# 2               NaN  Auxiliary       NaN    NaN       NaN         NaN
# 3               NaN    2 Valve       NaN    NaN       NaN         NaN
# 4               NaN  Auxiliary       NaN    NaN       NaN         NaN
#
#              Tire_Size              Coupler       Coupler_System  \
# 0  None or Unspecified  None or Unspecified                  NaN
# 1                 23.5  None or Unspecified                  NaN
# 2                  NaN  None or Unspecified  None or Unspecified
# 3                  NaN  None or Unspecified                  NaN
# 4                  NaN  None or Unspecified  None or Unspecified
#
#         Grouser_Tracks Hydraulics_Flow Track_Type Undercarriage_Pad_Width  \
# 0                  NaN             NaN        NaN                     NaN
# 1                  NaN             NaN        NaN                     NaN
# 2  None or Unspecified        Standard        NaN                     NaN
# 3                  NaN             NaN        NaN                     NaN
# 4  None or Unspecified        Standard        NaN                     NaN
#
#   Stick_Length Thumb Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0          NaN   NaN             NaN          NaN              NaN        NaN
# 1          NaN   NaN             NaN          NaN              NaN        NaN
# 2          NaN   NaN             NaN          NaN              NaN        NaN
# 3          NaN   NaN             NaN          NaN              NaN        NaN
# 4          NaN   NaN             NaN          NaN              NaN        NaN
#
#   Travel_Controls Differential_Type Steering_Controls  \
# 0             NaN          Standard      Conventional
# 1             NaN          Standard      Conventional
# 2             NaN               NaN               NaN
# 3             NaN               NaN               NaN
# 4             NaN               NaN               NaN
#
#            PrimarySizeBasis  MachineAge
# 0                Horsepower           2
# 1                Horsepower           8
# 2  Operating Capacity - Lbs           3
# 3                       NaN          10
# 4  Operating Capacity - Lbs           2

# %%
x_Test.head()
# Out:
#    MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0                    3688.0       Low         580               G
# 1                   28555.0      High         936             NaN
# 2                    6038.0    Medium       EC210               B
# 3                    8940.0      High         330               C
# 4                    2286.0       Low         650               K
#
#   fiModelSeries     ProductSize       state ProductGroup     ProductGroupDesc  \
# 0           NaN             NaN     Wyoming           BL      Backhoe Loaders
# 1           NaN          Medium    Virginia           WL         Wheel Loader
# 2           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 3           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 4           NaN             NaN     Florida          TTT  Track Type Tractors
#
#       Drive_System   Enclosure Forks             Pad_Type  \
# 0  Two Wheel Drive       OROPS   Yes  None or Unspecified
# 1              NaN       EROPS   Yes                  NaN
# 2              NaN  EROPS w AC   NaN                  NaN
# 3              NaN  EROPS w AC   NaN                  NaN
# 4              NaN       OROPS   NaN                  NaN
#
#           Ride_Control     Stick Transmission         Turbocharged  \
# 0                   No  Standard     Standard  None or Unspecified
# 1  None or Unspecified       NaN          NaN                  NaN
# 2                  NaN       NaN          NaN                  NaN
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN  Hydrostatic                  NaN
#
#   Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower Hydraulics  \
# 0             NaN         NaN            NaN               NaN        NaN
# 1             NaN         NaN            NaN               NaN    2 Valve
# 2             NaN         NaN            NaN               NaN  Auxiliary
# 3             NaN         NaN            NaN               NaN   Standard
# 4             NaN         NaN            NaN               NaN    2 Valve
#
#   Pushblock               Ripper Scarifier Tip_Control Tire_Size  \
# 0       NaN                  NaN       NaN         NaN       NaN
# 1       NaN                  NaN       NaN         NaN      20.5
# 2       NaN                  NaN       NaN         NaN       NaN
# 3       NaN                  NaN       NaN         NaN       NaN
# 4       NaN  None or Unspecified       NaN         NaN       NaN
#
#                Coupler Coupler_System Grouser_Tracks Hydraulics_Flow  \
# 0                  NaN            NaN            NaN             NaN
# 1  None or Unspecified            NaN            NaN             NaN
# 2  None or Unspecified            NaN            NaN             NaN
# 3  None or Unspecified            NaN            NaN             NaN
# 4                  NaN            NaN            NaN             NaN
#
#   Track_Type Undercarriage_Pad_Width         Stick_Length   Thumb  \
# 0        NaN                     NaN                  NaN     NaN
# 1        NaN                     NaN                  NaN     NaN
# 2      Steel     None or Unspecified                9' 6"  Manual
# 3      Steel     None or Unspecified  None or Unspecified  Manual
# 4        NaN                     NaN                  NaN     NaN
#
#        Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0                  NaN          NaN                  NaN        NaN
# 1                  NaN          NaN                  NaN        NaN
# 2  None or Unspecified       Double                  NaN        NaN
# 3                  Yes       Triple                  NaN        NaN
# 4                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  MachineAge
# 0  Standard Digging Depth - Ft          13
# 1                   Horsepower        1012
# 2         Weight - Metric Tons           8
# 3         Weight - Metric Tons           6
# 4                          NaN           7

# %%
x_Train.shape, x_Test.shape
# Out:
# ((401125, 45), (12457, 44))

# %%
x_Train.dtypes
# Out:
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# ProductSize                  object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# fiManufacturerDesc           object
# PrimarySizeBasis             object
# MachineAge                    int64
# dtype: object

# %%
x_Test.dtypes
# Out:
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# ProductSize                  object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# fiManufacturerDesc           object
# PrimarySizeBasis             object
# MachineAge                    int64
# dtype: object

# %%
# find categorical variables in the Training set
categorical_train = [var for var in x_Train.columns if x_Train[var].dtype=='O']
print('There are {} categorical variables in the Training set'.format(len(categorical_train)))
# Out:
# There are 42 categorical variables in the Training set

# %%
# find numerical variables
numerical_train = [var for var in x_Train.columns if x_Train[var].dtype!='O']
print('There are {} numerical variables in the Training set'.format(len(numerical_train)))
# Out:
# There are 3 numerical variables in the Training set

# %%
# find categorical variables in the Test set
categorical_test = [var for var in x_Test.columns if x_Test[var].dtype=='O']
print('There are {} categorical variables in the Test set'.format(len(categorical_test)))
# Out:
# There are 42 categorical variables in the Test set

# %%
# find numerical variables in the Test set
numerical_test = [var for var in x_Test.columns if x_Test[var].dtype!='O']
print('There are {} numerical variables in the Test set'.format(len(numerical_test)))
# Out:
# There are 2 numerical variables in the Test set

# %% [markdown]
# ## Outliers

# %%
#continuous_train = [var for var in numerical_train]
#continuous_train

# %%
continuous_train = [var for var in numerical_train if var not in [ 'SalePrice']]
continuous_train
# Out:
# ['MachineHoursCurrentMeter', 'MachineAge']

# %%
continuous_test = [var for var in numerical_test]
continuous_test
# Out:
# ['MachineHoursCurrentMeter', 'MachineAge']

# %%
# let's make boxplots to visualise outliers in the continuous variables 
# and histograms to get an idea of the distribution in the Training set

for var in continuous_train:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = x_Train.boxplot(column=var)
    fig.set_title('')
    fig.set_ylabel(var)
    
    plt.subplot(1, 2, 2)
    fig = x_Train[var].hist(bins=20)
    fig.set_ylabel('Number of Buldozers')
    fig.set_xlabel(var)

    plt.show()

# %%
# let's make boxplots to visualise outliers in the continuous variables 
# and histograms to get an idea of the distribution in the Test set

for var in continuous_test:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = x_Test.boxplot(column=var)
    fig.set_title('')
    fig.set_ylabel(var)
    
    plt.subplot(1, 2, 2)
    fig = x_Test[var].hist(bins=20)
    fig.set_ylabel('Number of Buldozers')
    fig.set_xlabel(var)

    plt.show()

# %%
x_Train.MachineAge
# Out:
# 0            2
# 1            8
# 2            3
# 3           10
# 4            2
# 5            4
# 6           11
# 7            4
# 8            1
# 9         1007
# 10           4
# 11           8
# 12           7
# 13           5
# 14           2
# 15           7
# 16           8
# 17           7
# 18           5
# 19          14
# 20           6
# 21        1006
# 22           2
# 23          10
# 24           3
# 25           3
# 26           3
# 27           7
# 28           3
# 29           8
#           ...
# 401095       8
# 401096       7
# 401097       6
# 401098       7
# 401099       7
# 401100       7
# 401101       7
# 401102       6
# 401103       6
# 401104       6
# 401105       6
# 401106       6
# 401107       6
# 401108       6
# 401109       6
# 401110       6
# 401111       6
# 401112       6
# 401113       6
# 401114       6
# 401115       6
# 401116       6
# 401117       6
# 401118       5
# 401119       6
# 401120       6
# 401121       6
# 401122       6
# 401123       6
# 401124       6
# Name: MachineAge, Length: 401125, dtype: int64

# %% [markdown]
# All of the continuous variables seem to contain outliers. In addition, the variables are not normally distributed. If we are planning to build linear regression, we might need to tackle these to improve the model performance. To tackle the 2 aspects together, I will do discretisation. And in particular, **I will use trees to find the right buckets onto which I will divide the variables.**

# %% [markdown]
# Note: there exist no discrete variables in the datasets.
#
#
# #### Number of labels: cardinality

# %%
# Examining the number of labels for the categorical variables in the Training set
for var in categorical_train:
    print(var, ' contains ', len(x_Train[var].unique()), ' labels')
# Out:
# UsageBand  contains  4  labels
# fiBaseModel  contains  1950  labels
# fiSecondaryDesc  contains  176  labels
# fiModelSeries  contains  129  labels
# ProductSize  contains  7  labels
# state  contains  53  labels
# ProductGroup  contains  6  labels
# ProductGroupDesc  contains  6  labels
# Drive_System  contains  5  labels
# Enclosure  contains  7  labels
# Forks  contains  3  labels
# Pad_Type  contains  5  labels
# Ride_Control  contains  4  labels
# Stick  contains  3  labels
# Transmission  contains  9  labels
# Turbocharged  contains  3  labels
# Blade_Extension  contains  3  labels
# Blade_Width  contains  7  labels
# Enclosure_Type  contains  4  labels
# Engine_Horsepower  contains  3  labels
# Hydraulics  contains  13  labels
# Pushblock  contains  3  labels
# Ripper  contains  5  labels
# Scarifier  contains  3  labels
# Tip_Control  contains  4  labels
# Tire_Size  contains  18  labels
# Coupler  contains  4  labels
# Coupler_System  contains  3  labels
# Grouser_Tracks  contains  3  labels
# Hydraulics_Flow  contains  4  labels
# Track_Type  contains  3  labels
# Undercarriage_Pad_Width  contains  20  labels
# Stick_Length  contains  30  labels
# Thumb  contains  4  labels
# Pattern_Changer  contains  4  labels
# Grouser_Type  contains  4  labels
# Backhoe_Mounting  contains  3  labels
# Blade_Type  contains  11  labels
# Travel_Controls  contains  8  labels
# Differential_Type  contains  5  labels
# Steering_Controls  contains  6  labels
# PrimarySizeBasis  contains  5  labels

# %%
# Examining the number of labels for the categorical variables in the Test set
for var in categorical_test:
    print(var, ' contains ', len(x_Test[var].unique()), ' labels')
# Out:
# UsageBand  contains  4  labels
# fiBaseModel  contains  831  labels
# fiSecondaryDesc  contains  83  labels
# fiModelSeries  contains  64  labels
# ProductSize  contains  7  labels
# state  contains  51  labels
# ProductGroup  contains  6  labels
# ProductGroupDesc  contains  6  labels
# Drive_System  contains  5  labels
# Enclosure  contains  4  labels
# Forks  contains  3  labels
# Pad_Type  contains  5  labels
# Ride_Control  contains  4  labels
# Stick  contains  3  labels
# Transmission  contains  8  labels
# Turbocharged  contains  3  labels
# Blade_Extension  contains  3  labels
# Blade_Width  contains  7  labels
# Enclosure_Type  contains  4  labels
# Engine_Horsepower  contains  3  labels
# Hydraulics  contains  12  labels
# Pushblock  contains  3  labels
# Ripper  contains  5  labels
# Scarifier  contains  3  labels
# Tip_Control  contains  4  labels
# Tire_Size  contains  14  labels
# Coupler  contains  4  labels
# Coupler_System  contains  3  labels
# Grouser_Tracks  contains  3  labels
# Hydraulics_Flow  contains  4  labels
# Track_Type  contains  3  labels
# Undercarriage_Pad_Width  contains  18  labels
# Stick_Length  contains  21  labels
# Thumb  contains  4  labels
# Pattern_Changer  contains  3  labels
# Grouser_Type  contains  3  labels
# Backhoe_Mounting  contains  2  labels
# Blade_Type  contains  9  labels
# Travel_Controls  contains  7  labels
# Differential_Type  contains  4  labels
# Steering_Controls  contains  4  labels
# PrimarySizeBasis  contains  5  labels

# %% [markdown]
# Most of the variables have variables do not have a lot of labels, but some have very high levels of cardinality.

# %% [markdown]
# ### Engineering missing values in numerical variables (section 5)
# #### Continuous variables

# %%
# print variables with missing data in Training set
for col in continuous_train:
    if x_Train[col].isnull().mean()>0:
        print(col, x_Train[col].isnull().mean())
# Out:
# MachineHoursCurrentMeter 0.644088501091

# %%
# print variables with missing data in Test set
for col in continuous_test:
    if x_Test[col].isnull().mean()>0:
        print(col, x_Test[col].isnull().mean())
# Out:
# MachineHoursCurrentMeter 0.829092076744

# %% [markdown]
# - If a variable contains < 50% NA: create additional variable with NA + random sample imputation
# - If a variable contains > 50% NA: impute NA by value far in the distribution

# %%
#def impute_na(x_Train, df, variable):
    # make temporary df copy
#    temp = df.copy()
    
    # extract random from train set to fill the na
#    random_sample = x_Train[variable].dropna().sample(temp[variable].isnull().sum(), random_state=0)
    
    # pandas needs to have the same index in order to merge datasets
#    random_sample.index = temp[temp[variable].isnull()].index
#    temp.loc[temp[variable].isnull(), variable] = random_sample
#    return temp[variable]

# %%
# add variable indicating missingness
#for df in [x_Train, x_Test,]:
#    for var in ['Age', 'Ticket_numerical']:
#        df[var+'_NA'] = np.where(df[var].isnull(), 1, 0)
#    
# replace by random sampling
#for df in [x_Train, x_Test]:
#    for var in ['Age', 'Ticket_numerical']:
#        df[var] = impute_na(x_Train, df, var)

# %%
# MachineHoursCurrentMeter 
extreme = x_Train.MachineHoursCurrentMeter.mean() + x_Train.MachineHoursCurrentMeter.std()*3
for df in [x_Train, x_Test]:
    df.MachineHoursCurrentMeter.fillna(extreme, inplace=True)

# %% [markdown]
# ### Engineering Missing Data in categorical variables

# %%
# print variables with missing data in Training set
for col in categorical_train:
    if x_Train[col].isnull().mean()>0:
        print(col, x_Train[col].isnull().mean())
# Out:
# UsageBand 0.826390775943
# fiSecondaryDesc 0.342015581178
# fiModelSeries 0.858129012153
# ProductSize 0.525459644749
# Drive_System 0.73982923029
# Enclosure 0.000810221252727
# Forks 0.521154253662
# Pad_Type 0.802719850421
# Ride_Control 0.629526955438
# Stick 0.802719850421
# Transmission 0.543209722655
# Turbocharged 0.802719850421
# Blade_Extension 0.937129323777
# Blade_Width 0.937129323777
# Enclosure_Type 0.937129323777
# Engine_Horsepower 0.937129323777
# Hydraulics 0.200822686195
# Pushblock 0.937129323777
# Ripper 0.740387659707
# Scarifier 0.937101900904
# Tip_Control 0.937129323777
# Tire_Size 0.763869118105
# Coupler 0.466620130882
# Coupler_System 0.891659707074
# Grouser_Tracks 0.891899033967
# Hydraulics_Flow 0.891899033967
# Track_Type 0.752812714241
# Undercarriage_Pad_Width 0.751020255531
# Stick_Length 0.752650669991
# Thumb 0.752476160798
# Pattern_Changer 0.752650669991
# Grouser_Type 0.752812714241
# Backhoe_Mounting 0.803871611094
# Blade_Type 0.80097725148
# Travel_Controls 0.800974758492
# Differential_Type 0.826959177314
# Steering_Controls 0.82706388283
# PrimarySizeBasis 0.0710426924275

# %% [markdown]
# - If a variable has low NA then NA imputed by most frequent category
# - If a variable has high NA imputed by 'Missing'

# %%
x_Train2 = x_Train

# %%
x_Test2 =x_Test

# %%
# print variables with missing data in Training set
for col in categorical_train:
    if x_Train2[col].isnull().mean()>0:
        print(col, x_Train2[col].isnull().mean())
# Out:
# UsageBand 0.826390775943
# fiSecondaryDesc 0.342015581178
# fiModelSeries 0.858129012153
# ProductSize 0.525459644749
# Drive_System 0.73982923029
# Enclosure 0.000810221252727
# Forks 0.521154253662
# Pad_Type 0.802719850421
# Ride_Control 0.629526955438
# Stick 0.802719850421
# Transmission 0.543209722655
# Turbocharged 0.802719850421
# Blade_Extension 0.937129323777
# Blade_Width 0.937129323777
# Enclosure_Type 0.937129323777
# Engine_Horsepower 0.937129323777
# Hydraulics 0.200822686195
# Pushblock 0.937129323777
# Ripper 0.740387659707
# Scarifier 0.937101900904
# Tip_Control 0.937129323777
# Tire_Size 0.763869118105
# Coupler 0.466620130882
# Coupler_System 0.891659707074
# Grouser_Tracks 0.891899033967
# Hydraulics_Flow 0.891899033967
# Track_Type 0.752812714241
# Undercarriage_Pad_Width 0.751020255531
# Stick_Length 0.752650669991
# Thumb 0.752476160798
# Pattern_Changer 0.752650669991
# Grouser_Type 0.752812714241
# Backhoe_Mounting 0.803871611094
# Blade_Type 0.80097725148
# Travel_Controls 0.800974758492
# Differential_Type 0.826959177314
# Steering_Controls 0.82706388283
# PrimarySizeBasis 0.0710426924275

# %%
# print variables with missing data in Training set
for col in categorical_train:
    if x_Train2[col].isnull().mean()<.08:
        for df in [x_Train2, x_Test2]:
            df[col].fillna(x_Train2[col].mode()[0], inplace=True) 
    else:
        for df in [x_Train2, x_Test2]:
            df[col].fillna('Missing', inplace=True)

# %%
## print variables with missing data in Training set
#for col in categorical_train:
#    if x_Train1[col].isnull().mean()>.08:
#        for df in [x_Train1, x_Test1]:
#            df[col].fillna('Missing', inplace=True)

# %%
# check absence of null values
x_Train2.isnull().sum()
# Out:
# SalePrice                   0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# ProductSize                 0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# PrimarySizeBasis            0
# MachineAge                  0
# dtype: int64

# %%
x_Train.isnull().sum()
# Out:
# MachineHoursCurrentMeter    0
# UsageBand                   0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# ProductSize                 0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# PrimarySizeBasis            0
# MachineAge                  0
# dtype: int64

# %%
x_Train2.head()
# Out:
#    MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0                      68.0       Low         521               D
# 1                    4640.0       Low         950               F
# 2                    2838.0      High         226         Missing
# 3                    3486.0      High       PC120         Missing
# 4                     722.0    Medium        S175         Missing
#
#   fiModelSeries ProductSize           state ProductGroup    ProductGroupDesc  \
# 0       Missing     Missing         Alabama           WL        Wheel Loader
# 1            II      Medium  North Carolina           WL        Wheel Loader
# 2       Missing     Missing        New York          SSL  Skid Steer Loaders
# 3           -6E       Small           Texas          TEX    Track Excavators
# 4       Missing     Missing        New York          SSL  Skid Steer Loaders
#
#   Drive_System   Enclosure                Forks Pad_Type         Ride_Control  \
# 0      Missing  EROPS w AC  None or Unspecified  Missing  None or Unspecified
# 1      Missing  EROPS w AC  None or Unspecified  Missing  None or Unspecified
# 2      Missing       OROPS  None or Unspecified  Missing              Missing
# 3      Missing  EROPS w AC              Missing  Missing              Missing
# 4      Missing       EROPS  None or Unspecified  Missing              Missing
#
#      Stick Transmission Turbocharged Blade_Extension Blade_Width  \
# 0  Missing      Missing      Missing         Missing     Missing
# 1  Missing      Missing      Missing         Missing     Missing
# 2  Missing      Missing      Missing         Missing     Missing
# 3  Missing      Missing      Missing         Missing     Missing
# 4  Missing      Missing      Missing         Missing     Missing
#
#   Enclosure_Type Engine_Horsepower Hydraulics Pushblock   Ripper Scarifier  \
# 0        Missing           Missing    2 Valve   Missing  Missing   Missing
# 1        Missing           Missing    2 Valve   Missing  Missing   Missing
# 2        Missing           Missing  Auxiliary   Missing  Missing   Missing
# 3        Missing           Missing    2 Valve   Missing  Missing   Missing
# 4        Missing           Missing  Auxiliary   Missing  Missing   Missing
#
#   Tip_Control            Tire_Size              Coupler       Coupler_System  \
# 0     Missing  None or Unspecified  None or Unspecified              Missing
# 1     Missing                 23.5  None or Unspecified              Missing
# 2     Missing              Missing  None or Unspecified  None or Unspecified
# 3     Missing              Missing  None or Unspecified              Missing
# 4     Missing              Missing  None or Unspecified  None or Unspecified
#
#         Grouser_Tracks Hydraulics_Flow Track_Type Undercarriage_Pad_Width  \
# 0              Missing         Missing    Missing                 Missing
# 1              Missing         Missing    Missing                 Missing
# 2  None or Unspecified        Standard    Missing                 Missing
# 3              Missing         Missing    Missing                 Missing
# 4  None or Unspecified        Standard    Missing                 Missing
#
#   Stick_Length    Thumb Pattern_Changer Grouser_Type Backhoe_Mounting  \
# 0      Missing  Missing         Missing      Missing          Missing
# 1      Missing  Missing         Missing      Missing          Missing
# 2      Missing  Missing         Missing      Missing          Missing
# 3      Missing  Missing         Missing      Missing          Missing
# 4      Missing  Missing         Missing      Missing          Missing
#
#   Blade_Type Travel_Controls Differential_Type Steering_Controls  \
# 0    Missing         Missing          Standard      Conventional
# 1    Missing         Missing          Standard      Conventional
# 2    Missing         Missing           Missing           Missing
# 3    Missing         Missing           Missing           Missing
# 4    Missing         Missing           Missing           Missing
#
#            PrimarySizeBasis  MachineAge
# 0                Horsepower           2
# 1                Horsepower           8
# 2  Operating Capacity - Lbs           3
# 3                Horsepower          10
# 4  Operating Capacity - Lbs           2

# %%
x_Train2.fiModelSeries.unique()
# Out:
# array(['Missing', 'II', '-6E', 'LC', '-5', 'III', '-1', '5', '-2', '1',
#        '#NAME?', '-3L', '-20', '3', '15', '-12', '6', '-6', 'V', '-3',
#        '-3PT', '-21', '-7', '7', '-3MC', 'IV', '-21A', '-3LC', '-5L', '5N',
#        '-5H', '-1L', '-8', '4', '2', '-18', '-15', '2T', '18', 'E', '-3C',
#        '-6B', '7.00E+00', 'A', '-3LK', 'ZTS', '-2N', '12', 'V-2', 'XT',
#        '-7E', '-2C', '-8E', '-6LC', '-3H', '16', 'IV-2', '-6K', '6F', '22',
#        '3A', 'VHP', 'LGP', 'LT', '14FT', 'EX', '-6C', '3C', '-7K', '17',
#        '1970', '-2LC', 'M', 'D', 'ZX', 'LV', '-5LC', '-5E', '6.00E+00',
#        '-17', '-16', '-4', '8', '-7B', '-1C', '-11', 'L', '-6A', 'LL',
#        -5.0, -2.0, -8.0, -3.0, -7.0, 2.0, 'G', 'WX', '-2A', '-5F', '-3M',
#        'D7', '7A', ' III', 'AWS', '2B', '20', '-5A', '-6LK', '-2E', 'VI',
#        'H', '-1B', '-3EO', 'TC', 'Elite', 'WT', 'XLT', 'SeriesII',
#        '-1.50E+01', 'GALEO', '6L', '6LE', '6LK', '21KomStatII',
#        '21KomStat', '7L', 'Q', 'ZHS', 'FASTRRACK'], dtype=object)

# %%
#data1.groupby(['fiModelSeries'])['SalesID'].count()
x_Train2['fiModelSeries'].value_counts()
# Out:
# Missing        344217
# II              13202
# LC               8936
# III              5238
# -1               4591
# -2               3340
# -6               3161
# -3               2462
# -5               2434
# -12              1365
# -7                907
# 6                 749
# 7                 685
# -21               619
# IV                618
# -8                618
# -2.0              612
# 5                 540
# 3                 536
# -3LC              463
# -20               431
# 18                415
# V                 398
# #NAME?            396
# 2                 342
# -15               327
# -3MC              322
# -5L               281
# -18               238
# -17               233
#                 ...
# -6LK                2
# -2E                 2
# XLT                 2
# 21KomStatII         2
# EX                  2
# 21KomStat           2
# -2A                 2
# 7L                  1
# -5F                 1
# -1B                 1
# LGP                 1
# -5.0                1
# -7.0                1
# Q                   1
#  III                1
# LL                  1
# -3M                 1
# ZHS                 1
# 6F                  1
# 1970                1
# 3A                  1
# FASTRRACK           1
# Elite               1
# H                   1
# VI                  1
# -2LC                1
# 14FT                1
# -5A                 1
# 6L                  1
# WT                  1
# Name: fiModelSeries, Length: 129, dtype: int64

# %%
#x_Train2['fiModelSeries'].value_counts()/np.float(len(x_Train2))
print(x_Train2['fiModelSeries'].value_counts()/np.float(len(x_Train2)))
    #print()
# Out:
# Missing        0.858129
# II             0.032912
# LC             0.022277
# III            0.013058
# -1             0.011445
# -2             0.008327
# -6             0.007880
# -3             0.006138
# -5             0.006068
# -12            0.003403
# -7             0.002261
# 6              0.001867
# 7              0.001708
# -21            0.001543
# IV             0.001541
# -8             0.001541
# -2.0           0.001526
# 5              0.001346
# 3              0.001336
# -3LC           0.001154
# -20            0.001074
# 18             0.001035
# V              0.000992
# #NAME?         0.000987
# 2              0.000853
# -15            0.000815
# -3MC           0.000803
# -5L            0.000701
# -18            0.000593
# -17            0.000581
#                  ...
# -6LK           0.000005
# -2E            0.000005
# XLT            0.000005
# 21KomStatII    0.000005
# EX             0.000005
# 21KomStat      0.000005
# -2A            0.000005
# 7L             0.000002
# -5F            0.000002
# -1B            0.000002
# LGP            0.000002
# -5.0           0.000002
# -7.0           0.000002
# Q              0.000002
#  III           0.000002
# LL             0.000002
# -3M            0.000002
# ZHS            0.000002
# 6F             0.000002
# 1970           0.000002
# 3A             0.000002
# FASTRRACK      0.000002
# Elite          0.000002
# H              0.000002
# VI             0.000002
# -2LC           0.000002
# 14FT           0.000002
# -5A            0.000002
# 6L             0.000002
# WT             0.000002
# Name: fiModelSeries, Length: 129, dtype: float64

# %% [markdown]
# ## Imputation - Rare - Test and Training Set

# %%
def rare_imputation(variable, which='rare'):    
    # find frequent labels
    temp = x_Train2.groupby([variable])[variable].count()/np.float(len(x_Train2))
    frequent_cat = [x for x in temp.loc[temp>0.012].index.values]
    
    # create new variables, with Rare labels imputed
    x_Train2[variable] = np.where(x_Train2[variable].isin(frequent_cat), x_Train2[variable], 'Rare')
    x_Test2[variable] = np.where(x_Test2[variable].isin(frequent_cat), x_Test2[variable], 'Rare')

# %%
#rare_imputation('fiModelSeries', 'rare')

# %%
# Checking result of imputation
print(x_Train2['fiModelSeries'].value_counts()/np.float(len(x_Train2)))
# Out:
# Missing    0.858129
# Rare       0.073623
# II         0.032912
# LC         0.022277
# III        0.013058
# Name: fiModelSeries, dtype: float64

# %%
#Imputing "rare" for rare labels
for col in categorical_train:
    rare_imputation(col, 'rare')

# %%
# Checking result of imputation
for col in categorical_train:
    print(x_Train2[col].value_counts()/np.float(len(x_Train2)))
# Out:
# Missing    0.826391
# Medium     0.084724
# Low        0.058884
# High       0.030001
# Name: UsageBand, dtype: float64
# Rare    0.693365
# 580     0.049356
# 310     0.043263
# D6      0.032683
# 416     0.031629
# D5      0.023289
# 950     0.018463
# D3      0.017017
# D8      0.016785
# D4      0.016115
# 12      0.015314
# 140     0.014482
# 966     0.014454
# 320     0.013784
# Name: fiBaseModel, dtype: float64
# Missing    0.342016
# Rare       0.118193
# C          0.107784
# B          0.097733
# G          0.090805
# H          0.059956
# E          0.052472
# D          0.048506
# F          0.022818
# K          0.019393
# L          0.013731
# A          0.013721
# M          0.012871
# Name: fiSecondaryDesc, dtype: float64
# Missing    0.858129
# Rare       0.073623
# II         0.032912
# LC         0.022277
# III        0.013058
# Name: fiModelSeries, dtype: float64
# Missing           0.525460
# Medium            0.155248
# Large / Medium    0.123847
# Small             0.066049
# Mini              0.061926
# Large             0.052290
# Compact           0.015180
# Name: ProductSize, dtype: float64
# Florida           0.159412
# Texas             0.128843
# Rare              0.100906
# California        0.072344
# Washington        0.039776
# Georgia           0.035672
# Maryland          0.032322
# Mississippi       0.032312
# Ohio              0.030390
# Colorado          0.028056
# Illinois          0.027944
# New Jersey        0.027129
# North Carolina    0.025937
# Tennessee         0.024997
# Alabama           0.024922
# Pennsylvania      0.024783
# South Carolina    0.024416
# Arizona           0.022868
# New York          0.021450
# Connecticut       0.020263
# Minnesota         0.019281
# Missouri          0.017354
# Nevada            0.016686
# Louisiana         0.016080
# Kentucky          0.013158
# Maine             0.012702
# Name: state, dtype: float64
# TEX    0.252208
# TTT    0.200735
# BL     0.197981
# WL     0.177117
# SSL    0.108415
# MG     0.063544
# Name: ProductGroup, dtype: float64
# Track Excavators       0.252208
# Track Type Tractors    0.200735
# Backhoe Loaders        0.197981
# Wheel Loader           0.177117
# Skid Steer Loaders     0.108415
# Motor Graders          0.063544
# Name: ProductGroupDesc, dtype: float64
# Missing             0.739829
# Two Wheel Drive     0.115024
# Four Wheel Drive    0.082259
# No                  0.060899
# Rare                0.001989
# Name: Drive_System, dtype: float64
# OROPS         0.434421
# EROPS         0.346590
# EROPS w AC    0.218934
# Rare          0.000055
# Name: Enclosure, dtype: float64
# Missing                0.521154
# None or Unspecified    0.444500
# Yes                    0.034346
# Name: Forks, dtype: float64
# Missing                0.802720
# None or Unspecified    0.176040
# Reversible             0.014539
# Rare                   0.006701
# Name: Pad_Type, dtype: float64
# Missing                0.629527
# No                     0.193668
# None or Unspecified    0.157347
# Yes                    0.019458
# Name: Ride_Control, dtype: float64
# Missing     0.80272
# Standard    0.12173
# Extended    0.07555
# Name: Stick, dtype: float64
# Missing                0.543210
# Standard               0.349836
# None or Unspecified    0.057705
# Powershift             0.029245
# Rare                   0.020004
# Name: Transmission, dtype: float64
# Missing                0.80272
# None or Unspecified    0.18750
# Rare                   0.00978
# Name: Turbocharged, dtype: float64
# Missing                0.937129
# None or Unspecified    0.061557
# Rare                   0.001314
# Name: Blade_Extension, dtype: float64
# Missing                0.937129
# 14'                    0.023970
# None or Unspecified    0.023142
# 12'                    0.012385
# Rare                   0.003373
# Name: Blade_Width, dtype: float64
# Missing                0.937129
# None or Unspecified    0.054654
# Rare                   0.008217
# Name: Enclosure_Type, dtype: float64
# Missing    0.937129
# No         0.059675
# Rare       0.003196
# Name: Engine_Horsepower, dtype: float64
# 2 Valve              0.352519
# Standard             0.260325
# Missing              0.200823
# Auxiliary            0.101557
# Base + 1 Function    0.061751
# 3 Valve              0.014016
# Rare                 0.009010
# Name: Hydraulics, dtype: float64
# Missing                0.937129
# None or Unspecified    0.048521
# Yes                    0.014350
# Name: Pushblock, dtype: float64
# Missing                0.740388
# None or Unspecified    0.208045
# Yes                    0.019700
# Multi Shank            0.019029
# Single Shank           0.012839
# Name: Ripper, dtype: float64
# Missing                0.937102
# None or Unspecified    0.031708
# Yes                    0.031190
# Name: Scarifier, dtype: float64
# Missing                0.937129
# None or Unspecified    0.040404
# Sideshift & Tip        0.017625
# Rare                   0.004841
# Name: Tip_Control, dtype: float64
# Missing                0.763869
# None or Unspecified    0.115523
# Rare                   0.039499
# 20.5                   0.037998
# 14"                    0.021971
# 23.5                   0.021141
# Name: Tire_Size, dtype: float64
# Missing                0.466620
# None or Unspecified    0.460161
# Manual                 0.058089
# Hydraulic              0.015130
# Name: Coupler, dtype: float64
# Missing                0.891660
# None or Unspecified    0.100792
# Rare                   0.007549
# Name: Coupler_System, dtype: float64
# Missing                0.891899
# None or Unspecified    0.101003
# Rare                   0.007098
# Name: Grouser_Tracks, dtype: float64
# Missing     0.891899
# Standard    0.106660
# Rare        0.001441
# Name: Hydraulics_Flow, dtype: float64
# Missing    0.752813
# Steel      0.211605
# Rubber     0.035582
# Name: Track_Type, dtype: float64
# Missing                0.751020
# None or Unspecified    0.198569
# Rare                   0.037415
# 32 inch                0.012996
# Name: Undercarriage_Pad_Width, dtype: float64
# Missing                0.752651
# None or Unspecified    0.196497
# Rare                   0.036480
# 9' 6"                  0.014372
# Name: Stick_Length, dtype: float64
# Missing                0.752476
# None or Unspecified    0.207150
# Manual                 0.023329
# Hydraulic              0.017045
# Name: Thumb, dtype: float64
# Missing                0.752651
# None or Unspecified    0.225005
# Yes                    0.022183
# Rare                   0.000162
# Name: Pattern_Changer, dtype: float64
# Missing    0.752813
# Double     0.211039
# Triple     0.036143
# Rare       0.000005
# Name: Grouser_Type, dtype: float64
# Missing                0.803872
# None or Unspecified    0.196079
# Rare                   0.000050
# Name: Backhoe_Mounting, dtype: float64
# Missing                0.800977
# PAT                    0.096259
# Straight               0.033214
# None or Unspecified    0.028497
# Semi U                 0.021482
# Rare                   0.019570
# Name: Blade_Type, dtype: float64
# Missing                0.800975
# None or Unspecified    0.174317
# Rare                   0.012545
# Differential Steer     0.012163
# Name: Travel_Controls, dtype: float64
# Missing     0.826959
# Standard    0.169705
# Rare        0.003336
# Name: Differential_Type, dtype: float64
# Missing         0.827064
# Conventional    0.171216
# Rare            0.001720
# Name: Steering_Controls, dtype: float64
# Horsepower                     0.483632
# Weight - Metric Tons           0.226214
# Standard Digging Depth - Ft    0.185426
# Operating Capacity - Lbs       0.104728
# Name: PrimarySizeBasis, dtype: float64

# %%
# Checking result of imputation - Test set
for col in categorical_train:
    print(x_Test2[col].value_counts()/np.float(len(x_Test2)))
# Out:
# Missing    0.852774
# Medium     0.066308
# Low        0.065104
# High       0.015814
# Name: UsageBand, dtype: float64
# Rare    0.754596
# 310     0.041583
# 580     0.037569
# D6      0.033074
# D5      0.022477
# 416     0.019025
# 320     0.014851
# 950     0.013165
# 140     0.012603
# D4      0.012041
# D8      0.011399
# 12      0.010918
# 966     0.009633
# D3      0.007064
# Name: fiBaseModel, dtype: float64
# Missing    0.319098
# Rare       0.158947
# G          0.114955
# C          0.107169
# B          0.081962
# D          0.056996
# H          0.048246
# E          0.039656
# M          0.024324
# F          0.019025
# K          0.014771
# L          0.007626
# A          0.007225
# Name: fiSecondaryDesc, dtype: float64
# Missing    0.838966
# Rare       0.084691
# II         0.042466
# LC         0.023922
# III        0.009954
# Name: fiModelSeries, dtype: float64
# Missing           0.514490
# Medium            0.162961
# Large / Medium    0.136068
# Mini              0.080035
# Small             0.058120
# Large             0.035643
# Compact           0.012684
# Name: ProductSize, dtype: float64
# Texas             0.172754
# Rare              0.149394
# Florida           0.088223
# California        0.069840
# Georgia           0.045195
# Maryland          0.044312
# Illinois          0.037650
# Tennessee         0.033154
# North Carolina    0.032993
# Washington        0.032191
# Arizona           0.029943
# Missouri          0.026973
# Louisiana         0.026652
# Pennsylvania      0.026331
# Ohio              0.023842
# Colorado          0.021755
# New Jersey        0.019908
# Nevada            0.019587
# Mississippi       0.019507
# New York          0.018223
# Connecticut       0.018062
# Kentucky          0.014048
# Alabama           0.013406
# Minnesota         0.009874
# South Carolina    0.005379
# Maine             0.000803
# Name: state, dtype: float64
# TEX    0.274304
# WL     0.171791
# BL     0.170105
# SSL    0.165931
# TTT    0.165529
# MG     0.052340
# Name: ProductGroup, dtype: float64
# Track Excavators       0.274304
# Wheel Loader           0.171791
# Backhoe Loaders        0.170105
# Skid Steer Loaders     0.165931
# Track Type Tractors    0.165529
# Motor Graders          0.052340
# Name: ProductGroupDesc, dtype: float64
# Missing             0.778518
# Two Wheel Drive     0.111664
# Four Wheel Drive    0.057558
# No                  0.050173
# Rare                0.002087
# Name: Drive_System, dtype: float64
# OROPS         0.394798
# EROPS w AC    0.343020
# EROPS         0.262182
# Name: Enclosure, dtype: float64
# Missing                0.493618
# None or Unspecified    0.451874
# Yes                    0.054508
# Name: Forks, dtype: float64
# Missing                0.830778
# None or Unspecified    0.152284
# Reversible             0.013165
# Rare                   0.003773
# Name: Pad_Type, dtype: float64
# Missing                0.659549
# No                     0.155977
# None or Unspecified    0.137272
# Yes                    0.047202
# Name: Ride_Control, dtype: float64
# Missing     0.830778
# Standard    0.098900
# Extended    0.070322
# Name: Stick, dtype: float64
# Missing                0.613230
# Standard               0.290680
# None or Unspecified    0.050574
# Powershift             0.029140
# Rare                   0.016376
# Name: Transmission, dtype: float64
# Missing                0.830778
# None or Unspecified    0.164245
# Rare                   0.004977
# Name: Turbocharged, dtype: float64
# Missing                0.947740
# None or Unspecified    0.050413
# Rare                   0.001846
# Name: Blade_Extension, dtype: float64
# Missing                0.947740
# 14'                    0.020069
# None or Unspecified    0.019587
# 12'                    0.010035
# Rare                   0.002569
# Name: Blade_Width, dtype: float64
# Missing                0.947740
# None or Unspecified    0.039897
# Rare                   0.012363
# Name: Enclosure_Type, dtype: float64
# Missing    0.947740
# No         0.048888
# Rare       0.003372
# Name: Engine_Horsepower, dtype: float64
# 2 Valve              0.307618
# Auxiliary            0.224452
# Standard             0.214658
# Missing              0.171952
# Base + 1 Function    0.049851
# 3 Valve              0.017661
# Rare                 0.013807
# Name: Hydraulics, dtype: float64
# Missing                0.947740
# None or Unspecified    0.038854
# Yes                    0.013406
# Name: Pushblock, dtype: float64
# Missing                0.782933
# None or Unspecified    0.164566
# Multi Shank            0.022638
# Yes                    0.017661
# Single Shank           0.012202
# Name: Ripper, dtype: float64
# Missing                0.947740
# None or Unspecified    0.026411
# Yes                    0.025849
# Name: Scarifier, dtype: float64
# Missing                0.947740
# None or Unspecified    0.045195
# Sideshift & Tip        0.004335
# Rare                   0.002729
# Name: Tip_Control, dtype: float64
# Missing                0.776993
# None or Unspecified    0.133339
# 20.5                   0.031147
# Rare                   0.026491
# 23.5                   0.018142
# 14"                    0.013888
# Name: Tire_Size, dtype: float64
# None or Unspecified    0.506623
# Missing                0.389821
# Manual                 0.073613
# Hydraulic              0.029943
# Name: Coupler, dtype: float64
# Missing                0.834149
# None or Unspecified    0.134463
# Rare                   0.031388
# Name: Coupler_System, dtype: float64
# Missing                0.834149
# None or Unspecified    0.140082
# Rare                   0.025769
# Name: Grouser_Tracks, dtype: float64
# Missing     0.834149
# Standard    0.157422
# Rare        0.008429
# Name: Hydraulics_Flow, dtype: float64
# Missing    0.727543
# Steel      0.231035
# Rubber     0.041422
# Name: Track_Type, dtype: float64
# Missing                0.727222
# None or Unspecified    0.233282
# Rare                   0.026571
# 32 inch                0.012924
# Name: Undercarriage_Pad_Width, dtype: float64
# Missing                0.727543
# None or Unspecified    0.233684
# Rare                   0.031789
# 9' 6"                  0.006984
# Name: Stick_Length, dtype: float64
# Missing                0.727462
# None or Unspecified    0.202376
# Hydraulic              0.044553
# Manual                 0.025608
# Name: Thumb, dtype: float64
# Missing                0.727543
# None or Unspecified    0.227984
# Yes                    0.044473
# Name: Pattern_Changer, dtype: float64
# Missing    0.727543
# Double     0.220037
# Triple     0.052420
# Name: Grouser_Type, dtype: float64
# Missing                0.835354
# None or Unspecified    0.164646
# Name: Backhoe_Mounting, dtype: float64
# Missing                0.834792
# PAT                    0.074336
# None or Unspecified    0.041824
# Semi U                 0.020631
# Rare                   0.016216
# Straight               0.012202
# Name: Blade_Type, dtype: float64
# Missing                0.834792
# None or Unspecified    0.128201
# Differential Steer     0.019748
# Rare                   0.017259
# Name: Travel_Controls, dtype: float64
# Missing     0.829092
# Standard    0.165449
# Rare        0.005459
# Name: Differential_Type, dtype: float64
# Missing         0.829092
# Conventional    0.167617
# Rare            0.003291
# Name: Steering_Controls, dtype: float64
# Horsepower                     0.415830
# Weight - Metric Tons           0.264269
# Standard Digging Depth - Ft    0.161676
# Operating Capacity - Lbs       0.158224
# Name: PrimarySizeBasis, dtype: float64

# %% [markdown]
# ### Outliers in Numerical variables (15)
#
# In order to tackle outliers and skewed distributions at the same time, I suggested I would do discretisation. And in order to find the optimal buckets automatically, I would use decision trees to find the buckets for me.

# %%
def tree_binariser(var):
    score_ls = [] # here I will store the mse

    for tree_depth in [1,2,3,4]:
        # call the model
        tree_model = DecisionTreeRegressor(max_depth=tree_depth)

        # train the model using 3 fold cross validation
        scores = cross_val_score(tree_model, x_Train2[var].to_frame(), y_Train, cv=3, scoring='neg_mean_squared_error')
        score_ls.append(np.mean(scores))

    # find depth with smallest mse
    depth = [1,2,3,4][np.argmax(score_ls)]
    #print(score_ls, np.argmax(score_ls), depth)

    # transform the variable using the tree
    tree_model = DecisionTreeRegressor(max_depth=depth)
    tree_model.fit(x_Train2[var].to_frame(), x_Train2.SalePrice)
    x_Train2[var] = tree_model.predict(x_Train2[var].to_frame())
    x_Test2[var] = tree_model.predict(x_Test2[var].to_frame())

# %%
for var in continuous_train:
    tree_binariser(var)

# %%
for var in continuous_test:
    tree_binariser(var)

# %%
x_Train2[continuous_train].head()
# Out:
#    MachineHoursCurrentMeter    MachineAge
# 0              30210.356930  45613.739433
# 1              40332.445579  32022.027750
# 2              30210.356930  42968.756966
# 3              40332.445579  30439.543667
# 4              30210.356930  45613.739433

# %%
for var in continuous_train:
    print(var, len(x_Train2[var].unique()))
# Out:
# MachineHoursCurrentMeter 2
# MachineAge 13

# %%
x_Test2[continuous_test].head()
# Out:
#    MachineHoursCurrentMeter    MachineAge
# 0              40332.445579  28768.601111
# 1              40332.445579  23812.767985
# 2              40332.445579  32022.027750
# 3              40332.445579  33689.341183
# 4              30210.356930  33689.341183

# %%
for var in continuous_test:
    print(var, len(x_Test2[var].unique()))
# Out:
# MachineHoursCurrentMeter 2
# MachineAge 13

# %% [markdown]
# ### Encode categorical and discrete variables (section 10)

# %%
def encode_categorical_variables(var, target):
        # make label to price dictionary
        ordered_labels = x_Train2.groupby([var])[target].mean().to_dict()
        
        # encode variables
        x_Train2[var] = x_Train2[var].map(ordered_labels)
        x_Test2[var] = x_Test2[var].map(ordered_labels)
        

# encode labels in categorical vars
for var in categorical_train:
    encode_categorical_variables(var, 'SalePrice')
    
# encode labels in discrete vars
#for var in discrete:
 #   encode_categorical_variables(var, 'SalePrice')

# %%
#let's inspect the dataset
x_Train2.head()
# Out:
#    SalePrice  MachineHoursCurrentMeter     UsageBand   fiBaseModel  \
# 0      66000              30210.356930  28334.130440  28931.061328
# 1      57000              40332.445579  28334.130440  46569.295166
# 2      10000              30210.356930  44477.643344  28931.061328
# 3      38500              40332.445579  44477.643344  28931.061328
# 4      11000              30210.356930  36970.215330  28931.061328
#
#    fiSecondaryDesc  fiModelSeries   ProductSize         state  ProductGroup  \
# 0     29402.883487   29981.266010  23979.399753  35369.592778  37052.463249
# 1     42141.415383   47733.102257  45476.506680  32134.863995  37052.463249
# 2     23397.791284   29981.266010  23979.399753  25555.172013  10549.458563
# 3     23397.791284   32046.904070  32370.001359  32939.036396  35666.120622
# 4     23397.791284   29981.266010  23979.399753  25555.172013  10549.458563
#
#    ProductGroupDesc  Drive_System     Enclosure         Forks     Pad_Type  \
# 0      37052.463249  32431.888757  51777.326782  23512.603724  33608.04452
# 1      37052.463249  32431.888757  51777.326782  23512.603724  33608.04452
# 2      10549.458563  32431.888757  22557.918241  23512.603724  33608.04452
# 3      35666.120622  32431.888757  51777.326782  37194.246441  33608.04452
# 4      10549.458563  32431.888757  28745.229806  23512.603724  33608.04452
#
#    Ride_Control        Stick  Transmission  Turbocharged  Blade_Extension  \
# 0  34754.662273  33608.04452  31016.734588   33608.04452     30002.690135
# 1  34754.662273  33608.04452  31016.734588   33608.04452     30002.690135
# 2  32613.419521  33608.04452  31016.734588   33608.04452     30002.690135
# 3  32613.419521  33608.04452  31016.734588   33608.04452     30002.690135
# 4  32613.419521  33608.04452  31016.734588   33608.04452     30002.690135
#
#     Blade_Width  Enclosure_Type  Engine_Horsepower    Hydraulics  \
# 0  30002.690135    30002.690135       30002.690135  35997.191600
# 1  30002.690135    30002.690135       30002.690135  35997.191600
# 2  30002.690135    30002.690135       30002.690135  25052.796058
# 3  30002.690135    30002.690135       30002.690135  35997.191600
# 4  30002.690135    30002.690135       30002.690135  25052.796058
#
#       Pushblock        Ripper   Scarifier   Tip_Control     Tire_Size  \
# 0  30002.690135  28322.244623  30002.8219  30002.690135  35109.295712
# 1  30002.690135  28322.244623  30002.8219  30002.690135  47058.113208
# 2  30002.690135  28322.244623  30002.8219  30002.690135  28361.684325
# 3  30002.690135  28322.244623  30002.8219  30002.690135  28361.684325
# 4  30002.690135  28322.244623  30002.8219  30002.690135  28361.684325
#
#         Coupler  Coupler_System  Grouser_Tracks  Hydraulics_Flow  \
# 0  30256.342249    33596.706467    33591.153814     33591.153814
# 1  30256.342249    33596.706467    33591.153814     33591.153814
# 2  30256.342249    10470.911551    10382.497322     10507.249299
# 3  30256.342249    33596.706467    33591.153814     33591.153814
# 4  30256.342249    10470.911551    10382.497322     10507.249299
#
#      Track_Type  Undercarriage_Pad_Width  Stick_Length         Thumb  \
# 0  29565.657382             29570.555118  29565.690564  29565.729818
# 1  29565.657382             29570.555118  29565.690564  29565.729818
# 2  29565.657382             29570.555118  29565.690564  29565.729818
# 3  29565.657382             29570.555118  29565.690564  29565.729818
# 4  29565.657382             29570.555118  29565.690564  29565.729818
#
#    Pattern_Changer  Grouser_Type  Backhoe_Mounting    Blade_Type  \
# 0     29565.690564  29565.657382      29816.728063  29831.619645
# 1     29565.690564  29565.657382      29816.728063  29831.619645
# 2     29565.690564  29565.657382      29816.728063  29831.619645
# 3     29565.690564  29565.657382      29816.728063  29831.619645
# 4     29565.690564  29565.657382      29816.728063  29831.619645
#
#    Travel_Controls  Differential_Type  Steering_Controls  PrimarySizeBasis  \
# 0     29832.178505       36854.326664       36975.240306      37118.131466
# 1     29832.178505       36854.326664       36975.240306      37118.131466
# 2     29832.178505       29815.001137       29814.778141      10503.305339
# 3     29832.178505       29815.001137       29814.778141      37118.131466
# 4     29832.178505       29815.001137       29814.778141      10503.305339
#
#      MachineAge
# 0  45613.739433
# 1  32022.027750
# 2  42968.756966
# 3  30439.543667
# 4  45613.739433

# %% [markdown]
# We can see that the labels have now been replaced by the mean house price.
#
# ### Feature scaling (section 13)

# %%
x_Train2.describe()
# Out:
#            SalePrice  MachineHoursCurrentMeter      UsageBand    fiBaseModel  \
# count  401125.000000             401125.000000  401125.000000  401125.000000
# mean    31099.712848              31099.712848   31099.712848   31099.712848
# std     23036.898502               2865.520190    3065.073987    9048.752557
# min      4750.000000              30210.356930   28334.130440   20016.801596
# 25%     14500.000000              30210.356930   30209.249944   28931.061328
# 50%     24000.000000              30210.356930   30209.249944   28931.061328
# 75%     40000.000000              30210.356930   30209.249944   28931.061328
# max    142000.000000              40332.445579   44477.643344   70751.489069
#
#        fiSecondaryDesc  fiModelSeries    ProductSize          state  \
# count    401125.000000  401125.000000  401125.000000  401125.000000
# mean      31099.712848   31099.712848   31099.712848   31099.712848
# std        7960.776063    3966.546563   10845.730404    2525.365222
# min       18811.365552   29981.266010   15149.894686   25420.216276
# 25%       23397.791284   29981.266010   23979.399753   29787.451256
# 50%       28885.699385   29981.266010   23979.399753   30981.542823
# 75%       36653.645286   29981.266010   45476.506680   32939.036396
# max       48369.771850   47733.102257   47719.945952   36015.740326
#
#         ProductGroup  ProductGroupDesc   Drive_System      Enclosure  \
# count  401125.000000     401125.000000  401125.000000  401125.000000
# mean    31099.712848      31099.712848   31099.712847   31099.712848
# std      9982.103252       9982.103252    6389.894685   11279.521418
# min     10549.458563      10549.458563   18310.681983   22557.918241
# 25%     20897.352553      20897.352553   32431.888757   22557.918241
# 50%     35666.120622      35666.120622   32431.888757   28745.229806
# 75%     36158.412221      36158.412221   32431.888757   28745.229806
# max     47251.564518      47251.564518   60011.466165   51777.326782
#
#                Forks       Pad_Type   Ride_Control          Stick  \
# count  401125.000000  401125.000000  401125.000000  401125.000000
# mean    31099.712848   31099.712847   31099.712848   31099.712847
# std      6787.228960    5138.896664    6020.141768    5125.622351
# min     23512.603724   20201.640298   20728.651001   19440.228819
# 25%     23512.603724   33608.044520   32613.419521   33608.044520
# 50%     37194.246441   33608.044520   32613.419521   33608.044520
# 75%     37194.246441   33608.044520   32613.419521   33608.044520
# max     37194.246441   33608.044520   55795.479180   33608.044520
#
#         Transmission   Turbocharged  Blade_Extension    Blade_Width  \
# count  401125.000000  401125.000000    401125.000000  401125.000000
# mean    31099.712848   31099.712847     31099.712848   31099.712848
# std      4412.837548    5070.509373      4280.347261    4866.196627
# min     25966.030035   20723.421654     30002.690135   30002.690135
# 25%     28285.938765   33608.044520     30002.690135   30002.690135
# 50%     31016.734588   33608.044520     30002.690135   30002.690135
# 75%     31016.734588   33608.044520     30002.690135   30002.690135
# max     47008.807923   33608.044520     64345.540797   58942.376599
#
#        Enclosure_Type  Engine_Horsepower     Hydraulics      Pushblock  \
# count   401125.000000      401125.000000  401125.000000  401125.000000
# mean     31099.712848       31099.712848   31099.712848   31099.712848
# std       5374.724137        4913.389025    7645.644757    5081.385771
# min      30002.690135       30002.690135   20978.169611   30002.690135
# 25%      30002.690135       30002.690135   25052.796058   30002.690135
# 50%      30002.690135       30002.690135   29274.054097   30002.690135
# 75%      30002.690135       30002.690135   35997.191600   30002.690135
# max      81486.441444       90372.269891   61018.677366   68040.808200
#
#               Ripper      Scarifier    Tip_Control      Tire_Size  \
# count  401125.000000  401125.000000  401125.000000  401125.000000
# mean    31099.712848   31099.712847   31099.712848   31099.712847
# std      6361.151041    4253.482141    4365.980369    5557.779074
# min     28322.244623   30002.821900   30002.690135   28361.684325
# 25%     28322.244623   30002.821900   30002.690135   28361.684325
# 50%     28322.244623   30002.821900   30002.690135   28361.684325
# 75%     35104.655155   30002.821900   30002.690135   28361.684325
# max     63495.752468   49081.788506   62078.646241   50083.806082
#
#              Coupler  Coupler_System  Grouser_Tracks  Hydraulics_Flow  \
# count  401125.000000   401125.000000   401125.000000    401125.000000
# mean    31099.712848    31099.712848    31099.712848     31099.712848
# std      2105.720475     7164.070985     7159.189376      7157.140258
# min     30256.342249    10470.911551    10382.497322     10507.249299
# 25%     30256.342249    33596.706467    33591.153814     33591.153814
# 50%     31103.994743    33596.706467    33591.153814     33591.153814
# 75%     31103.994743    33596.706467    33591.153814     33591.153814
# max     46793.387708    33596.706467    33591.153814     33591.153814
#
#           Track_Type  Undercarriage_Pad_Width   Stick_Length          Thumb  \
# count  401125.000000            401125.000000  401125.000000  401125.000000
# mean    31099.712848             31099.712848   31099.712847   31099.712848
# std      4882.143631              3075.537052    4262.817566    2760.681221
# min     15746.541302             29570.555118   29565.690564   29565.729818
# 25%     29565.657382             29570.555118   29565.690564   29565.729818
# 50%     29565.657382             29570.555118   29565.690564   29565.729818
# 75%     29565.657382             29570.555118   29565.690564   29565.729818
# max     39139.034413             48916.573950   49711.692749   39335.906711
#
#        Pattern_Changer   Grouser_Type  Backhoe_Mounting     Blade_Type  \
# count    401125.000000  401125.000000     401125.000000  401125.000000
# mean      31099.712847   31099.712848      31099.712848   31099.712847
# std        3711.430378    3020.247593       2601.235282    4895.016000
# min       29411.538462   29565.657382      16462.500000   29831.619645
# 25%       29565.690564   29565.657382      29816.728063   29831.619645
# 50%       29565.690564   29565.657382      29816.728063   29831.619645
# 75%       29565.690564   29565.657382      29816.728063   29831.619645
# max       52238.069117   52000.000000      36363.342979   58536.042126
#
#        Travel_Controls  Differential_Type  Steering_Controls  \
# count    401125.000000      401125.000000      401125.000000
# mean      31099.712848       31099.712848       31099.712848
# std        4712.131841        3031.931084        3024.526436
# min       29832.178505       29815.001137       29814.778141
# 25%       29832.178505       29815.001137       29814.778141
# 50%       29832.178505       29815.001137       29814.778141
# 75%       29832.178505       29815.001137       29814.778141
# max       69572.622464       56826.943199       64084.420290
#
#        PrimarySizeBasis     MachineAge
# count     401125.000000  401125.000000
# mean       31099.712848   31099.712848
# std         9264.797734    7110.567412
# min        10503.305339   17951.619644
# 25%        21100.720674   25728.332737
# 50%        35964.098622   30439.543667
# 75%        37118.131466   35567.880894
# max        37118.131466   45613.739433

# %%
training_vars = [var for var in x_Train2.columns if var not in [ 'SalePrice']]

# %%
# fit scaler
scaler = StandardScaler() # create an instance
scaler.fit(x_Train2[training_vars]) #  fit  the scaler to the train set for later use
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# The scaler is now ready, we can use it in a machine learning algorithm when required. See below.
#
# ### Machine Learning algorithm building
#
# #### xgboost

# %%
xgb_model = xgb.XGBRegressor()

#eval_set = [(x_Test2[training_vars], y_test)]
#xgb_model.fit(x_Train2[training_vars], y_train, eval_set=eval_set, verbose=False)
xgb_model.fit(x_Train2[training_vars], y_Train, verbose=False)

pred = xgb_model.predict(x_Train2[training_vars])
print('xgb train mse: {}'.format(mean_squared_error(y_Train, pred)))
pred = xgb_model.predict(x_Test2[training_vars])
#print('xgb test mse: {}'.format(mean_squared_error(y_test, pred)))
print(pred)
# Out:
# xgb train mse: 128598149.92532888
# [ 20634.234375    21066.22460938  46200.9609375  ...,  11713.56835938
#   13915.5546875   17774.8515625 ]

# %% [markdown]
# #### Random Forests

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_Train2[training_vars], y_Train)

pred = rf_model.predict(x_Train2[training_vars])
print('rf train mse: {}'.format(mean_squared_error(y_Train, pred)))
pred = rf_model.predict(x_Test[training_vars])
print(pred)
#print('rf test mse: {}'.format(mean_squared_error(y_test, pred)))
# Out:
# rf train mse: 35702683.70353865
# [ 18683.33333333  30287.5         45775.         ...,  12276.92906664
#   10624.86768898  42833.33333333]

# %% [markdown]
# #### Support vector machine

# %%
SVR_model = SVR()
SVR_model.fit(scaler.transform(x_Train2[training_vars]), y_Train)

pred = SVR_model.predict(scaler.transform(x_Train2[training_vars]))
print('SVR train mse: {}'.format(mean_squared_error(y_Train, pred)))
pred = SVR_model.predict(scaler.transform(x_Test[training_vars]))
#print('SVR test mse: {}'.format(mean_squared_error(y_test, pred)))
print(pred)

# %% [markdown]
# #### Regularised linear regression

# %%
lin_model = Lasso(random_state=2909)
lin_model.fit(scaler.transform(x_Train2[training_vars]), y_Train)

pred = lin_model.predict(scaler.transform(x_Train2[training_vars]))
print('linear train mse: {}'.format(mean_squared_error(y_Train, pred)))
pred = lin_model.predict(scaler.transform(x_Test2[training_vars]))
#print('linear test mse: {}'.format(mean_squared_error(y_test, pred)))
print(pred)
