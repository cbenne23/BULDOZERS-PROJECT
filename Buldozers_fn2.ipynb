# %% [markdown]
# ## Project Summary
# This project was undertaken as part of a data mining competition hosted on Kaggle’s website and is aimed at developing a "Blue Book" for Bulldozers challenge, i.e. estimating a statistical/machine-learning model(s) to predict the sale prices of used Buldozers. The contest is sponsored by Fast Iron, a company known for ‘creating enterprise data standards, cleaning data, and maintaining clean data’. Similar to Kelly’s Blue Book (www.kbb.com) which provides values on new and used automobiles, the purpose of the Blue Book competition is to develop a similar tool to help customers put a value on their equipment. Kaggle contestants are provided with the sales data from previous auctions to use in developing their submission.
#
# I estimated a suite of competing machine-learning/statistical models to predict the sale prices of used  buldozers, including Xgboost, Random Forest, Regularized Linear Regression, and Support Vector Machines. Notably, the Xgboost model proved to be the superior model in terms of performance. It is worth noting that the parsimonious model comprising features selected through the modeling process performed comparably( Rsquare of **74.93%** versus **75.44%**) well relative to the model with all features, including those with importance scores close to zero. The Random Forest model was the runner up model with an Rsquare of approx. **73%**.

# %% [markdown]
# ## Importing the python libaries

# %%
# to handle datasets
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
% matplotlib inline

from matplotlib import pyplot

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler

# for tree binarisation
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score


# to build the models
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

import xgboost as xgb

# to evaluate the models
from sklearn.metrics import mean_squared_error

from sklearn.metrics import r2_score

pd.pandas.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset 1

# %%
# loading the Training  dataset 1
data1 = pd.read_csv('Train.csv')

# %%
# Examing the first 5 rows of the dataset
data1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate fiModelDesc  \
# 0                      68.0       Low  11/16/2006 0:00        521D
# 1                    4640.0       Low   3/26/2004 0:00      950FII
# 2                    2838.0      High   2/26/2004 0:00         226
# 3                    3486.0      High   5/19/2011 0:00    PC120-6E
# 4                     722.0    Medium   7/23/2009 0:00        S175
#
#   fiBaseModel fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0         521               D           NaN               NaN         NaN
# 1         950               F            II               NaN      Medium
# 2         226             NaN           NaN               NaN         NaN
# 3       PC120             NaN           -6E               NaN       Small
# 4        S175             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls
# 0          Standard      Conventional
# 1          Standard      Conventional
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN

# %% [markdown]
# ## Variable Types - Dataset 1 Training set

# %%
# let's inspect the type of variables in pandas
data1.dtypes
# Out:
# SalesID                       int64
# SalePrice                     int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                float64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# dtype: object

# %% [markdown]
# This dataset is very large. Thus, manual inspection of each one of them is a bit time demanding. Therefore, here instead of deciding variable by variable what is the best way to proceed, I will try to automate the feature engineering pipeline, making some a priori decisions on when I will apply one technique or the other, and then expanding them to the entire dataset.

# %% [markdown]
# ## Investigating Duplicate sales

# %%
# Checking duplicate sales transactions
data1.SalesID.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Dataset 2

# %%
# loading Training dataset 2
data2 = pd.read_csv('Machine_Appendix.csv')

# %%
# Checking the first 5 rows of dataset 2
data2.head()
# Out:
#    MachineID  ModelID fiModelDesc fiBaseModel fiSecondaryDesc fiModelSeries  \
# 0        113     1355        350L         350             NaN           NaN
# 1        434     3538        416C         416               C           NaN
# 2        534     3538        416C         416               C           NaN
# 3        718     3538        416C         416               C           NaN
# 4       1753     1580      D5GLGP          D5               G           NaN
#
#   fiModelDescriptor                                 fiProductClassDesc  \
# 0                 L  Hydraulic Excavator, Track - 50.0 to 66.0 Metr...
# 1               NaN  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# 2               NaN  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# 3               NaN  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...
# 4               LGP  Track Type Tractor, Dozer - 85.0 to 105.0 Hors...
#
#   ProductGroup     ProductGroupDesc  MfgYear  fiManufacturerID  \
# 0          TEX     Track Excavators   1994.0                26
# 1           BL      Backhoe Loaders   1997.0                26
# 2           BL      Backhoe Loaders   1998.0                26
# 3           BL      Backhoe Loaders   2000.0                26
# 4          TTT  Track Type Tractors   2006.0                26
#
#   fiManufacturerDesc             PrimarySizeBasis  PrimaryLower  PrimaryUpper
# 0        Caterpillar         Weight - Metric Tons          50.0          66.0
# 1        Caterpillar  Standard Digging Depth - Ft          14.0          15.0
# 2        Caterpillar  Standard Digging Depth - Ft          14.0          15.0
# 3        Caterpillar  Standard Digging Depth - Ft          14.0          15.0
# 4        Caterpillar                   Horsepower          85.0         105.0

# %% [markdown]
# ## Variable Types - Dataset 2 -Test set

# %%
# let's inspect the type of variables in pandas
data2.dtypes
# Out:
# MachineID               int64
# ModelID                 int64
# fiModelDesc            object
# fiBaseModel            object
# fiSecondaryDesc        object
# fiModelSeries          object
# fiModelDescriptor      object
# fiProductClassDesc     object
# ProductGroup           object
# ProductGroupDesc       object
# MfgYear               float64
# fiManufacturerID        int64
# fiManufacturerDesc     object
# PrimarySizeBasis       object
# PrimaryLower          float64
# PrimaryUpper          float64
# dtype: object

# %%
# Extracting relevant variables from dataset 2
dataset2_rel = ['MachineID','ModelID', 'PrimarySizeBasis']

# %%
data2_rev = data2[dataset2_rel]

# %%
# Checking revised dataset 
data2_rev.head()
# Out:
#    MachineID  ModelID             PrimarySizeBasis
# 0        113     1355         Weight - Metric Tons
# 1        434     3538  Standard Digging Depth - Ft
# 2        534     3538  Standard Digging Depth - Ft
# 3        718     3538  Standard Digging Depth - Ft
# 4       1753     1580                   Horsepower

# %%
# let's inspect the type of variables in pandas for dataset 2 revised
data2_rev.dtypes
# Out:
# MachineID            int64
# ModelID              int64
# PrimarySizeBasis    object
# dtype: object

# %%
# checking dimensions of dataset 1 -Test set
data1.shape
# Out:
# (401125, 53)

# %%
# checking dimensions of dataset 2
data2_rev.shape
# Out:
# (358593, 3)

# %% [markdown]
# ## Merging the two datasets - data1 and data2_rev - test

# %%
 data_new1 = pd.merge(data1,data2_rev, how='left', on=['MachineID', 'ModelID'])

# %%
# Checking types of variables in the merged datasets
data_new1.dtypes
# Out:
# SalesID                       int64
# SalePrice                     int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                float64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# PrimarySizeBasis             object
# dtype: object

# %%
# Examing the top 5 rows of the merged dataset
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate fiModelDesc  \
# 0                      68.0       Low  11/16/2006 0:00        521D
# 1                    4640.0       Low   3/26/2004 0:00      950FII
# 2                    2838.0      High   2/26/2004 0:00         226
# 3                    3486.0      High   5/19/2011 0:00    PC120-6E
# 4                     722.0    Medium   7/23/2009 0:00        S175
#
#   fiBaseModel fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0         521               D           NaN               NaN         NaN
# 1         950               F            II               NaN      Medium
# 2         226             NaN           NaN               NaN         NaN
# 3       PC120             NaN           -6E               NaN       Small
# 4        S175             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls          PrimarySizeBasis
# 0          Standard      Conventional                Horsepower
# 1          Standard      Conventional                Horsepower
# 2               NaN               NaN  Operating Capacity - Lbs
# 3               NaN               NaN                       NaN
# 4               NaN               NaN  Operating Capacity - Lbs

# %%
# Checking dimensions of the merged dataset
data_new1.shape
# Out:
# (401125, 54)

# %% [markdown]
# *There are a mixture of categorical and numerical variables. Numerical are those of type int and float. Categorical those of type object.*

# %%
print('Number of Sales Id labels in the Training Dataset: ', len(data_new1.SalesID.unique()))
print('Number of Sales in the Training Dataset: ', len(data_new1))
# Out:
# Number of Sales Id labels in the Training Dataset:  401125
# Number of Sales in the Training Dataset:  401125

# %% [markdown]
# ## Merging test data

# %%
# load test dataset 1
data_test = pd.read_csv('Test.csv')

# %%
# Checking the shape of the Test dataset
data_test.shape
# Out:
# (12457, 52)

# %%
# let's inspect the type of variables in pandas test data
data_test.dtypes
# Out:
# SalesID                       int64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                  int64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# saledate                     object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# Turbocharged                 object
# Blade_Extension              object
# Blade_Width                  object
# Enclosure_Type               object
# Engine_Horsepower            object
# Hydraulics                   object
# Pushblock                    object
# Ripper                       object
# Scarifier                    object
# Tip_Control                  object
# Tire_Size                    object
# Coupler                      object
# Coupler_System               object
# Grouser_Tracks               object
# Hydraulics_Flow              object
# Track_Type                   object
# Undercarriage_Pad_Width      object
# Stick_Length                 object
# Thumb                        object
# Pattern_Changer              object
# Grouser_Type                 object
# Backhoe_Mounting             object
# Blade_Type                   object
# Travel_Controls              object
# Differential_Type            object
# Steering_Controls            object
# dtype: object

# %%
# merging test data with machine_appendix data
data_test_mer = pd.merge(data_test,data2_rev, how='left', on=['MachineID', 'ModelID'])

# %%
data_test_mer.shape
# Out:
# (12457, 53)

# %%
print('Number of Sales Id labels in the Test Dataset: ', len(data_test_mer.SalesID.unique()))
print('Number of Sales in the Test Dataset: ', len(data_test_mer))
# Out:
# Number of Sales Id labels in the Test Dataset:  12457
# Number of Sales in the Test Dataset:  12457

# %%
# Checking the first 5 rows of the merged Text dataset
data_test_mer.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand        saledate fiModelDesc fiBaseModel  \
# 0                    3688.0       Low   5/3/2012 0:00        580G         580
# 1                   28555.0      High  5/10/2012 0:00         936         936
# 2                    6038.0    Medium  5/10/2012 0:00    EC210BLC       EC210
# 3                    8940.0      High  5/10/2012 0:00       330CL         330
# 4                    2286.0       Low  5/10/2012 0:00        650K         650
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor     ProductSize  \
# 0               G           NaN               NaN             NaN
# 1             NaN           NaN               NaN          Medium
# 2               B           NaN                LC  Large / Medium
# 3               C           NaN                 L  Large / Medium
# 4               K           NaN               NaN             NaN
#
#                                   fiProductClassDesc       state ProductGroup  \
# 0  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...     Wyoming           BL
# 1           Wheel Loader - 135.0 to 150.0 Horsepower    Virginia           WL
# 2  Hydraulic Excavator, Track - 21.0 to 24.0 Metr...  New Jersey          TEX
# 3  Hydraulic Excavator, Track - 33.0 to 40.0 Metr...  New Jersey          TEX
# 4  Track Type Tractor, Dozer - 20.0 to 75.0 Horse...     Florida          TTT
#
#       ProductGroupDesc     Drive_System   Enclosure Forks  \
# 0      Backhoe Loaders  Two Wheel Drive       OROPS   Yes
# 1         Wheel Loader              NaN       EROPS   Yes
# 2     Track Excavators              NaN  EROPS w AC   NaN
# 3     Track Excavators              NaN  EROPS w AC   NaN
# 4  Track Type Tractors              NaN       OROPS   NaN
#
#               Pad_Type         Ride_Control     Stick Transmission  \
# 0  None or Unspecified                   No  Standard     Standard
# 1                  NaN  None or Unspecified       NaN          NaN
# 2                  NaN                  NaN       NaN          NaN
# 3                  NaN                  NaN       NaN          NaN
# 4                  NaN                  NaN       NaN  Hydrostatic
#
#           Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  None or Unspecified             NaN         NaN            NaN
# 1                  NaN             NaN         NaN            NaN
# 2                  NaN             NaN         NaN            NaN
# 3                  NaN             NaN         NaN            NaN
# 4                  NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock               Ripper Scarifier  \
# 0               NaN        NaN       NaN                  NaN       NaN
# 1               NaN    2 Valve       NaN                  NaN       NaN
# 2               NaN  Auxiliary       NaN                  NaN       NaN
# 3               NaN   Standard       NaN                  NaN       NaN
# 4               NaN    2 Valve       NaN  None or Unspecified       NaN
#
#   Tip_Control Tire_Size              Coupler Coupler_System Grouser_Tracks  \
# 0         NaN       NaN                  NaN            NaN            NaN
# 1         NaN      20.5  None or Unspecified            NaN            NaN
# 2         NaN       NaN  None or Unspecified            NaN            NaN
# 3         NaN       NaN  None or Unspecified            NaN            NaN
# 4         NaN       NaN                  NaN            NaN            NaN
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width         Stick_Length  \
# 0             NaN        NaN                     NaN                  NaN
# 1             NaN        NaN                     NaN                  NaN
# 2             NaN      Steel     None or Unspecified                9' 6"
# 3             NaN      Steel     None or Unspecified  None or Unspecified
# 4             NaN        NaN                     NaN                  NaN
#
#     Thumb      Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0     NaN                  NaN          NaN                  NaN        NaN
# 1     NaN                  NaN          NaN                  NaN        NaN
# 2  Manual  None or Unspecified       Double                  NaN        NaN
# 3  Manual                  Yes       Triple                  NaN        NaN
# 4     NaN                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis
# 0  Standard Digging Depth - Ft
# 1                   Horsepower
# 2         Weight - Metric Tons
# 3         Weight - Metric Tons
# 4                          NaN

# %% [markdown]
# ## Creating an Age variable for the Training dataset

# %%
# Extracting the year from a time object
data_new1['saledate'] = pd.to_datetime(data_new1['saledate'])

# %%
#use the datetime attribute dt to access the datetime components
data_new1['yearsold'] = data_new1['saledate'].dt.year

# %%
#Checking if the new variable was created
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                      68.0       Low 2006-11-16        521D         521
# 1                    4640.0       Low 2004-03-26      950FII         950
# 2                    2838.0      High 2004-02-26         226         226
# 3                    3486.0      High 2011-05-19    PC120-6E       PC120
# 4                     722.0    Medium 2009-07-23        S175        S175
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0               D           NaN               NaN         NaN
# 1               F            II               NaN      Medium
# 2             NaN           NaN               NaN         NaN
# 3             NaN           -6E               NaN       Small
# 4             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls          PrimarySizeBasis  yearsold
# 0          Standard      Conventional                Horsepower      2006
# 1          Standard      Conventional                Horsepower      2004
# 2               NaN               NaN  Operating Capacity - Lbs      2004
# 3               NaN               NaN                       NaN      2011
# 4               NaN               NaN  Operating Capacity - Lbs      2009

# %%
# Checking data types for the yearsold and the YearMade variables
data_new1.yearsold.dtypes, data_new1.YearMade.dtypes
# Out:
# (dtype('int64'), dtype('int64'))

# %%
# Creating an Age variable
data_new1['MachineAge'] = data_new1['yearsold'] - data_new1['YearMade']

# %%
# Checking if the new MachineAge variable was created
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                      68.0       Low 2006-11-16        521D         521
# 1                    4640.0       Low 2004-03-26      950FII         950
# 2                    2838.0      High 2004-02-26         226         226
# 3                    3486.0      High 2011-05-19    PC120-6E       PC120
# 4                     722.0    Medium 2009-07-23        S175        S175
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor ProductSize  \
# 0               D           NaN               NaN         NaN
# 1               F            II               NaN      Medium
# 2             NaN           NaN               NaN         NaN
# 3             NaN           -6E               NaN       Small
# 4             NaN           NaN               NaN         NaN
#
#                                   fiProductClassDesc           state  \
# 0           Wheel Loader - 110.0 to 120.0 Horsepower         Alabama
# 1           Wheel Loader - 150.0 to 175.0 Horsepower  North Carolina
# 2  Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...        New York
# 3  Hydraulic Excavator, Track - 12.0 to 14.0 Metr...           Texas
# 4  Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...        New York
#
#   ProductGroup    ProductGroupDesc Drive_System   Enclosure  \
# 0           WL        Wheel Loader          NaN  EROPS w AC
# 1           WL        Wheel Loader          NaN  EROPS w AC
# 2          SSL  Skid Steer Loaders          NaN       OROPS
# 3          TEX    Track Excavators          NaN  EROPS w AC
# 4          SSL  Skid Steer Loaders          NaN       EROPS
#
#                  Forks Pad_Type         Ride_Control Stick Transmission  \
# 0  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 1  None or Unspecified      NaN  None or Unspecified   NaN          NaN
# 2  None or Unspecified      NaN                  NaN   NaN          NaN
# 3                  NaN      NaN                  NaN   NaN          NaN
# 4  None or Unspecified      NaN                  NaN   NaN          NaN
#
#   Turbocharged Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower  \
# 0          NaN             NaN         NaN            NaN               NaN
# 1          NaN             NaN         NaN            NaN               NaN
# 2          NaN             NaN         NaN            NaN               NaN
# 3          NaN             NaN         NaN            NaN               NaN
# 4          NaN             NaN         NaN            NaN               NaN
#
#   Hydraulics Pushblock Ripper Scarifier Tip_Control            Tire_Size  \
# 0    2 Valve       NaN    NaN       NaN         NaN  None or Unspecified
# 1    2 Valve       NaN    NaN       NaN         NaN                 23.5
# 2  Auxiliary       NaN    NaN       NaN         NaN                  NaN
# 3    2 Valve       NaN    NaN       NaN         NaN                  NaN
# 4  Auxiliary       NaN    NaN       NaN         NaN                  NaN
#
#                Coupler       Coupler_System       Grouser_Tracks  \
# 0  None or Unspecified                  NaN                  NaN
# 1  None or Unspecified                  NaN                  NaN
# 2  None or Unspecified  None or Unspecified  None or Unspecified
# 3  None or Unspecified                  NaN                  NaN
# 4  None or Unspecified  None or Unspecified  None or Unspecified
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length Thumb  \
# 0             NaN        NaN                     NaN          NaN   NaN
# 1             NaN        NaN                     NaN          NaN   NaN
# 2        Standard        NaN                     NaN          NaN   NaN
# 3             NaN        NaN                     NaN          NaN   NaN
# 4        Standard        NaN                     NaN          NaN   NaN
#
#   Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type Travel_Controls  \
# 0             NaN          NaN              NaN        NaN             NaN
# 1             NaN          NaN              NaN        NaN             NaN
# 2             NaN          NaN              NaN        NaN             NaN
# 3             NaN          NaN              NaN        NaN             NaN
# 4             NaN          NaN              NaN        NaN             NaN
#
#   Differential_Type Steering_Controls          PrimarySizeBasis  yearsold  \
# 0          Standard      Conventional                Horsepower      2006
# 1          Standard      Conventional                Horsepower      2004
# 2               NaN               NaN  Operating Capacity - Lbs      2004
# 3               NaN               NaN                       NaN      2011
# 4               NaN               NaN  Operating Capacity - Lbs      2009
#
#    MachineAge
# 0           2
# 1           8
# 2           3
# 3          10
# 4           2

# %% [markdown]
#  Some of the variables are superfluous and will be removed from the analysis:
#     . SalesID
#     . datasource
#     . auctioneerID
#     . YearMade
#     . saledate
#     . fiModelDesc
#     . fiModelDescriptor
#     . fiProductClassDesc
#     . yearsold
#     . PrimaryUpper
#     . PrimaryLower

# %% [markdown]
# ## Creating an Age variable for the Test dataset

# %%
# Extracting the year from a time object
data_test_mer['saledate'] = pd.to_datetime(data_test_mer['saledate'])

# %%
#use the datetime attribute dt to access the datetime components
data_test_mer['yearsold'] = data_test_mer['saledate'].dt.year

# %%
#Checking if the new variable was created for the Test dataset
data_test_mer.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                    3688.0       Low 2012-05-03        580G         580
# 1                   28555.0      High 2012-05-10         936         936
# 2                    6038.0    Medium 2012-05-10    EC210BLC       EC210
# 3                    8940.0      High 2012-05-10       330CL         330
# 4                    2286.0       Low 2012-05-10        650K         650
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor     ProductSize  \
# 0               G           NaN               NaN             NaN
# 1             NaN           NaN               NaN          Medium
# 2               B           NaN                LC  Large / Medium
# 3               C           NaN                 L  Large / Medium
# 4               K           NaN               NaN             NaN
#
#                                   fiProductClassDesc       state ProductGroup  \
# 0  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...     Wyoming           BL
# 1           Wheel Loader - 135.0 to 150.0 Horsepower    Virginia           WL
# 2  Hydraulic Excavator, Track - 21.0 to 24.0 Metr...  New Jersey          TEX
# 3  Hydraulic Excavator, Track - 33.0 to 40.0 Metr...  New Jersey          TEX
# 4  Track Type Tractor, Dozer - 20.0 to 75.0 Horse...     Florida          TTT
#
#       ProductGroupDesc     Drive_System   Enclosure Forks  \
# 0      Backhoe Loaders  Two Wheel Drive       OROPS   Yes
# 1         Wheel Loader              NaN       EROPS   Yes
# 2     Track Excavators              NaN  EROPS w AC   NaN
# 3     Track Excavators              NaN  EROPS w AC   NaN
# 4  Track Type Tractors              NaN       OROPS   NaN
#
#               Pad_Type         Ride_Control     Stick Transmission  \
# 0  None or Unspecified                   No  Standard     Standard
# 1                  NaN  None or Unspecified       NaN          NaN
# 2                  NaN                  NaN       NaN          NaN
# 3                  NaN                  NaN       NaN          NaN
# 4                  NaN                  NaN       NaN  Hydrostatic
#
#           Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  None or Unspecified             NaN         NaN            NaN
# 1                  NaN             NaN         NaN            NaN
# 2                  NaN             NaN         NaN            NaN
# 3                  NaN             NaN         NaN            NaN
# 4                  NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock               Ripper Scarifier  \
# 0               NaN        NaN       NaN                  NaN       NaN
# 1               NaN    2 Valve       NaN                  NaN       NaN
# 2               NaN  Auxiliary       NaN                  NaN       NaN
# 3               NaN   Standard       NaN                  NaN       NaN
# 4               NaN    2 Valve       NaN  None or Unspecified       NaN
#
#   Tip_Control Tire_Size              Coupler Coupler_System Grouser_Tracks  \
# 0         NaN       NaN                  NaN            NaN            NaN
# 1         NaN      20.5  None or Unspecified            NaN            NaN
# 2         NaN       NaN  None or Unspecified            NaN            NaN
# 3         NaN       NaN  None or Unspecified            NaN            NaN
# 4         NaN       NaN                  NaN            NaN            NaN
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width         Stick_Length  \
# 0             NaN        NaN                     NaN                  NaN
# 1             NaN        NaN                     NaN                  NaN
# 2             NaN      Steel     None or Unspecified                9' 6"
# 3             NaN      Steel     None or Unspecified  None or Unspecified
# 4             NaN        NaN                     NaN                  NaN
#
#     Thumb      Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0     NaN                  NaN          NaN                  NaN        NaN
# 1     NaN                  NaN          NaN                  NaN        NaN
# 2  Manual  None or Unspecified       Double                  NaN        NaN
# 3  Manual                  Yes       Triple                  NaN        NaN
# 4     NaN                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  yearsold
# 0  Standard Digging Depth - Ft      2012
# 1                   Horsepower      2012
# 2         Weight - Metric Tons      2012
# 3         Weight - Metric Tons      2012
# 4                          NaN      2012

# %%
# Checking the data types
data_test_mer.yearsold.dtypes, data_test_mer.YearMade.dtypes
# Out:
# (dtype('int64'), dtype('int64'))

# %%
# Creating an Age variable for the Test dataset
data_test_mer['MachineAge'] = data_test_mer['yearsold'] - data_test_mer['YearMade']

# %%
#Checking if the new variable was created in the Test dataset
data_test_mer.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 0                    3688.0       Low 2012-05-03        580G         580
# 1                   28555.0      High 2012-05-10         936         936
# 2                    6038.0    Medium 2012-05-10    EC210BLC       EC210
# 3                    8940.0      High 2012-05-10       330CL         330
# 4                    2286.0       Low 2012-05-10        650K         650
#
#   fiSecondaryDesc fiModelSeries fiModelDescriptor     ProductSize  \
# 0               G           NaN               NaN             NaN
# 1             NaN           NaN               NaN          Medium
# 2               B           NaN                LC  Large / Medium
# 3               C           NaN                 L  Large / Medium
# 4               K           NaN               NaN             NaN
#
#                                   fiProductClassDesc       state ProductGroup  \
# 0  Backhoe Loader - 14.0 to 15.0 Ft Standard Digg...     Wyoming           BL
# 1           Wheel Loader - 135.0 to 150.0 Horsepower    Virginia           WL
# 2  Hydraulic Excavator, Track - 21.0 to 24.0 Metr...  New Jersey          TEX
# 3  Hydraulic Excavator, Track - 33.0 to 40.0 Metr...  New Jersey          TEX
# 4  Track Type Tractor, Dozer - 20.0 to 75.0 Horse...     Florida          TTT
#
#       ProductGroupDesc     Drive_System   Enclosure Forks  \
# 0      Backhoe Loaders  Two Wheel Drive       OROPS   Yes
# 1         Wheel Loader              NaN       EROPS   Yes
# 2     Track Excavators              NaN  EROPS w AC   NaN
# 3     Track Excavators              NaN  EROPS w AC   NaN
# 4  Track Type Tractors              NaN       OROPS   NaN
#
#               Pad_Type         Ride_Control     Stick Transmission  \
# 0  None or Unspecified                   No  Standard     Standard
# 1                  NaN  None or Unspecified       NaN          NaN
# 2                  NaN                  NaN       NaN          NaN
# 3                  NaN                  NaN       NaN          NaN
# 4                  NaN                  NaN       NaN  Hydrostatic
#
#           Turbocharged Blade_Extension Blade_Width Enclosure_Type  \
# 0  None or Unspecified             NaN         NaN            NaN
# 1                  NaN             NaN         NaN            NaN
# 2                  NaN             NaN         NaN            NaN
# 3                  NaN             NaN         NaN            NaN
# 4                  NaN             NaN         NaN            NaN
#
#   Engine_Horsepower Hydraulics Pushblock               Ripper Scarifier  \
# 0               NaN        NaN       NaN                  NaN       NaN
# 1               NaN    2 Valve       NaN                  NaN       NaN
# 2               NaN  Auxiliary       NaN                  NaN       NaN
# 3               NaN   Standard       NaN                  NaN       NaN
# 4               NaN    2 Valve       NaN  None or Unspecified       NaN
#
#   Tip_Control Tire_Size              Coupler Coupler_System Grouser_Tracks  \
# 0         NaN       NaN                  NaN            NaN            NaN
# 1         NaN      20.5  None or Unspecified            NaN            NaN
# 2         NaN       NaN  None or Unspecified            NaN            NaN
# 3         NaN       NaN  None or Unspecified            NaN            NaN
# 4         NaN       NaN                  NaN            NaN            NaN
#
#   Hydraulics_Flow Track_Type Undercarriage_Pad_Width         Stick_Length  \
# 0             NaN        NaN                     NaN                  NaN
# 1             NaN        NaN                     NaN                  NaN
# 2             NaN      Steel     None or Unspecified                9' 6"
# 3             NaN      Steel     None or Unspecified  None or Unspecified
# 4             NaN        NaN                     NaN                  NaN
#
#     Thumb      Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0     NaN                  NaN          NaN                  NaN        NaN
# 1     NaN                  NaN          NaN                  NaN        NaN
# 2  Manual  None or Unspecified       Double                  NaN        NaN
# 3  Manual                  Yes       Triple                  NaN        NaN
# 4     NaN                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  yearsold  MachineAge
# 0  Standard Digging Depth - Ft      2012          13
# 1                   Horsepower      2012        1012
# 2         Weight - Metric Tons      2012           8
# 3         Weight - Metric Tons      2012           6
# 4                          NaN      2012           7

# %% [markdown]
# ### Types of problems within the variables in the Training dataset

# %% [markdown]
# ## Missing values

# %%
# let's visualise the percentage of missing values in the Training dataset
for var in data_new1.columns:
    if data_new1[var].isnull().sum()>0:
        print(var, data_new1[var].isnull().mean())
# Out:
# auctioneerID 0.0501988158305
# MachineHoursCurrentMeter 0.644088501091
# UsageBand 0.826390775943
# fiSecondaryDesc 0.342015581178
# fiModelSeries 0.858129012153
# fiModelDescriptor 0.820706762231
# ProductSize 0.525459644749
# Drive_System 0.73982923029
# Enclosure 0.000810221252727
# Forks 0.521154253662
# Pad_Type 0.802719850421
# Ride_Control 0.629526955438
# Stick 0.802719850421
# Transmission 0.543209722655
# Turbocharged 0.802719850421
# Blade_Extension 0.937129323777
# Blade_Width 0.937129323777
# Enclosure_Type 0.937129323777
# Engine_Horsepower 0.937129323777
# Hydraulics 0.200822686195
# Pushblock 0.937129323777
# Ripper 0.740387659707
# Scarifier 0.937101900904
# Tip_Control 0.937129323777
# Tire_Size 0.763869118105
# Coupler 0.466620130882
# Coupler_System 0.891659707074
# Grouser_Tracks 0.891899033967
# Hydraulics_Flow 0.891899033967
# Track_Type 0.752812714241
# Undercarriage_Pad_Width 0.751020255531
# Stick_Length 0.752650669991
# Thumb 0.752476160798
# Pattern_Changer 0.752650669991
# Grouser_Type 0.752812714241
# Backhoe_Mounting 0.803871611094
# Blade_Type 0.80097725148
# Travel_Controls 0.800974758492
# Differential_Type 0.826959177314
# Steering_Controls 0.82706388283
# PrimarySizeBasis 0.0710426924275

# %%
# let's inspect the type of those variables with a lot of missing information in the Training dataset
for var in data_new1.columns:
    if data_new1[var].isnull().mean()>0.4:
        print(var, data_new1[var].unique())
# Out:
# MachineHoursCurrentMeter [    68.   4640.   2838. ...,   8298.  35740.  12201.]
# UsageBand ['Low' 'High' 'Medium' nan]
# fiModelSeries [nan 'II' '-6E' 'LC' '-5' 'III' '-1' '5' '-2' '1' '#NAME?' '-3L' '-20' '3'
#  '15' '-12' '6' '-6' 'V' '-3' '-3PT' '-21' '-7' '7' '-3MC' 'IV' '-21A'
#  '-3LC' '-5L' '5N' '-5H' '-1L' '-8' '4' '2' '-18' '-15' '2T' '18' 'E' '-3C'
#  '-6B' '7.00E+00' 'A' '-3LK' 'ZTS' '-2N' '12' 'V-2' 'XT' '-7E' '-2C' '-8E'
#  '-6LC' '-3H' '16' 'IV-2' '-6K' '6F' '22' '3A' 'VHP' 'LGP' 'LT' '14FT' 'EX'
#  '-6C' '3C' '-7K' '17' '1970' '-2LC' 'M' 'D' 'ZX' 'LV' '-5LC' '-5E'
#  '6.00E+00' '-17' '-16' '-4' '8' '-7B' '-1C' '-11' 'L' '-6A' 'LL' -5.0 -2.0
#  -8.0 -3.0 -7.0 2.0 'G' 'WX' '-2A' '-5F' '-3M' 'D7' '7A' ' III' 'AWS' '2B'
#  '20' '-5A' '-6LK' '-2E' 'VI' 'H' '-1B' '-3EO' 'TC' 'Elite' 'WT' 'XLT'
#  'SeriesII' '-1.50E+01' 'GALEO' '6L' '6LE' '6LK' '21KomStatII' '21KomStat'
#  '7L' 'Q' 'ZHS' 'FASTRRACK']
# fiModelDescriptor [nan 'LC' '6' 'L' 'LT' 'CR' 'SB' 'XL' 'LGP' 'VHP' '7' 'Z' '2.00E+00' 'MC'
#  'H' 'E' '3' 'LK' '5' 'K' '8' 'HT' 'LX' 'XLT' 'XW' 'HSD' '2' 'XR' 'TC'
#  'LCR' 'TLB' 'WT' 'TURBO' 'U' '4WD' 'XT' 'LRC' 'ZTS' 'RTS' 'TP' 'LE' 'LRR'
#  'SA' '3C' 'SR' 'XP' '1' 'BE' '3NO' 'CRSB' 'N' 'SSR' 'DHP' 'LM' ' SUPER'
#  'KA' 'H5' 'II' 'MH' 'P' 'LU' 'DT' 'XTV' 'LR' 'ZX' 'LL' 'V' 'DELUXE' 'USLC'
#  'SU' 'SRDZ' 'C' 'PRO' 'PLUS' 'SITEMASTER' 'DINGO' '3.00E+00' ' XLT' 'LN'
#  'AE0' 'SERIES3' '7.00E+00' 'ESL' 'A' 'G' 'B' 'DLL' 'CK' 'NSUC' 'LS' 'SLGP'
#  'RR' 'WLT' 'LCRTS' 'X' 'LCH' 'T' 'NLC' 'SM' 'SE' 'TM' 'SRLC' 'CUSTOM' 'HD'
#  'DW' 'LC8' ' LGP' 'TK' 'HF' 'SUPER K' 'IV' ' XT' 'IT' 'XLVP' 'LGPVP' 'K5'
#  '3L' '7A' 'XD' 'DA' 'Y' 'S' 'M' '6K' 'LITRONIC' 'KBNA' ' 14FT' '2N' 'III'
#  'ME' 'High Lift' 'HighLift' 'VHP/AWD' 'K3' '4x4x4' ' ZX' '(BLADE RUNNER)'
#  'AVANCE' 'GALEO' 'LongReach']
# ProductSize [nan 'Medium' 'Small' 'Large / Medium' 'Mini' 'Large' 'Compact']
# Drive_System [nan 'Four Wheel Drive' 'Two Wheel Drive' 'No' 'All Wheel Drive']
# Forks ['None or Unspecified' nan 'Yes']
# Pad_Type [nan 'None or Unspecified' 'Reversible' 'Street' 'Grouser']
# Ride_Control ['None or Unspecified' nan 'No' 'Yes']
# Stick [nan 'Extended' 'Standard']
# Transmission [nan 'Powershuttle' 'Standard' 'Powershift' 'None or Unspecified'
#  'Hydrostatic' 'Autoshift' 'Direct Drive' 'AutoShift']
# Turbocharged [nan 'None or Unspecified' 'Yes']
# Blade_Extension [nan 'Yes' 'None or Unspecified']
# Blade_Width [nan 'None or Unspecified' "12'" "14'" "13'" "16'" "<12'"]
# Enclosure_Type [nan 'None or Unspecified' 'Low Profile' 'High Profile']
# Engine_Horsepower [nan 'No' 'Variable']
# Pushblock [nan 'None or Unspecified' 'Yes']
# Ripper [nan 'None or Unspecified' 'Yes' 'Single Shank' 'Multi Shank']
# Scarifier [nan 'Yes' 'None or Unspecified']
# Tip_Control [nan 'Sideshift & Tip' 'None or Unspecified' 'Tip']
# Tire_Size ['None or Unspecified' '23.5' nan '13"' '26.5' '29.5' '14"' '20.5' '17.5"'
#  '15.5"' '20.5"' '17.5' '7.0"' '15.5' '23.5"' '10"' '23.1"' '10 inch']
# Coupler ['None or Unspecified' nan 'Manual' 'Hydraulic']
# Coupler_System [nan 'None or Unspecified' 'Yes']
# Grouser_Tracks [nan 'None or Unspecified' 'Yes']
# Hydraulics_Flow [nan 'Standard' 'High Flow' 'None or Unspecified']
# Track_Type [nan 'Steel' 'Rubber']
# Undercarriage_Pad_Width [nan 'None or Unspecified' '16 inch' '32 inch' '28 inch' '30 inch'
#  '22 inch' '24 inch' '18 inch' '36 inch' '20 inch' '27 inch' '15 inch'
#  '26 inch' '34 inch' '33 inch' '14 inch' '31 inch' '25 inch' '31.5 inch']
# Stick_Length [nan 'None or Unspecified' '11\' 0"' '15\' 9"' '10\' 2"' '10\' 6"'
#  '9\' 10"' '10\' 10"' '9\' 6"' '9\' 7"' '12\' 8"' '8\' 2"' '8\' 6"'
#  '9\' 8"' '12\' 10"' '11\' 10"' '8\' 10"' '8\' 4"' '12\' 4"' '9\' 5"'
#  '6\' 3"' '14\' 1"' '13\' 7"' '13\' 10"' '13\' 9"' '7\' 10"' '15\' 4"'
#  '9\' 2"' '24\' 3"' '19\' 8"']
# Thumb [nan 'None or Unspecified' 'Hydraulic' 'Manual']
# Pattern_Changer [nan 'None or Unspecified' 'Yes' 'No']
# Grouser_Type [nan 'Double' 'Triple' 'Single']
# Backhoe_Mounting [nan 'None or Unspecified' 'Yes']
# Blade_Type [nan 'PAT' 'None or Unspecified' 'Semi U' 'VPAT' 'Straight' 'Angle' 'No'
#  'U' 'Landfill' 'Coal']
# Travel_Controls [nan 'None or Unspecified' 'Differential Steer' 'Lever' 'Finger Tip'
#  '2 Pedal' 'Pedal' '1 Speed']
# Differential_Type ['Standard' nan 'Limited Slip' 'No Spin' 'Locking']
# Steering_Controls ['Conventional' nan 'Command Control' 'Four Wheel Standard' 'Wheel' 'No']

# %% [markdown]
# ### Types of problems within the variables in the Test dataset

# %% [markdown]
# ## Missing Values

# %%
# let's visualise the percentage of missing values in the Test dataset
for var in data_test_mer.columns:
    if data_test_mer[var].isnull().sum()>0:
        print(var, data_test_mer[var].isnull().mean())
# Out:
# MachineHoursCurrentMeter 0.829092076744
# UsageBand 0.852773540981
# fiSecondaryDesc 0.319097696074
# fiModelSeries 0.838966043189
# fiModelDescriptor 0.757244922534
# ProductSize 0.514489845067
# Drive_System 0.778518102272
# Enclosure 0.000160552299912
# Forks 0.493618046079
# Pad_Type 0.830777875893
# Ride_Control 0.659548848037
# Stick 0.830777875893
# Transmission 0.613229509513
# Turbocharged 0.830777875893
# Blade_Extension 0.947740226379
# Blade_Width 0.947740226379
# Enclosure_Type 0.947740226379
# Engine_Horsepower 0.947740226379
# Hydraulics 0.171951513205
# Pushblock 0.947740226379
# Ripper 0.782933290519
# Scarifier 0.947740226379
# Tip_Control 0.947740226379
# Tire_Size 0.776992855423
# Coupler 0.389820984186
# Coupler_System 0.834149474191
# Grouser_Tracks 0.834149474191
# Hydraulics_Flow 0.834149474191
# Track_Type 0.72754274705
# Undercarriage_Pad_Width 0.72722164245
# Stick_Length 0.72754274705
# Thumb 0.7274624709
# Pattern_Changer 0.72754274705
# Grouser_Type 0.72754274705
# Backhoe_Mounting 0.835353616441
# Blade_Type 0.834791683391
# Travel_Controls 0.834791683391
# Differential_Type 0.829092076744
# Steering_Controls 0.829092076744
# PrimarySizeBasis 0.0398972465281

# %%
# let's inspect the type of those variables with a lot of missing information in the Test dataset
for var in data_test_mer.columns:
    if data_test_mer[var].isnull().mean()>0.1:
        print(var, data_test_mer[var].unique())
# Out:
# MachineHoursCurrentMeter [  3688.  28555.   6038. ...,   5603.   2871.   2233.]
# UsageBand ['Low' 'High' 'Medium' nan]
# fiSecondaryDesc ['G' nan 'B' 'C' 'K' 'E' 'US' 'MR' 'PX' 'LC' 'M' 'SUPER L' 'SUPER M'
#  'SUPER K' 'J' 'MXT' 'N' 'H' 'D' 'Z' 'A' 'R' 'P' 'AG' 'UU' 'F' 'SE' 'XT'
#  'LX' 'SG' 'L' 'SUPER E' 'TX' 'EX' 'SRLC' 'Q' 'CH' 'LE' 'BL' 'S' 'SUPER'
#  'HZ' 'ZTS' 'X' 'B     ' 'PT' 'PS' 'NX' 'SJ' 'SR' '7' 'HD' ' MSR SPIN ACE'
#  '5A' 'ZF' 'EST' 'C      ' 'USR' 'UR' 'U' 'XTD' '3' 'T' 'TM' 'HF' 'ZHS'
#  'HAG' 'LGP' 'WT' 'TC' 'LCM' 'W' 'SX' 'WD' ' ZTS' 'UNA' 'H      ' '-7A'
#  'BZD' 'DL' 'CS' 'DZ' 'EG']
# fiModelSeries [nan '-5' 'IV' 'LC' '8' '-6' '-3MC' '-12' '5' '6' '-1L' '-3L' '-1' 'II' 'V'
#  '-5L' '-2' '3' '-6E' 'III' '7' '2' '1' 'ZTS' '7.00E+00' '-3LK' '-7' '-3'
#  '-7E' '-15' '#NAME?' '-21' '-2C' '-16' 'LGP' 'WT' 'XT' 'L' 'XLT' '-18'
#  '6LE' '-2N' '15' '-20' '2T' 'LT' '-3C' 'E' '-5E' 'A' '4' ' III' 'IV-2'
#  'V-2' '-8' '-3PT' 'AWS' '-3EO' '-3LC' '2B' '22' 'XR' '7A' '17']
# fiModelDescriptor [nan 'LC' 'L' '2' '4WD' 'LK' 'LCR' 'LGP' 'XL' 'BE' 'LCH' 'CR' 'LT' 'XT' '3'
#  '7' 'K' '5' '6' 'SR' 'H' 'E' 'LRC' 'LE' 'XW' 'N' 'Y' 'CRSB' 'XTV' '3C'
#  'II' 'WT' 'XLT' 'VHP' 'III' 'Z' 'TC' 'ZTS' 'A' 'HT' 'C' 'AVANCE'
#  '2.00E+00' '8' 'LX' '3NO' ' LGP' 'LRR' 'TLB' 'RTS' 'ESL' 'SSR' 'LS' 'LN'
#  'LU' 'SB' 'IV' 'XP' 'W' 'DA' 'KA' 'HST' 'XR' 'MH' 'ZX' 'SRLC' 'SRDZ' 'WLT'
#  '(BLADE RUNNER)' 'CL' 'PLUS' 'XD' '1' 'MC' 'PRO']
# ProductSize [nan 'Medium' 'Large / Medium' 'Small' 'Large' 'Mini' 'Compact']
# Drive_System ['Two Wheel Drive' nan 'Four Wheel Drive' 'No' 'All Wheel Drive']
# Forks ['Yes' nan 'None or Unspecified']
# Pad_Type ['None or Unspecified' nan 'Reversible' 'Street' 'Grouser']
# Ride_Control ['No' 'None or Unspecified' nan 'Yes']
# Stick ['Standard' nan 'Extended']
# Transmission ['Standard' nan 'Hydrostatic' 'Powershift' 'Powershuttle'
#  'None or Unspecified' 'Direct Drive' 'Autoshift']
# Turbocharged ['None or Unspecified' nan 'Yes']
# Blade_Extension [nan 'None or Unspecified' 'Yes']
# Blade_Width [nan "14'" 'None or Unspecified' "12'" "<12'" "16'" "13'"]
# Enclosure_Type [nan 'None or Unspecified' 'High Profile' 'Low Profile']
# Engine_Horsepower [nan 'No' 'Variable']
# Hydraulics [nan '2 Valve' 'Auxiliary' 'Standard' '3 Valve' 'Base + 1 Function'
#  '4 Valve' 'Base + 4 Function' 'Base + 3 Function' 'Base + 2 Function'
#  'Base + 5 Function' 'Base + 6 Function']
# Pushblock [nan 'None or Unspecified' 'Yes']
# Ripper [nan 'None or Unspecified' 'Single Shank' 'Yes' 'Multi Shank']
# Scarifier [nan 'Yes' 'None or Unspecified']
# Tip_Control [nan 'None or Unspecified' 'Sideshift & Tip' 'Tip']
# Tire_Size [nan '20.5' '17.5' '23.5' '26.5' '17.5"' 'None or Unspecified' '14"' '29.5'
#  '15.5"' '13"' '20.5"' '15.5' '23.5"']
# Coupler [nan 'None or Unspecified' 'Hydraulic' 'Manual']
# Coupler_System [nan 'Yes' 'None or Unspecified']
# Grouser_Tracks [nan 'None or Unspecified' 'Yes']
# Hydraulics_Flow [nan 'Standard' 'High Flow' 'None or Unspecified']
# Track_Type [nan 'Steel' 'Rubber']
# Undercarriage_Pad_Width [nan 'None or Unspecified' '34 inch' '36 inch' '14 inch' '24 inch'
#  '32 inch' '16 inch' '20 inch' '27 inch' '28 inch' '30 inch' '31 inch'
#  '26 inch' '18 inch' '33 inch' '22 inch' '25 inch']
# Stick_Length [nan '9\' 6"' 'None or Unspecified' '9\' 8"' '9\' 10"' '10\' 2"' '11\' 0"'
#  '8\' 2"' '10\' 6"' '9\' 7"' '10\' 10"' '12\' 8"' '12\' 10"' '8\' 6"'
#  '11\' 10"' '8\' 10"' '8\' 4"' '12\' 4"' '13\' 10"' '9\' 5"' '15\' 9"']
# Thumb [nan 'Manual' 'None or Unspecified' 'Hydraulic']
# Pattern_Changer [nan 'None or Unspecified' 'Yes']
# Grouser_Type [nan 'Double' 'Triple']
# Backhoe_Mounting [nan 'None or Unspecified']
# Blade_Type [nan 'PAT' 'None or Unspecified' 'Semi U' 'Straight' 'No' 'U' 'Angle'
#  'VPAT']
# Travel_Controls [nan 'None or Unspecified' 'Differential Steer' 'Lever' '2 Pedal'
#  'Finger Tip' 'Pedal']
# Differential_Type [nan 'Standard' 'Limited Slip' 'No Spin']
# Steering_Controls [nan 'Conventional' 'Command Control' 'Four Wheel Standard']

# %% [markdown]
# ** There are alot of variables with missing data in both the Training set and Test set and the variables are all categorical**

# %% [markdown]
# ## Deleting superfluous variables from the Training and Test sets

# %%
# Deleting meaningless variables from the Training setdat
data_new1.drop(['yearsold','MachineID','ModelID','datasource','auctioneerID','YearMade','saledate','fiModelDesc','fiModelDescriptor','fiProductClassDesc'], axis=1,inplace=True)

# %%
data_new1.head()
# Out:
#    SalesID  SalePrice  MachineHoursCurrentMeter UsageBand fiBaseModel  \
# 0  1139246      66000                      68.0       Low         521
# 1  1139248      57000                    4640.0       Low         950
# 2  1139249      10000                    2838.0      High         226
# 3  1139251      38500                    3486.0      High       PC120
# 4  1139253      11000                     722.0    Medium        S175
#
#   fiSecondaryDesc fiModelSeries ProductSize           state ProductGroup  \
# 0               D           NaN         NaN         Alabama           WL
# 1               F            II      Medium  North Carolina           WL
# 2             NaN           NaN         NaN        New York          SSL
# 3             NaN           -6E       Small           Texas          TEX
# 4             NaN           NaN         NaN        New York          SSL
#
#      ProductGroupDesc Drive_System   Enclosure                Forks Pad_Type  \
# 0        Wheel Loader          NaN  EROPS w AC  None or Unspecified      NaN
# 1        Wheel Loader          NaN  EROPS w AC  None or Unspecified      NaN
# 2  Skid Steer Loaders          NaN       OROPS  None or Unspecified      NaN
# 3    Track Excavators          NaN  EROPS w AC                  NaN      NaN
# 4  Skid Steer Loaders          NaN       EROPS  None or Unspecified      NaN
#
#           Ride_Control Stick Transmission Turbocharged Blade_Extension  \
# 0  None or Unspecified   NaN          NaN          NaN             NaN
# 1  None or Unspecified   NaN          NaN          NaN             NaN
# 2                  NaN   NaN          NaN          NaN             NaN
# 3                  NaN   NaN          NaN          NaN             NaN
# 4                  NaN   NaN          NaN          NaN             NaN
#
#   Blade_Width Enclosure_Type Engine_Horsepower Hydraulics Pushblock Ripper  \
# 0         NaN            NaN               NaN    2 Valve       NaN    NaN
# 1         NaN            NaN               NaN    2 Valve       NaN    NaN
# 2         NaN            NaN               NaN  Auxiliary       NaN    NaN
# 3         NaN            NaN               NaN    2 Valve       NaN    NaN
# 4         NaN            NaN               NaN  Auxiliary       NaN    NaN
#
#   Scarifier Tip_Control            Tire_Size              Coupler  \
# 0       NaN         NaN  None or Unspecified  None or Unspecified
# 1       NaN         NaN                 23.5  None or Unspecified
# 2       NaN         NaN                  NaN  None or Unspecified
# 3       NaN         NaN                  NaN  None or Unspecified
# 4       NaN         NaN                  NaN  None or Unspecified
#
#         Coupler_System       Grouser_Tracks Hydraulics_Flow Track_Type  \
# 0                  NaN                  NaN             NaN        NaN
# 1                  NaN                  NaN             NaN        NaN
# 2  None or Unspecified  None or Unspecified        Standard        NaN
# 3                  NaN                  NaN             NaN        NaN
# 4  None or Unspecified  None or Unspecified        Standard        NaN
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# 2                     NaN          NaN   NaN             NaN          NaN
# 3                     NaN          NaN   NaN             NaN          NaN
# 4                     NaN          NaN   NaN             NaN          NaN
#
#   Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 0              NaN        NaN             NaN          Standard
# 1              NaN        NaN             NaN          Standard
# 2              NaN        NaN             NaN               NaN
# 3              NaN        NaN             NaN               NaN
# 4              NaN        NaN             NaN               NaN
#
#   Steering_Controls          PrimarySizeBasis  MachineAge
# 0      Conventional                Horsepower           2
# 1      Conventional                Horsepower           8
# 2               NaN  Operating Capacity - Lbs           3
# 3               NaN                       NaN          10
# 4               NaN  Operating Capacity - Lbs           2

# %%
#Deleting meaningless variables from the Test set
data_test_mer.drop(['yearsold','MachineID','ModelID','datasource','auctioneerID','YearMade','saledate','fiModelDesc','fiModelDescriptor','fiProductClassDesc'], axis=1,inplace=True)

# %%
# Checking that it worked
data_test_mer.head()
# Out:
#    SalesID  MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0  1227829                    3688.0       Low         580               G
# 1  1227844                   28555.0      High         936             NaN
# 2  1227847                    6038.0    Medium       EC210               B
# 3  1227848                    8940.0      High         330               C
# 4  1227863                    2286.0       Low         650               K
#
#   fiModelSeries     ProductSize       state ProductGroup     ProductGroupDesc  \
# 0           NaN             NaN     Wyoming           BL      Backhoe Loaders
# 1           NaN          Medium    Virginia           WL         Wheel Loader
# 2           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 3           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 4           NaN             NaN     Florida          TTT  Track Type Tractors
#
#       Drive_System   Enclosure Forks             Pad_Type  \
# 0  Two Wheel Drive       OROPS   Yes  None or Unspecified
# 1              NaN       EROPS   Yes                  NaN
# 2              NaN  EROPS w AC   NaN                  NaN
# 3              NaN  EROPS w AC   NaN                  NaN
# 4              NaN       OROPS   NaN                  NaN
#
#           Ride_Control     Stick Transmission         Turbocharged  \
# 0                   No  Standard     Standard  None or Unspecified
# 1  None or Unspecified       NaN          NaN                  NaN
# 2                  NaN       NaN          NaN                  NaN
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN  Hydrostatic                  NaN
#
#   Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower Hydraulics  \
# 0             NaN         NaN            NaN               NaN        NaN
# 1             NaN         NaN            NaN               NaN    2 Valve
# 2             NaN         NaN            NaN               NaN  Auxiliary
# 3             NaN         NaN            NaN               NaN   Standard
# 4             NaN         NaN            NaN               NaN    2 Valve
#
#   Pushblock               Ripper Scarifier Tip_Control Tire_Size  \
# 0       NaN                  NaN       NaN         NaN       NaN
# 1       NaN                  NaN       NaN         NaN      20.5
# 2       NaN                  NaN       NaN         NaN       NaN
# 3       NaN                  NaN       NaN         NaN       NaN
# 4       NaN  None or Unspecified       NaN         NaN       NaN
#
#                Coupler Coupler_System Grouser_Tracks Hydraulics_Flow  \
# 0                  NaN            NaN            NaN             NaN
# 1  None or Unspecified            NaN            NaN             NaN
# 2  None or Unspecified            NaN            NaN             NaN
# 3  None or Unspecified            NaN            NaN             NaN
# 4                  NaN            NaN            NaN             NaN
#
#   Track_Type Undercarriage_Pad_Width         Stick_Length   Thumb  \
# 0        NaN                     NaN                  NaN     NaN
# 1        NaN                     NaN                  NaN     NaN
# 2      Steel     None or Unspecified                9' 6"  Manual
# 3      Steel     None or Unspecified  None or Unspecified  Manual
# 4        NaN                     NaN                  NaN     NaN
#
#        Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0                  NaN          NaN                  NaN        NaN
# 1                  NaN          NaN                  NaN        NaN
# 2  None or Unspecified       Double                  NaN        NaN
# 3                  Yes       Triple                  NaN        NaN
# 4                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  MachineAge
# 0  Standard Digging Depth - Ft          13
# 1                   Horsepower        1012
# 2         Weight - Metric Tons           8
# 3         Weight - Metric Tons           6
# 4                          NaN           7

# %%
# Splitting the Training set in label and features
y_Train = data_new1['SalePrice']

# %%
#Checking
y_Train.shape
# Out:
# (401125,)

# %%
# Checking the first 5 rows dependent variable
y_Train.head()
# Out:
# 0    66000
# 1    57000
# 2    10000
# 3    38500
# 4    11000
# Name: SalePrice, dtype: int64

# %%
x_Train = data_new1

# %%
# Creating a separate dataset for submission to Kaggle
Submission=x_Train.copy

# %%
x_Train.head()
# Out:
#    SalesID  SalePrice  MachineHoursCurrentMeter UsageBand fiBaseModel  \
# 0  1139246      66000                      68.0       Low         521
# 1  1139248      57000                    4640.0       Low         950
# 2  1139249      10000                    2838.0      High         226
# 3  1139251      38500                    3486.0      High       PC120
# 4  1139253      11000                     722.0    Medium        S175
#
#   fiSecondaryDesc fiModelSeries ProductSize           state ProductGroup  \
# 0               D           NaN         NaN         Alabama           WL
# 1               F            II      Medium  North Carolina           WL
# 2             NaN           NaN         NaN        New York          SSL
# 3             NaN           -6E       Small           Texas          TEX
# 4             NaN           NaN         NaN        New York          SSL
#
#      ProductGroupDesc Drive_System   Enclosure                Forks Pad_Type  \
# 0        Wheel Loader          NaN  EROPS w AC  None or Unspecified      NaN
# 1        Wheel Loader          NaN  EROPS w AC  None or Unspecified      NaN
# 2  Skid Steer Loaders          NaN       OROPS  None or Unspecified      NaN
# 3    Track Excavators          NaN  EROPS w AC                  NaN      NaN
# 4  Skid Steer Loaders          NaN       EROPS  None or Unspecified      NaN
#
#           Ride_Control Stick Transmission Turbocharged Blade_Extension  \
# 0  None or Unspecified   NaN          NaN          NaN             NaN
# 1  None or Unspecified   NaN          NaN          NaN             NaN
# 2                  NaN   NaN          NaN          NaN             NaN
# 3                  NaN   NaN          NaN          NaN             NaN
# 4                  NaN   NaN          NaN          NaN             NaN
#
#   Blade_Width Enclosure_Type Engine_Horsepower Hydraulics Pushblock Ripper  \
# 0         NaN            NaN               NaN    2 Valve       NaN    NaN
# 1         NaN            NaN               NaN    2 Valve       NaN    NaN
# 2         NaN            NaN               NaN  Auxiliary       NaN    NaN
# 3         NaN            NaN               NaN    2 Valve       NaN    NaN
# 4         NaN            NaN               NaN  Auxiliary       NaN    NaN
#
#   Scarifier Tip_Control            Tire_Size              Coupler  \
# 0       NaN         NaN  None or Unspecified  None or Unspecified
# 1       NaN         NaN                 23.5  None or Unspecified
# 2       NaN         NaN                  NaN  None or Unspecified
# 3       NaN         NaN                  NaN  None or Unspecified
# 4       NaN         NaN                  NaN  None or Unspecified
#
#         Coupler_System       Grouser_Tracks Hydraulics_Flow Track_Type  \
# 0                  NaN                  NaN             NaN        NaN
# 1                  NaN                  NaN             NaN        NaN
# 2  None or Unspecified  None or Unspecified        Standard        NaN
# 3                  NaN                  NaN             NaN        NaN
# 4  None or Unspecified  None or Unspecified        Standard        NaN
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# 2                     NaN          NaN   NaN             NaN          NaN
# 3                     NaN          NaN   NaN             NaN          NaN
# 4                     NaN          NaN   NaN             NaN          NaN
#
#   Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 0              NaN        NaN             NaN          Standard
# 1              NaN        NaN             NaN          Standard
# 2              NaN        NaN             NaN               NaN
# 3              NaN        NaN             NaN               NaN
# 4              NaN        NaN             NaN               NaN
#
#   Steering_Controls          PrimarySizeBasis  MachineAge
# 0      Conventional                Horsepower           2
# 1      Conventional                Horsepower           8
# 2               NaN  Operating Capacity - Lbs           3
# 3               NaN                       NaN          10
# 4               NaN  Operating Capacity - Lbs           2

# %%
x_Test = data_test_mer

# %%
#Checking 
x_Test.head()
# Out:
#    SalesID  MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0  1227829                    3688.0       Low         580               G
# 1  1227844                   28555.0      High         936             NaN
# 2  1227847                    6038.0    Medium       EC210               B
# 3  1227848                    8940.0      High         330               C
# 4  1227863                    2286.0       Low         650               K
#
#   fiModelSeries     ProductSize       state ProductGroup     ProductGroupDesc  \
# 0           NaN             NaN     Wyoming           BL      Backhoe Loaders
# 1           NaN          Medium    Virginia           WL         Wheel Loader
# 2           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 3           NaN  Large / Medium  New Jersey          TEX     Track Excavators
# 4           NaN             NaN     Florida          TTT  Track Type Tractors
#
#       Drive_System   Enclosure Forks             Pad_Type  \
# 0  Two Wheel Drive       OROPS   Yes  None or Unspecified
# 1              NaN       EROPS   Yes                  NaN
# 2              NaN  EROPS w AC   NaN                  NaN
# 3              NaN  EROPS w AC   NaN                  NaN
# 4              NaN       OROPS   NaN                  NaN
#
#           Ride_Control     Stick Transmission         Turbocharged  \
# 0                   No  Standard     Standard  None or Unspecified
# 1  None or Unspecified       NaN          NaN                  NaN
# 2                  NaN       NaN          NaN                  NaN
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN  Hydrostatic                  NaN
#
#   Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower Hydraulics  \
# 0             NaN         NaN            NaN               NaN        NaN
# 1             NaN         NaN            NaN               NaN    2 Valve
# 2             NaN         NaN            NaN               NaN  Auxiliary
# 3             NaN         NaN            NaN               NaN   Standard
# 4             NaN         NaN            NaN               NaN    2 Valve
#
#   Pushblock               Ripper Scarifier Tip_Control Tire_Size  \
# 0       NaN                  NaN       NaN         NaN       NaN
# 1       NaN                  NaN       NaN         NaN      20.5
# 2       NaN                  NaN       NaN         NaN       NaN
# 3       NaN                  NaN       NaN         NaN       NaN
# 4       NaN  None or Unspecified       NaN         NaN       NaN
#
#                Coupler Coupler_System Grouser_Tracks Hydraulics_Flow  \
# 0                  NaN            NaN            NaN             NaN
# 1  None or Unspecified            NaN            NaN             NaN
# 2  None or Unspecified            NaN            NaN             NaN
# 3  None or Unspecified            NaN            NaN             NaN
# 4                  NaN            NaN            NaN             NaN
#
#   Track_Type Undercarriage_Pad_Width         Stick_Length   Thumb  \
# 0        NaN                     NaN                  NaN     NaN
# 1        NaN                     NaN                  NaN     NaN
# 2      Steel     None or Unspecified                9' 6"  Manual
# 3      Steel     None or Unspecified  None or Unspecified  Manual
# 4        NaN                     NaN                  NaN     NaN
#
#        Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0                  NaN          NaN                  NaN        NaN
# 1                  NaN          NaN                  NaN        NaN
# 2  None or Unspecified       Double                  NaN        NaN
# 3                  Yes       Triple                  NaN        NaN
# 4                  NaN          NaN  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0                  NaN               NaN               NaN
# 1                  NaN          Standard      Conventional
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4  None or Unspecified               NaN               NaN
#
#               PrimarySizeBasis  MachineAge
# 0  Standard Digging Depth - Ft          13
# 1                   Horsepower        1012
# 2         Weight - Metric Tons           8
# 3         Weight - Metric Tons           6
# 4                          NaN           7

# %%
x_Train.shape, x_Test.shape
# Out:
# ((401125, 46), (12457, 45))

# %%
x_Train.shape, x_Test.shape
# Out:
# ((401125, 46), (12457, 45))

# %%
# find categorical variables in the Training set
categorical_train = [var for var in x_Train.columns if x_Train[var].dtype=='O']
print('There are {} categorical variables in the Training set'.format(len(categorical_train)))
# Out:
# There are 42 categorical variables in the Training set

# %%
# find numerical variables
numerical_train = [var for var in x_Train.columns if x_Train[var].dtype!='O']
print('There are {} numerical variables in the Training set'.format(len(numerical_train)))
# Out:
# There are 4 numerical variables in the Training set

# %%
# find categorical variables in the Test set
categorical_test = [var for var in x_Test.columns if x_Test[var].dtype=='O']
print('There are {} categorical variables in the Test set'.format(len(categorical_test)))
# Out:
# There are 42 categorical variables in the Test set

# %%
# find numerical variables in the Test set
numerical_test = [var for var in x_Test.columns if x_Test[var].dtype!='O']
print('There are {} numerical variables in the Test set'.format(len(numerical_test)))
# Out:
# There are 3 numerical variables in the Test set

# %% [markdown]
# ## Outliers

# %%
continuous_train = [var for var in numerical_train if var not in [ 'SalesID','SalePrice']]
continuous_train
# Out:
# ['MachineHoursCurrentMeter', 'MachineAge']

# %%
continuous_test = [var for var in numerical_test if var not in [ 'SalesID','SalePrice']]
continuous_test
# Out:
# ['MachineHoursCurrentMeter', 'MachineAge']

# %%
# let's make boxplots to visualise outliers in the continuous variables 
# and histograms to get an idea of the distribution in the Training set

for var in continuous_train:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = x_Train.boxplot(column=var)
    fig.set_title('')
    fig.set_ylabel(var)
    
    plt.subplot(1, 2, 2)
    fig = x_Train[var].hist(bins=20)
    fig.set_ylabel('Number of Buldozers')
    fig.set_xlabel(var)

    plt.show()

# %%
# let's make boxplots to visualise outliers in the continuous variables 
# and histograms to get an idea of the distribution in the Test set

for var in continuous_test:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = x_Test.boxplot(column=var)
    fig.set_title('')
    fig.set_ylabel(var)
    
    plt.subplot(1, 2, 2)
    fig = x_Test[var].hist(bins=20)
    fig.set_ylabel('Number of Buldozers')
    fig.set_xlabel(var)

    plt.show()

# %% [markdown]
# All of the continuous variables seem to contain outliers. In addition, the variables are not normally distributed. If we are planning to build linear regression, we might need to tackle these to improve the model performance. To tackle the 2 aspects together, I will do discretisation. And in particular, **I will use trees to find the right buckets onto which I will divide the variables.**

# %% [markdown]
# Note: there exist no discrete variables in the datasets.
#
#
# #### Number of labels: cardinality

# %%
# Examining the number of labels for the categorical variables in the Training set
for var in categorical_train:
    print(var, ' contains ', len(x_Train[var].unique()), ' labels')
# Out:
# UsageBand  contains  4  labels
# fiBaseModel  contains  1950  labels
# fiSecondaryDesc  contains  176  labels
# fiModelSeries  contains  129  labels
# ProductSize  contains  7  labels
# state  contains  53  labels
# ProductGroup  contains  6  labels
# ProductGroupDesc  contains  6  labels
# Drive_System  contains  5  labels
# Enclosure  contains  7  labels
# Forks  contains  3  labels
# Pad_Type  contains  5  labels
# Ride_Control  contains  4  labels
# Stick  contains  3  labels
# Transmission  contains  9  labels
# Turbocharged  contains  3  labels
# Blade_Extension  contains  3  labels
# Blade_Width  contains  7  labels
# Enclosure_Type  contains  4  labels
# Engine_Horsepower  contains  3  labels
# Hydraulics  contains  13  labels
# Pushblock  contains  3  labels
# Ripper  contains  5  labels
# Scarifier  contains  3  labels
# Tip_Control  contains  4  labels
# Tire_Size  contains  18  labels
# Coupler  contains  4  labels
# Coupler_System  contains  3  labels
# Grouser_Tracks  contains  3  labels
# Hydraulics_Flow  contains  4  labels
# Track_Type  contains  3  labels
# Undercarriage_Pad_Width  contains  20  labels
# Stick_Length  contains  30  labels
# Thumb  contains  4  labels
# Pattern_Changer  contains  4  labels
# Grouser_Type  contains  4  labels
# Backhoe_Mounting  contains  3  labels
# Blade_Type  contains  11  labels
# Travel_Controls  contains  8  labels
# Differential_Type  contains  5  labels
# Steering_Controls  contains  6  labels
# PrimarySizeBasis  contains  5  labels

# %%
# Examining the number of labels for the categorical variables in the Test set
for var in categorical_test:
    print(var, ' contains ', len(x_Test[var].unique()), ' labels')
# Out:
# UsageBand  contains  4  labels
# fiBaseModel  contains  831  labels
# fiSecondaryDesc  contains  83  labels
# fiModelSeries  contains  64  labels
# ProductSize  contains  7  labels
# state  contains  51  labels
# ProductGroup  contains  6  labels
# ProductGroupDesc  contains  6  labels
# Drive_System  contains  5  labels
# Enclosure  contains  4  labels
# Forks  contains  3  labels
# Pad_Type  contains  5  labels
# Ride_Control  contains  4  labels
# Stick  contains  3  labels
# Transmission  contains  8  labels
# Turbocharged  contains  3  labels
# Blade_Extension  contains  3  labels
# Blade_Width  contains  7  labels
# Enclosure_Type  contains  4  labels
# Engine_Horsepower  contains  3  labels
# Hydraulics  contains  12  labels
# Pushblock  contains  3  labels
# Ripper  contains  5  labels
# Scarifier  contains  3  labels
# Tip_Control  contains  4  labels
# Tire_Size  contains  14  labels
# Coupler  contains  4  labels
# Coupler_System  contains  3  labels
# Grouser_Tracks  contains  3  labels
# Hydraulics_Flow  contains  4  labels
# Track_Type  contains  3  labels
# Undercarriage_Pad_Width  contains  18  labels
# Stick_Length  contains  21  labels
# Thumb  contains  4  labels
# Pattern_Changer  contains  3  labels
# Grouser_Type  contains  3  labels
# Backhoe_Mounting  contains  2  labels
# Blade_Type  contains  9  labels
# Travel_Controls  contains  7  labels
# Differential_Type  contains  4  labels
# Steering_Controls  contains  4  labels
# PrimarySizeBasis  contains  5  labels

# %% [markdown]
# Most of the variables have variables do not have a lot of labels, but some have very high levels of cardinality.

# %% [markdown]
# ### Engineering missing values in numerical variables
# #### Continuous variables

# %%
# print variables with missing data in Training set
for col in continuous_train:
    if x_Train[col].isnull().mean()>0:
        print(col, x_Train[col].isnull().mean())
# Out:
# MachineHoursCurrentMeter 0.644088501091

# %%
# print variables with missing data in Test set
for col in continuous_test:
    if x_Test[col].isnull().mean()>0:
        print(col, x_Test[col].isnull().mean())
# Out:
# MachineHoursCurrentMeter 0.829092076744

# %% [markdown]
# - If a variable contains < 50% NA: create additional variable with NA + random sample imputation
# - If a variable contains > 50% NA: impute NA by value far in the distribution

# %%
# MachineHoursCurrentMeter 
extreme = x_Train.MachineHoursCurrentMeter.mean() + x_Train.MachineHoursCurrentMeter.std()*3
for df in [x_Train, x_Test]:
    df.MachineHoursCurrentMeter.fillna(extreme, inplace=True)

# %% [markdown]
# ### Engineering Missing Data in categorical variables

# %%
# print variables with missing data in Training set
for col in categorical_train:
    if x_Train[col].isnull().mean()>0:
        print(col, x_Train[col].isnull().mean())
# Out:
# UsageBand 0.826390775943
# fiSecondaryDesc 0.342015581178
# fiModelSeries 0.858129012153
# ProductSize 0.525459644749
# Drive_System 0.73982923029
# Enclosure 0.000810221252727
# Forks 0.521154253662
# Pad_Type 0.802719850421
# Ride_Control 0.629526955438
# Stick 0.802719850421
# Transmission 0.543209722655
# Turbocharged 0.802719850421
# Blade_Extension 0.937129323777
# Blade_Width 0.937129323777
# Enclosure_Type 0.937129323777
# Engine_Horsepower 0.937129323777
# Hydraulics 0.200822686195
# Pushblock 0.937129323777
# Ripper 0.740387659707
# Scarifier 0.937101900904
# Tip_Control 0.937129323777
# Tire_Size 0.763869118105
# Coupler 0.466620130882
# Coupler_System 0.891659707074
# Grouser_Tracks 0.891899033967
# Hydraulics_Flow 0.891899033967
# Track_Type 0.752812714241
# Undercarriage_Pad_Width 0.751020255531
# Stick_Length 0.752650669991
# Thumb 0.752476160798
# Pattern_Changer 0.752650669991
# Grouser_Type 0.752812714241
# Backhoe_Mounting 0.803871611094
# Blade_Type 0.80097725148
# Travel_Controls 0.800974758492
# Differential_Type 0.826959177314
# Steering_Controls 0.82706388283
# PrimarySizeBasis 0.0710426924275

# %% [markdown]
# - If a variable has low NA then NA imputed by most frequent category
# - If a variable has high NA imputed by 'Missing'

# %%
# Imputing missing data in Training and Test sets with the word "Missing"
for col in categorical_train:
    if x_Train[col].isnull().mean()<.08:
        for df in [x_Train, x_Test]:
            df[col].fillna(x_Train[col].mode()[0], inplace=True) 
    else:
        for df in [x_Train, x_Test]:
            df[col].fillna('Missing', inplace=True)

# %%
# check absence of null values
x_Train.isnull().sum()
# Out:
# SalesID                     0
# SalePrice                   0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# ProductSize                 0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# PrimarySizeBasis            0
# MachineAge                  0
# dtype: int64

# %%
# Checking the test set for missing values
x_Test.isnull().sum()
# Out:
# SalesID                     0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# ProductSize                 0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# Engine_Horsepower           0
# Hydraulics                  0
# Pushblock                   0
# Ripper                      0
# Scarifier                   0
# Tip_Control                 0
# Tire_Size                   0
# Coupler                     0
# Coupler_System              0
# Grouser_Tracks              0
# Hydraulics_Flow             0
# Track_Type                  0
# Undercarriage_Pad_Width     0
# Stick_Length                0
# Thumb                       0
# Pattern_Changer             0
# Grouser_Type                0
# Backhoe_Mounting            0
# Blade_Type                  0
# Travel_Controls             0
# Differential_Type           0
# Steering_Controls           0
# PrimarySizeBasis            0
# MachineAge                  0
# dtype: int64

# %%
# Checking Training set after imputation
x_Train.head()
# Out:
#    SalesID  SalePrice  MachineHoursCurrentMeter UsageBand fiBaseModel  \
# 0  1139246      66000                      68.0       Low         521
# 1  1139248      57000                    4640.0       Low         950
# 2  1139249      10000                    2838.0      High         226
# 3  1139251      38500                    3486.0      High       PC120
# 4  1139253      11000                     722.0    Medium        S175
#
#   fiSecondaryDesc fiModelSeries ProductSize           state ProductGroup  \
# 0               D       Missing     Missing         Alabama           WL
# 1               F            II      Medium  North Carolina           WL
# 2         Missing       Missing     Missing        New York          SSL
# 3         Missing           -6E       Small           Texas          TEX
# 4         Missing       Missing     Missing        New York          SSL
#
#      ProductGroupDesc Drive_System   Enclosure                Forks Pad_Type  \
# 0        Wheel Loader      Missing  EROPS w AC  None or Unspecified  Missing
# 1        Wheel Loader      Missing  EROPS w AC  None or Unspecified  Missing
# 2  Skid Steer Loaders      Missing       OROPS  None or Unspecified  Missing
# 3    Track Excavators      Missing  EROPS w AC              Missing  Missing
# 4  Skid Steer Loaders      Missing       EROPS  None or Unspecified  Missing
#
#           Ride_Control    Stick Transmission Turbocharged Blade_Extension  \
# 0  None or Unspecified  Missing      Missing      Missing         Missing
# 1  None or Unspecified  Missing      Missing      Missing         Missing
# 2              Missing  Missing      Missing      Missing         Missing
# 3              Missing  Missing      Missing      Missing         Missing
# 4              Missing  Missing      Missing      Missing         Missing
#
#   Blade_Width Enclosure_Type Engine_Horsepower Hydraulics Pushblock   Ripper  \
# 0     Missing        Missing           Missing    2 Valve   Missing  Missing
# 1     Missing        Missing           Missing    2 Valve   Missing  Missing
# 2     Missing        Missing           Missing  Auxiliary   Missing  Missing
# 3     Missing        Missing           Missing    2 Valve   Missing  Missing
# 4     Missing        Missing           Missing  Auxiliary   Missing  Missing
#
#   Scarifier Tip_Control            Tire_Size              Coupler  \
# 0   Missing     Missing  None or Unspecified  None or Unspecified
# 1   Missing     Missing                 23.5  None or Unspecified
# 2   Missing     Missing              Missing  None or Unspecified
# 3   Missing     Missing              Missing  None or Unspecified
# 4   Missing     Missing              Missing  None or Unspecified
#
#         Coupler_System       Grouser_Tracks Hydraulics_Flow Track_Type  \
# 0              Missing              Missing         Missing    Missing
# 1              Missing              Missing         Missing    Missing
# 2  None or Unspecified  None or Unspecified        Standard    Missing
# 3              Missing              Missing         Missing    Missing
# 4  None or Unspecified  None or Unspecified        Standard    Missing
#
#   Undercarriage_Pad_Width Stick_Length    Thumb Pattern_Changer Grouser_Type  \
# 0                 Missing      Missing  Missing         Missing      Missing
# 1                 Missing      Missing  Missing         Missing      Missing
# 2                 Missing      Missing  Missing         Missing      Missing
# 3                 Missing      Missing  Missing         Missing      Missing
# 4                 Missing      Missing  Missing         Missing      Missing
#
#   Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 0          Missing    Missing         Missing          Standard
# 1          Missing    Missing         Missing          Standard
# 2          Missing    Missing         Missing           Missing
# 3          Missing    Missing         Missing           Missing
# 4          Missing    Missing         Missing           Missing
#
#   Steering_Controls          PrimarySizeBasis  MachineAge
# 0      Conventional                Horsepower           2
# 1      Conventional                Horsepower           8
# 2           Missing  Operating Capacity - Lbs           3
# 3           Missing                Horsepower          10
# 4           Missing  Operating Capacity - Lbs           2

# %%
# Checking Test set after imputation
x_Test.head()
# Out:
#    SalesID  MachineHoursCurrentMeter UsageBand fiBaseModel fiSecondaryDesc  \
# 0  1227829                    3688.0       Low         580               G
# 1  1227844                   28555.0      High         936         Missing
# 2  1227847                    6038.0    Medium       EC210               B
# 3  1227848                    8940.0      High         330               C
# 4  1227863                    2286.0       Low         650               K
#
#   fiModelSeries     ProductSize       state ProductGroup     ProductGroupDesc  \
# 0       Missing         Missing     Wyoming           BL      Backhoe Loaders
# 1       Missing          Medium    Virginia           WL         Wheel Loader
# 2       Missing  Large / Medium  New Jersey          TEX     Track Excavators
# 3       Missing  Large / Medium  New Jersey          TEX     Track Excavators
# 4       Missing         Missing     Florida          TTT  Track Type Tractors
#
#       Drive_System   Enclosure    Forks             Pad_Type  \
# 0  Two Wheel Drive       OROPS      Yes  None or Unspecified
# 1          Missing       EROPS      Yes              Missing
# 2          Missing  EROPS w AC  Missing              Missing
# 3          Missing  EROPS w AC  Missing              Missing
# 4          Missing       OROPS  Missing              Missing
#
#           Ride_Control     Stick Transmission         Turbocharged  \
# 0                   No  Standard     Standard  None or Unspecified
# 1  None or Unspecified   Missing      Missing              Missing
# 2              Missing   Missing      Missing              Missing
# 3              Missing   Missing      Missing              Missing
# 4              Missing   Missing  Hydrostatic              Missing
#
#   Blade_Extension Blade_Width Enclosure_Type Engine_Horsepower Hydraulics  \
# 0         Missing     Missing        Missing           Missing    Missing
# 1         Missing     Missing        Missing           Missing    2 Valve
# 2         Missing     Missing        Missing           Missing  Auxiliary
# 3         Missing     Missing        Missing           Missing   Standard
# 4         Missing     Missing        Missing           Missing    2 Valve
#
#   Pushblock               Ripper Scarifier Tip_Control Tire_Size  \
# 0   Missing              Missing   Missing     Missing   Missing
# 1   Missing              Missing   Missing     Missing      20.5
# 2   Missing              Missing   Missing     Missing   Missing
# 3   Missing              Missing   Missing     Missing   Missing
# 4   Missing  None or Unspecified   Missing     Missing   Missing
#
#                Coupler Coupler_System Grouser_Tracks Hydraulics_Flow  \
# 0              Missing        Missing        Missing         Missing
# 1  None or Unspecified        Missing        Missing         Missing
# 2  None or Unspecified        Missing        Missing         Missing
# 3  None or Unspecified        Missing        Missing         Missing
# 4              Missing        Missing        Missing         Missing
#
#   Track_Type Undercarriage_Pad_Width         Stick_Length    Thumb  \
# 0    Missing                 Missing              Missing  Missing
# 1    Missing                 Missing              Missing  Missing
# 2      Steel     None or Unspecified                9' 6"   Manual
# 3      Steel     None or Unspecified  None or Unspecified   Manual
# 4    Missing                 Missing              Missing  Missing
#
#        Pattern_Changer Grouser_Type     Backhoe_Mounting Blade_Type  \
# 0              Missing      Missing              Missing    Missing
# 1              Missing      Missing              Missing    Missing
# 2  None or Unspecified       Double              Missing    Missing
# 3                  Yes       Triple              Missing    Missing
# 4              Missing      Missing  None or Unspecified        PAT
#
#        Travel_Controls Differential_Type Steering_Controls  \
# 0              Missing           Missing           Missing
# 1              Missing          Standard      Conventional
# 2              Missing           Missing           Missing
# 3              Missing           Missing           Missing
# 4  None or Unspecified           Missing           Missing
#
#               PrimarySizeBasis  MachineAge
# 0  Standard Digging Depth - Ft          13
# 1                   Horsepower        1012
# 2         Weight - Metric Tons           8
# 3         Weight - Metric Tons           6
# 4                   Horsepower           7

# %% [markdown]
# ## Imputation - Rare - Test and Training Set

# %%
# Defining function to flag categorical label with low proportion of respondents as "rare"
def rare_imputation(variable, which='rare'):    
    # find frequent labels
    temp = x_Train.groupby([variable])[variable].count()/np.float(len(x_Train))
    frequent_cat = [x for x in temp.loc[temp>0.01].index.values]
    
    # create new variables, with Rare labels imputed
    if which=='frequent':
        # find the most frequent category
        mode_label = x_Train.groupby(variable)[variable].count().sort_values().tail(1).index.values[0]
        x_Train[variable] = np.where(x_Train[variable].isin(frequent_cat), x_Train[variable], mode_label)
        x_Test[variable] = np.where(x_Test[variable].isin(frequent_cat), x_Test[variable], mode_label)
        
    else:
        x_Train[variable] = np.where(x_Train[variable].isin(frequent_cat), x_Train[variable], 'Rare')
        x_Test[variable] = np.where(x_Test[variable].isin(frequent_cat), x_Test[variable], 'Rare')

# %%
#Imputing "rare" for rare labels
for col in categorical_train:
    rare_imputation(col, 'rare')

# %%
#Imputing "frequent" for rare labels
for col in categorical_train:
    rare_imputation(col, 'frequent')

# %%
# Checking result of imputation
for col in categorical_train:
    print(x_Train[col].value_counts()/np.float(len(x_Train)))
# Out:
# Missing    0.826391
# Medium     0.084724
# Low        0.058884
# High       0.030001
# Name: UsageBand, dtype: float64
# Rare    0.639953
# 580     0.049356
# 310     0.043263
# D6      0.032683
# 416     0.031629
# D5      0.023289
# 950     0.018463
# D3      0.017017
# D8      0.016785
# D4      0.016115
# 12      0.015314
# 140     0.014482
# 966     0.014454
# 320     0.013784
# 544     0.011450
# 410     0.010964
# 330     0.010543
# 650     0.010446
# 450     0.010009
# Name: fiBaseModel, dtype: float64
# Missing    0.342016
# C          0.107784
# B          0.097733
# G          0.090805
# Rare       0.086781
# H          0.059956
# E          0.052472
# D          0.048506
# F          0.022818
# K          0.019393
# L          0.013731
# A          0.013721
# M          0.012871
# J          0.010894
# P          0.010478
# LC         0.010039
# Name: fiSecondaryDesc, dtype: float64
# Missing    0.858129
# Rare       0.062178
# II         0.032912
# LC         0.022277
# III        0.013058
# -1         0.011445
# Name: fiModelSeries, dtype: float64
# Missing           0.525460
# Medium            0.155248
# Large / Medium    0.123847
# Small             0.066049
# Mini              0.061926
# Large             0.052290
# Compact           0.015180
# Name: ProductSize, dtype: float64
# Florida           0.159412
# Texas             0.128843
# Rare              0.090720
# California        0.072344
# Washington        0.039776
# Georgia           0.035672
# Maryland          0.032322
# Mississippi       0.032312
# Ohio              0.030390
# Colorado          0.028056
# Illinois          0.027944
# New Jersey        0.027129
# North Carolina    0.025937
# Tennessee         0.024997
# Alabama           0.024922
# Pennsylvania      0.024783
# South Carolina    0.024416
# Arizona           0.022868
# New York          0.021450
# Connecticut       0.020263
# Minnesota         0.019281
# Missouri          0.017354
# Nevada            0.016686
# Louisiana         0.016080
# Kentucky          0.013158
# Maine             0.012702
# Indiana           0.010186
# Name: state, dtype: float64
# TEX    0.252208
# TTT    0.200735
# BL     0.197981
# WL     0.177117
# SSL    0.108415
# MG     0.063544
# Name: ProductGroup, dtype: float64
# Track Excavators       0.252208
# Track Type Tractors    0.200735
# Backhoe Loaders        0.197981
# Wheel Loader           0.177117
# Skid Steer Loaders     0.108415
# Motor Graders          0.063544
# Name: ProductGroupDesc, dtype: float64
# Missing             0.741819
# Two Wheel Drive     0.115024
# Four Wheel Drive    0.082259
# No                  0.060899
# Name: Drive_System, dtype: float64
# OROPS         0.434476
# EROPS         0.346590
# EROPS w AC    0.218934
# Name: Enclosure, dtype: float64
# Missing                0.521154
# None or Unspecified    0.444500
# Yes                    0.034346
# Name: Forks, dtype: float64
# Missing                0.809421
# None or Unspecified    0.176040
# Reversible             0.014539
# Name: Pad_Type, dtype: float64
# Missing                0.629527
# No                     0.193668
# None or Unspecified    0.157347
# Yes                    0.019458
# Name: Ride_Control, dtype: float64
# Missing     0.80272
# Standard    0.12173
# Extended    0.07555
# Name: Stick, dtype: float64
# Missing                0.552633
# Standard               0.349836
# None or Unspecified    0.057705
# Powershift             0.029245
# Powershuttle           0.010580
# Name: Transmission, dtype: float64
# Missing                0.8125
# None or Unspecified    0.1875
# Name: Turbocharged, dtype: float64
# Missing                0.938443
# None or Unspecified    0.061557
# Name: Blade_Extension, dtype: float64
# Missing                0.940502
# 14'                    0.023970
# None or Unspecified    0.023142
# 12'                    0.012385
# Name: Blade_Width, dtype: float64
# Missing                0.945346
# None or Unspecified    0.054654
# Name: Enclosure_Type, dtype: float64
# Missing    0.940325
# No         0.059675
# Name: Engine_Horsepower, dtype: float64
# 2 Valve              0.361528
# Standard             0.260325
# Missing              0.200823
# Auxiliary            0.101557
# Base + 1 Function    0.061751
# 3 Valve              0.014016
# Name: Hydraulics, dtype: float64
# Missing                0.937129
# None or Unspecified    0.048521
# Yes                    0.014350
# Name: Pushblock, dtype: float64
# Missing                0.740388
# None or Unspecified    0.208045
# Yes                    0.019700
# Multi Shank            0.019029
# Single Shank           0.012839
# Name: Ripper, dtype: float64
# Missing                0.937102
# None or Unspecified    0.031708
# Yes                    0.031190
# Name: Scarifier, dtype: float64
# Missing                0.941971
# None or Unspecified    0.040404
# Sideshift & Tip        0.017625
# Name: Tip_Control, dtype: float64
# Missing                0.763869
# None or Unspecified    0.115523
# 20.5                   0.037998
# Rare                   0.028325
# 14"                    0.021971
# 23.5                   0.021141
# 26.5                   0.011174
# Name: Tire_Size, dtype: float64
# Missing                0.466620
# None or Unspecified    0.460161
# Manual                 0.058089
# Hydraulic              0.015130
# Name: Coupler, dtype: float64
# Missing                0.899208
# None or Unspecified    0.100792
# Name: Coupler_System, dtype: float64
# Missing                0.898997
# None or Unspecified    0.101003
# Name: Grouser_Tracks, dtype: float64
# Missing     0.89334
# Standard    0.10666
# Name: Hydraulics_Flow, dtype: float64
# Missing    0.752813
# Steel      0.211605
# Rubber     0.035582
# Name: Track_Type, dtype: float64
# Missing                0.751020
# None or Unspecified    0.198569
# Rare                   0.037415
# 32 inch                0.012996
# Name: Undercarriage_Pad_Width, dtype: float64
# Missing                0.752651
# None or Unspecified    0.196497
# Rare                   0.036480
# 9' 6"                  0.014372
# Name: Stick_Length, dtype: float64
# Missing                0.752476
# None or Unspecified    0.207150
# Manual                 0.023329
# Hydraulic              0.017045
# Name: Thumb, dtype: float64
# Missing                0.752813
# None or Unspecified    0.225005
# Yes                    0.022183
# Name: Pattern_Changer, dtype: float64
# Missing    0.752818
# Double     0.211039
# Triple     0.036143
# Name: Grouser_Type, dtype: float64
# Missing                0.803921
# None or Unspecified    0.196079
# Name: Backhoe_Mounting, dtype: float64
# Missing                0.800977
# PAT                    0.096259
# Straight               0.033214
# None or Unspecified    0.028497
# Semi U                 0.021482
# Rare                   0.019570
# Name: Blade_Type, dtype: float64
# Missing                0.800975
# None or Unspecified    0.174317
# Rare                   0.012545
# Differential Steer     0.012163
# Name: Travel_Controls, dtype: float64
# Missing     0.830295
# Standard    0.169705
# Name: Differential_Type, dtype: float64
# Missing         0.828784
# Conventional    0.171216
# Name: Steering_Controls, dtype: float64
# Horsepower                     0.483632
# Weight - Metric Tons           0.226214
# Standard Digging Depth - Ft    0.185426
# Operating Capacity - Lbs       0.104728
# Name: PrimarySizeBasis, dtype: float64

# %%
# Checking result of imputation - Test set
for col in categorical_test:
    print(x_Test[col].value_counts()/np.float(len(x_Test)))
# Out:
# Missing    0.852774
# Medium     0.066308
# Low        0.065104
# High       0.015814
# Name: UsageBand, dtype: float64
# Rare    0.703701
# 310     0.041583
# 580     0.037569
# D6      0.033074
# D5      0.022477
# 416     0.019025
# 320     0.014851
# 950     0.013165
# 330     0.012844
# 650     0.012684
# 140     0.012603
# D4      0.012041
# D8      0.011399
# 450     0.011078
# 12      0.010918
# 966     0.009633
# 544     0.007626
# D3      0.007064
# 410     0.006663
# Name: fiBaseModel, dtype: float64
# Missing    0.319098
# G          0.114955
# Rare       0.111985
# C          0.107169
# B          0.081962
# D          0.056996
# H          0.048246
# E          0.039656
# J          0.024886
# M          0.024324
# F          0.019025
# LC         0.017500
# K          0.014771
# L          0.007626
# A          0.007225
# P          0.004576
# Name: fiSecondaryDesc, dtype: float64
# Missing    0.838966
# Rare       0.075941
# II         0.042466
# LC         0.023922
# III        0.009954
# -1         0.008750
# Name: fiModelSeries, dtype: float64
# Missing           0.514490
# Medium            0.162961
# Large / Medium    0.136068
# Mini              0.080035
# Small             0.058120
# Large             0.035643
# Compact           0.012684
# Name: ProductSize, dtype: float64
# Texas             0.172754
# Rare              0.143534
# Florida           0.088223
# California        0.069840
# Georgia           0.045195
# Maryland          0.044312
# Illinois          0.037650
# Tennessee         0.033154
# North Carolina    0.032993
# Washington        0.032191
# Arizona           0.029943
# Missouri          0.026973
# Louisiana         0.026652
# Pennsylvania      0.026331
# Ohio              0.023842
# Colorado          0.021755
# New Jersey        0.019908
# Nevada            0.019587
# Mississippi       0.019507
# New York          0.018223
# Connecticut       0.018062
# Kentucky          0.014048
# Alabama           0.013406
# Minnesota         0.009874
# Indiana           0.005860
# South Carolina    0.005379
# Maine             0.000803
# Name: state, dtype: float64
# TEX    0.274304
# WL     0.171791
# BL     0.170105
# SSL    0.165931
# TTT    0.165529
# MG     0.052340
# Name: ProductGroup, dtype: float64
# Track Excavators       0.274304
# Wheel Loader           0.171791
# Backhoe Loaders        0.170105
# Skid Steer Loaders     0.165931
# Track Type Tractors    0.165529
# Motor Graders          0.052340
# Name: ProductGroupDesc, dtype: float64
# Missing             0.780605
# Two Wheel Drive     0.111664
# Four Wheel Drive    0.057558
# No                  0.050173
# Name: Drive_System, dtype: float64
# OROPS         0.394798
# EROPS w AC    0.343020
# EROPS         0.262182
# Name: Enclosure, dtype: float64
# Missing                0.493618
# None or Unspecified    0.451874
# Yes                    0.054508
# Name: Forks, dtype: float64
# Missing                0.834551
# None or Unspecified    0.152284
# Reversible             0.013165
# Name: Pad_Type, dtype: float64
# Missing                0.659549
# No                     0.155977
# None or Unspecified    0.137272
# Yes                    0.047202
# Name: Ride_Control, dtype: float64
# Missing     0.830778
# Standard    0.098900
# Extended    0.070322
# Name: Stick, dtype: float64
# Missing                0.625993
# Standard               0.290680
# None or Unspecified    0.050574
# Powershift             0.029140
# Powershuttle           0.003612
# Name: Transmission, dtype: float64
# Missing                0.835755
# None or Unspecified    0.164245
# Name: Turbocharged, dtype: float64
# Missing                0.949587
# None or Unspecified    0.050413
# Name: Blade_Extension, dtype: float64
# Missing                0.950309
# 14'                    0.020069
# None or Unspecified    0.019587
# 12'                    0.010035
# Name: Blade_Width, dtype: float64
# Missing                0.960103
# None or Unspecified    0.039897
# Name: Enclosure_Type, dtype: float64
# Missing    0.951112
# No         0.048888
# Name: Engine_Horsepower, dtype: float64
# 2 Valve              0.321426
# Auxiliary            0.224452
# Standard             0.214658
# Missing              0.171952
# Base + 1 Function    0.049851
# 3 Valve              0.017661
# Name: Hydraulics, dtype: float64
# Missing                0.947740
# None or Unspecified    0.038854
# Yes                    0.013406
# Name: Pushblock, dtype: float64
# Missing                0.782933
# None or Unspecified    0.164566
# Multi Shank            0.022638
# Yes                    0.017661
# Single Shank           0.012202
# Name: Ripper, dtype: float64
# Missing                0.947740
# None or Unspecified    0.026411
# Yes                    0.025849
# Name: Scarifier, dtype: float64
# Missing                0.950470
# None or Unspecified    0.045195
# Sideshift & Tip        0.004335
# Name: Tip_Control, dtype: float64
# Missing                0.776993
# None or Unspecified    0.133339
# 20.5                   0.031147
# 23.5                   0.018142
# Rare                   0.015814
# 14"                    0.013888
# 26.5                   0.010677
# Name: Tire_Size, dtype: float64
# None or Unspecified    0.506623
# Missing                0.389821
# Manual                 0.073613
# Hydraulic              0.029943
# Name: Coupler, dtype: float64
# Missing                0.865537
# None or Unspecified    0.134463
# Name: Coupler_System, dtype: float64
# Missing                0.859918
# None or Unspecified    0.140082
# Name: Grouser_Tracks, dtype: float64
# Missing     0.842578
# Standard    0.157422
# Name: Hydraulics_Flow, dtype: float64
# Missing    0.727543
# Steel      0.231035
# Rubber     0.041422
# Name: Track_Type, dtype: float64
# Missing                0.727222
# None or Unspecified    0.233282
# Rare                   0.026571
# 32 inch                0.012924
# Name: Undercarriage_Pad_Width, dtype: float64
# Missing                0.727543
# None or Unspecified    0.233684
# Rare                   0.031789
# 9' 6"                  0.006984
# Name: Stick_Length, dtype: float64
# Missing                0.727462
# None or Unspecified    0.202376
# Hydraulic              0.044553
# Manual                 0.025608
# Name: Thumb, dtype: float64
# Missing                0.727543
# None or Unspecified    0.227984
# Yes                    0.044473
# Name: Pattern_Changer, dtype: float64
# Missing    0.727543
# Double     0.220037
# Triple     0.052420
# Name: Grouser_Type, dtype: float64
# Missing                0.835354
# None or Unspecified    0.164646
# Name: Backhoe_Mounting, dtype: float64
# Missing                0.834792
# PAT                    0.074336
# None or Unspecified    0.041824
# Semi U                 0.020631
# Rare                   0.016216
# Straight               0.012202
# Name: Blade_Type, dtype: float64
# Missing                0.834792
# None or Unspecified    0.128201
# Differential Steer     0.019748
# Rare                   0.017259
# Name: Travel_Controls, dtype: float64
# Missing     0.834551
# Standard    0.165449
# Name: Differential_Type, dtype: float64
# Missing         0.832383
# Conventional    0.167617
# Name: Steering_Controls, dtype: float64
# Horsepower                     0.415830
# Weight - Metric Tons           0.264269
# Standard Digging Depth - Ft    0.161676
# Operating Capacity - Lbs       0.158224
# Name: PrimarySizeBasis, dtype: float64

# %% [markdown]
# ### Outliers in Numerical variables
#
# In order to tackle outliers and skewed distributions at the same time, I suggested I would do discretisation. And in order to find the optimal buckets automatically, I would use decision trees to find the buckets for me.

# %%
def tree_binariser(var):
    score_ls = [] # here I will store the mse

    for tree_depth in [1,2,3,4]:
        # call the model
        tree_model = DecisionTreeRegressor(max_depth=tree_depth)

        # train the model using 3 fold cross validation
        scores = cross_val_score(tree_model, x_Train[var].to_frame(), y_Train, cv=3, scoring='neg_mean_squared_error')
        score_ls.append(np.mean(scores))

    # find depth with smallest mse
    depth = [1,2,3,4][np.argmax(score_ls)]
    #print(score_ls, np.argmax(score_ls), depth)

    # transform the variable using the tree
    tree_model = DecisionTreeRegressor(max_depth=depth)
    tree_model.fit(x_Train[var].to_frame(), x_Train.SalePrice)
    x_Train[var] = tree_model.predict(x_Train[var].to_frame())
    x_Test[var] = tree_model.predict(x_Test[var].to_frame())

# %%
continuous_train
# Out:
# ['MachineHoursCurrentMeter', 'MachineAge']

# %%
continuous_test
# Out:
# ['MachineHoursCurrentMeter', 'MachineAge']

# %%
for var in continuous_train:
    tree_binariser(var)

# %%
for var in continuous_test:
    tree_binariser(var)

# %%
x_Train[continuous_train].head()
# Out:
#    MachineHoursCurrentMeter    MachineAge
# 0              30210.356930  45613.739433
# 1              40332.445579  32022.027750
# 2              30210.356930  42968.756966
# 3              40332.445579  30439.543667
# 4              30210.356930  45613.739433

# %%
for var in continuous_train:
    print(var, len(x_Train[var].unique()))
# Out:
# MachineHoursCurrentMeter 2
# MachineAge 13

# %%
x_Test[continuous_test].head()
# Out:
#    MachineHoursCurrentMeter    MachineAge
# 0              40332.445579  28768.601111
# 1              40332.445579  23812.767985
# 2              40332.445579  32022.027750
# 3              40332.445579  33689.341183
# 4              30210.356930  33689.341183

# %%
for var in continuous_test:
    print(var, len(x_Test[var].unique()))
# Out:
# MachineHoursCurrentMeter 2
# MachineAge 13

# %% [markdown]
# ### Encode categorical and discrete variables

# %%
def encode_categorical_variables(var, target):
        # make label to price dictionary
        ordered_labels = x_Train.groupby([var])[target].mean().to_dict()
        
        # encode variables
        x_Train[var] = x_Train[var].map(ordered_labels)
        x_Test[var] = x_Test[var].map(ordered_labels)
        

# encode labels in categorical vars
for var in categorical_train:
    encode_categorical_variables(var, 'SalePrice')

# %%
#let's inspect the dataset
x_Train.head()
# Out:
#    SalesID  SalePrice  MachineHoursCurrentMeter     UsageBand   fiBaseModel  \
# 0  1139246      66000              30210.356930  28334.130440  28351.974975
# 1  1139248      57000              40332.445579  28334.130440  46569.295166
# 2  1139249      10000              30210.356930  44477.643344  28351.974975
# 3  1139251      38500              40332.445579  44477.643344  28351.974975
# 4  1139253      11000              30210.356930  36970.215330  28351.974975
#
#    fiSecondaryDesc  fiModelSeries   ProductSize         state  ProductGroup  \
# 0     29402.883487   29981.266010  23979.399753  35369.592778  37052.463249
# 1     42141.415383   47733.102257  45476.506680  32134.863995  37052.463249
# 2     23397.791284   29981.266010  23979.399753  25555.172013  10549.458563
# 3     23397.791284   32825.498416  32370.001359  32939.036396  35666.120622
# 4     23397.791284   29981.266010  23979.399753  25555.172013  10549.458563
#
#    ProductGroupDesc  Drive_System     Enclosure         Forks     Pad_Type  \
# 0      37052.463249  32505.851503  51777.326782  23512.603724  33537.03177
# 1      37052.463249  32505.851503  51777.326782  23512.603724  33537.03177
# 2      10549.458563  32505.851503  22558.387178  23512.603724  33537.03177
# 3      35666.120622  32505.851503  51777.326782  37194.246441  33537.03177
# 4      10549.458563  32505.851503  28745.229806  23512.603724  33537.03177
#
#    Ride_Control        Stick  Transmission  Turbocharged  Blade_Extension  \
# 0  34754.662273  33608.04452  31059.310766  33494.244034     30050.769561
# 1  34754.662273  33608.04452  31059.310766  33494.244034     30050.769561
# 2  32613.419521  33608.04452  31059.310766  33494.244034     30050.769561
# 3  32613.419521  33608.04452  31059.310766  33494.244034     30050.769561
# 4  32613.419521  33608.04452  31059.310766  33494.244034     30050.769561
#
#     Blade_Width  Enclosure_Type  Engine_Horsepower    Hydraulics  \
# 0  30073.083009    30450.183673       30207.876412  36620.753155
# 1  30073.083009    30450.183673       30207.876412  36620.753155
# 2  30073.083009    30450.183673       30207.876412  25052.796058
# 3  30073.083009    30450.183673       30207.876412  36620.753155
# 4  30073.083009    30450.183673       30207.876412  25052.796058
#
#       Pushblock        Ripper   Scarifier   Tip_Control     Tire_Size  \
# 0  30002.690135  28322.244623  30002.8219  30167.548774  35109.295712
# 1  30002.690135  28322.244623  30002.8219  30167.548774  47058.113208
# 2  30002.690135  28322.244623  30002.8219  30167.548774  28361.684325
# 3  30002.690135  28322.244623  30002.8219  30167.548774  28361.684325
# 4  30002.690135  28322.244623  30002.8219  30167.548774  28361.684325
#
#         Coupler  Coupler_System  Grouser_Tracks  Hydraulics_Flow  \
# 0  30256.342249    33411.977882    33427.318813     33558.342925
# 1  30256.342249    33411.977882    33427.318813     33558.342925
# 2  30256.342249    10470.911551    10382.497322     10507.249299
# 3  30256.342249    33411.977882    33427.318813     33558.342925
# 4  30256.342249    10470.911551    10382.497322     10507.249299
#
#      Track_Type  Undercarriage_Pad_Width  Stick_Length         Thumb  \
# 0  29565.657382             29570.555118  29565.690564  29565.729818
# 1  29565.657382             29570.555118  29565.690564  29565.729818
# 2  29565.657382             29570.555118  29565.690564  29565.729818
# 3  29565.657382             29570.555118  29565.690564  29565.729818
# 4  29565.657382             29570.555118  29565.690564  29565.729818
#
#    Pattern_Changer  Grouser_Type  Backhoe_Mounting    Blade_Type  \
# 0     29565.657382  29565.805967      29815.899824  29831.619645
# 1     29565.657382  29565.805967      29815.899824  29831.619645
# 2     29565.657382  29565.805967      29815.899824  29831.619645
# 3     29565.657382  29565.805967      29815.899824  29831.619645
# 4     29565.657382  29565.805967      29815.899824  29831.619645
#
#    Travel_Controls  Differential_Type  Steering_Controls  PrimarySizeBasis  \
# 0     29832.178505       36854.326664       36975.240306      37118.131466
# 1     29832.178505       36854.326664       36975.240306      37118.131466
# 2     29832.178505       29923.518661       29885.905642      10503.305339
# 3     29832.178505       29923.518661       29885.905642      37118.131466
# 4     29832.178505       29923.518661       29885.905642      10503.305339
#
#      MachineAge
# 0  45613.739433
# 1  32022.027750
# 2  42968.756966
# 3  30439.543667
# 4  45613.739433

# %% [markdown]
# We can see that the labels have now been replaced by the mean house price.
#
# ### Feature scaling

# %%
x_Train.describe()
# Out:
#             SalesID      SalePrice  MachineHoursCurrentMeter      UsageBand  \
# count  4.011250e+05  401125.000000             401125.000000  401125.000000
# mean   1.919713e+06   31099.712848              31099.712848   31099.712848
# std    9.090215e+05   23036.898502               2865.520190    3065.073987
# min    1.139246e+06    4750.000000              30210.356930   28334.130440
# 25%    1.418371e+06   14500.000000              30210.356930   30209.249944
# 50%    1.639422e+06   24000.000000              30210.356930   30209.249944
# 75%    2.242707e+06   40000.000000              30210.356930   30209.249944
# max    6.333342e+06  142000.000000              40332.445579   44477.643344
#
#          fiBaseModel  fiSecondaryDesc  fiModelSeries    ProductSize  \
# count  401125.000000    401125.000000  401125.000000  401125.000000
# mean    31099.712848     31099.712848   31099.712848   31099.712848
# std      9819.530672      8368.710554    3996.993046   10845.730404
# min     18574.269668     18811.365552   27817.123720   15149.894686
# 25%     28351.974975     23397.791284   29981.266010   23979.399753
# 50%     28351.974975     28885.699385   29981.266010   23979.399753
# 75%     28351.974975     36117.334760   29981.266010   45476.506680
# max     70751.489069     54024.050343   47733.102257   47719.945952
#
#                state   ProductGroup  ProductGroupDesc   Drive_System  \
# count  401125.000000  401125.000000     401125.000000  401125.000000
# mean    31099.712848   31099.712848      31099.712848   31099.712848
# std      2607.013793    9982.103252       9982.103252    6270.693846
# min     24415.130935   10549.458563      10549.458563   18310.681983
# 25%     29095.193650   20897.352553      20897.352553   32505.851503
# 50%     31179.566447   35666.120622      35666.120622   32505.851503
# 75%     32939.036396   36158.412221      36158.412221   32505.851503
# max     36015.740326   47251.564518      47251.564518   47034.844359
#
#            Enclosure          Forks       Pad_Type   Ride_Control  \
# count  401125.000000  401125.000000  401125.000000  401125.000000
# mean    31099.712848   31099.712848   31099.712848   31099.712848
# std     11279.487872    6787.228960    5091.101149    6020.141768
# min     22558.387178   23512.603724   20201.640298   20728.651001
# 25%     22558.387178   23512.603724   33537.031770   32613.419521
# 50%     28745.229806   37194.246441   33537.031770   32613.419521
# 75%     28745.229806   37194.246441   33537.031770   32613.419521
# max     51777.326782   37194.246441   33537.031770   55795.479180
#
#                Stick   Transmission   Turbocharged  Blade_Extension  \
# count  401125.000000  401125.000000  401125.000000    401125.000000
# mean    31099.712847   31099.712848   31099.712848     31099.712848
# std      5125.622351    4519.992170    4984.617819      4095.606839
# min     19440.228819   19243.660226   20723.421654     30050.769561
# 25%     33608.044520   28285.938765   33494.244034     30050.769561
# 50%     33608.044520   31059.310766   33494.244034     30050.769561
# 75%     33608.044520   31059.310766   33494.244034     30050.769561
# max     33608.044520   47008.807923   33494.244034     47091.000243
#
#          Blade_Width  Enclosure_Type  Engine_Horsepower     Hydraulics  \
# count  401125.000000   401125.000000      401125.000000  401125.000000
# mean    31099.712848    31099.712848       31099.712847   31099.712848
# std      4731.287159     2701.372797        3540.216539    7277.068218
# min     30073.083009    30450.183673       30207.876412   20978.169611
# 25%     30073.083009    30450.183673       30207.876412   25052.796058
# 50%     30073.083009    30450.183673       30207.876412   29274.054097
# 75%     30073.083009    30450.183673       30207.876412   36620.753155
# max     58942.376599    42334.615107       45152.852404   46337.235688
#
#            Pushblock         Ripper      Scarifier    Tip_Control  \
# count  401125.000000  401125.000000  401125.000000  401125.000000
# mean    31099.712848   31099.712848   31099.712847   31099.712847
# std      5081.385771    6361.151041    4253.482141    3755.826650
# min     30002.690135   28322.244623   30002.821900   30167.548774
# 25%     30002.690135   28322.244623   30002.821900   30167.548774
# 50%     30002.690135   28322.244623   30002.821900   30167.548774
# 75%     30002.690135   35104.655155   30002.821900   30167.548774
# max     68040.808200   63495.752468   49081.788506   46443.603395
#
#            Tire_Size        Coupler  Coupler_System  Grouser_Tracks  \
# count  401125.000000  401125.000000   401125.000000   401125.000000
# mean    31099.712847   31099.712848    31099.712848    31099.712848
# std      5626.010523    2105.720475     6906.473401     6944.179912
# min     28361.684325   30256.342249    10470.911551    10382.497322
# 25%     28361.684325   30256.342249    33411.977882    33427.318813
# 50%     28361.684325   31103.994743    33411.977882    33427.318813
# 75%     28361.684325   31103.994743    33411.977882    33427.318813
# max     50737.663989   46793.387708    33411.977882    33427.318813
#
#        Hydraulics_Flow     Track_Type  Undercarriage_Pad_Width   Stick_Length  \
# count    401125.000000  401125.000000            401125.000000  401125.000000
# mean      31099.712847   31099.712848             31099.712848   31099.712847
# std        7115.432275    4882.143631              3075.537052    4262.817566
# min       10507.249299   15746.541302             29570.555118   29565.690564
# 25%       33558.342925   29565.657382             29570.555118   29565.690564
# 50%       33558.342925   29565.657382             29570.555118   29565.690564
# 75%       33558.342925   29565.657382             29570.555118   29565.690564
# max       33558.342925   39139.034413             48916.573950   49711.692749
#
#                Thumb  Pattern_Changer   Grouser_Type  Backhoe_Mounting  \
# count  401125.000000    401125.000000  401125.000000     401125.000000
# mean    31099.712848     31099.712848   31099.712848      31099.712848
# std      2760.681221      3711.429859    3019.832130       2599.525680
# min     29565.729818     29565.657382   29565.805967      29815.899824
# 25%     29565.729818     29565.657382   29565.805967      29815.899824
# 50%     29565.729818     29565.657382   29565.805967      29815.899824
# 75%     29565.729818     29565.657382   29565.805967      29815.899824
# max     39335.906711     52238.069117   42564.375431      36363.342979
#
#           Blade_Type  Travel_Controls  Differential_Type  Steering_Controls  \
# count  401125.000000    401125.000000      401125.000000      401125.000000
# mean    31099.712847     31099.712848       31099.712848       31099.712848
# std      4895.016000      4712.131841        2601.645670        2670.538400
# min     29831.619645     29832.178505       29923.518661       29885.905642
# 25%     29831.619645     29832.178505       29923.518661       29885.905642
# 50%     29831.619645     29832.178505       29923.518661       29885.905642
# 75%     29831.619645     29832.178505       29923.518661       29885.905642
# max     58536.042126     69572.622464       36854.326664       36975.240306
#
#        PrimarySizeBasis     MachineAge
# count     401125.000000  401125.000000
# mean       31099.712848   31099.712848
# std         9264.797734    7110.567412
# min        10503.305339   17951.619644
# 25%        21100.720674   25728.332737
# 50%        35964.098622   30439.543667
# 75%        37118.131466   35567.880894
# max        37118.131466   45613.739433

# %% [markdown]
# ## Taking a Random Sample of the X_Train data set

# %%
# Taking a Random Sample of 10000 observations from the x_Train
# you can use random_state for reproducibility
x_Train_RS = x_Train.sample(n=10000, random_state=2)

# %%
# Taking a Random Sample of 10000 observations from the x_Test
# you can use random_state for reproducibility
x_Test_RS = x_Test.sample(n=10000, random_state=2)

# %%
#Checking the sample
x_Train_RS.head()
# Out:
#         SalesID  SalePrice  MachineHoursCurrentMeter     UsageBand  \
# 315789  2284133      33000               30210.35693  30209.249944
# 312294  2273358      16000               30210.35693  30209.249944
# 53444   1299720      25000               30210.35693  30209.249944
# 27681   1256624      12500               30210.35693  30209.249944
# 72699   1358232      67500               30210.35693  30209.249944
#
#          fiBaseModel  fiSecondaryDesc  fiModelSeries   ProductSize  \
# 315789  28351.974975     28885.699385   47733.102257  47719.945952
# 312294  24114.357058     28885.699385   29981.266010  23979.399753
# 53444   52275.367048     29402.883487   29981.266010  45476.506680
# 27681   28351.974975     28885.699385   29981.266010  32370.001359
# 72699   28351.974975     33613.526448   29981.266010  47719.945952
#
#                state  ProductGroup  ProductGroupDesc  Drive_System  \
# 315789  29787.451256  35666.120622      35666.120622  32505.851503
# 312294  34064.361160  20897.352553      20897.352553  24504.861104
# 53444   27165.936126  36158.412221      36158.412221  32505.851503
# 27681   32939.036396  35666.120622      35666.120622  32505.851503
# 72699   29918.207654  35666.120622      35666.120622  32505.851503
#
#            Enclosure         Forks      Pad_Type  Ride_Control         Stick  \
# 315789  51777.326782  37194.246441  33537.031770  32613.419521  33608.044520
# 312294  22558.387178  23512.603724  20201.640298  20728.651001  23235.027883
# 53444   22558.387178  37194.246441  33537.031770  32613.419521  33608.044520
# 27681   28745.229806  37194.246441  33537.031770  32613.419521  33608.044520
# 72699   51777.326782  37194.246441  33537.031770  32613.419521  33608.044520
#
#         Transmission  Turbocharged  Blade_Extension   Blade_Width  \
# 315789  31059.310766  33494.244034     30050.769561  30073.083009
# 312294  28285.938765  20723.421654     30050.769561  30073.083009
# 53444   28285.938765  33494.244034     30050.769561  30073.083009
# 27681   31059.310766  33494.244034     30050.769561  30073.083009
# 72699   31059.310766  33494.244034     30050.769561  30073.083009
#
#         Enclosure_Type  Engine_Horsepower    Hydraulics     Pushblock  \
# 315789    30450.183673       30207.876412  29274.054097  30002.690135
# 312294    30450.183673       30207.876412  20978.169611  30002.690135
# 53444     30450.183673       30207.876412  36620.753155  30002.690135
# 27681     30450.183673       30207.876412  29274.054097  30002.690135
# 72699     30450.183673       30207.876412  29274.054097  30002.690135
#
#               Ripper   Scarifier   Tip_Control     Tire_Size       Coupler  \
# 315789  28322.244623  30002.8219  30167.548774  28361.684325  30256.342249
# 312294  28322.244623  30002.8219  30167.548774  28361.684325  31103.994743
# 53444   35104.655155  30002.8219  30167.548774  28361.684325  31103.994743
# 27681   28322.244623  30002.8219  30167.548774  28361.684325  30256.342249
# 72699   28322.244623  30002.8219  30167.548774  28361.684325  30256.342249
#
#         Coupler_System  Grouser_Tracks  Hydraulics_Flow    Track_Type  \
# 315789    33411.977882    33427.318813     33558.342925  39139.034413
# 312294    33411.977882    33427.318813     33558.342925  29565.657382
# 53444     33411.977882    33427.318813     33558.342925  29565.657382
# 27681     33411.977882    33427.318813     33558.342925  39139.034413
# 72699     33411.977882    33427.318813     33558.342925  39139.034413
#
#         Undercarriage_Pad_Width  Stick_Length         Thumb  Pattern_Changer  \
# 315789             34875.912117  32389.146473  35165.333650     34148.327361
# 312294             29570.555118  29565.690564  29565.729818     29565.657382
# 53444              29570.555118  29565.690564  29565.729818     29565.657382
# 27681              34875.912117  32389.146473  35165.333650     34148.327361
# 72699              34875.912117  49711.692749  35165.333650     34148.327361
#
#         Grouser_Type  Backhoe_Mounting    Blade_Type  Travel_Controls  \
# 315789  34607.979753      29815.899824  29831.619645     29832.178505
# 312294  29565.805967      29815.899824  29831.619645     29832.178505
# 53444   29565.805967      36363.342979  35536.673872     33318.204182
# 27681   34607.979753      29815.899824  29831.619645     29832.178505
# 72699   34607.979753      29815.899824  29831.619645     29832.178505
#
#         Differential_Type  Steering_Controls  PrimarySizeBasis    MachineAge
# 315789       29923.518661       29885.905642      35964.098622  32022.027750
# 312294       29923.518661       29885.905642      21100.720674  28768.601111
# 53444        29923.518661       29885.905642      37118.131466  23812.767985
# 27681        29923.518661       29885.905642      35964.098622  17951.619644
# 72699        29923.518661       29885.905642      35964.098622  33689.341183

# %%
#Checking the sample
x_Test_RS.head()
# Out:
#        SalesID  MachineHoursCurrentMeter     UsageBand   fiBaseModel  \
# 1278   4296762              40332.445579  44477.643344  52275.367048
# 1887   4512705              30210.356930  30209.249944  21609.507549
# 1898   4512869              30210.356930  30209.249944  28351.974975
# 10140  6622232              30210.356930  30209.249944  20016.801596
# 10796  6627715              30210.356930  30209.249944  52275.367048
#
#        fiSecondaryDesc  fiModelSeries   ProductSize         state  \
# 1278      27925.251703   29981.266010  45476.506680  34064.361160
# 1887      29402.883487   29981.266010  23979.399753  32266.706269
# 1898      36117.334760   29981.266010  47719.945952  31564.548130
# 10140     44604.682355   47733.102257  23979.399753  29787.451256
# 10796     27925.251703   29981.266010  45476.506680  31905.798344
#
#        ProductGroup  ProductGroupDesc  Drive_System     Enclosure  \
# 1278   36158.412221      36158.412221  32505.851503  51777.326782
# 1887   20897.352553      20897.352553  18310.681983  22558.387178
# 1898   35666.120622      35666.120622  32505.851503  51777.326782
# 10140  20897.352553      20897.352553  18310.681983  51777.326782
# 10796  36158.412221      36158.412221  32505.851503  22558.387178
#
#               Forks      Pad_Type  Ride_Control         Stick  Transmission  \
# 1278   37194.246441  33537.031770  32613.419521  33608.044520  28285.938765
# 1887   23512.603724  20201.640298  20728.651001  19440.228819  28285.938765
# 1898   37194.246441  33537.031770  32613.419521  33608.044520  31059.310766
# 10140  23512.603724  20201.640298  20728.651001  23235.027883  28285.938765
# 10796  37194.246441  33537.031770  32613.419521  33608.044520  28285.938765
#
#        Turbocharged  Blade_Extension   Blade_Width  Enclosure_Type  \
# 1278   33494.244034     30050.769561  30073.083009    30450.183673
# 1887   20723.421654     30050.769561  30073.083009    30450.183673
# 1898   33494.244034     30050.769561  30073.083009    30450.183673
# 10140  20723.421654     30050.769561  30073.083009    30450.183673
# 10796  33494.244034     30050.769561  30073.083009    30450.183673
#
#        Engine_Horsepower    Hydraulics     Pushblock        Ripper  \
# 1278        30207.876412  36620.753155  30002.690135  49267.732215
# 1887        30207.876412  20978.169611  30002.690135  28322.244623
# 1898        30207.876412  29274.054097  30002.690135  28322.244623
# 10140       30207.876412  20978.169611  30002.690135  28322.244623
# 10796       30207.876412  36620.753155  30002.690135  35104.655155
#
#         Scarifier   Tip_Control     Tire_Size       Coupler  Coupler_System  \
# 1278   30002.8219  30167.548774  28361.684325  31103.994743    33411.977882
# 1887   30002.8219  30167.548774  28361.684325  31103.994743    33411.977882
# 1898   30002.8219  30167.548774  28361.684325  46793.387708    33411.977882
# 10140  30002.8219  30167.548774  28361.684325  31103.994743    33411.977882
# 10796  30002.8219  30167.548774  28361.684325  31103.994743    33411.977882
#
#        Grouser_Tracks  Hydraulics_Flow    Track_Type  Undercarriage_Pad_Width  \
# 1278     33427.318813     33558.342925  29565.657382             29570.555118
# 1887     33427.318813     33558.342925  29565.657382             29570.555118
# 1898     33427.318813     33558.342925  39139.034413             48916.573950
# 10140    33427.318813     33558.342925  29565.657382             29570.555118
# 10796    33427.318813     33558.342925  29565.657382             29570.555118
#
#        Stick_Length         Thumb  Pattern_Changer  Grouser_Type  \
# 1278   29565.690564  29565.729818     29565.657382  29565.805967
# 1887   29565.690564  29565.729818     29565.657382  29565.805967
# 1898   49711.692749  35165.333650     34148.327361  34607.979753
# 10140  29565.690564  29565.729818     29565.657382  29565.805967
# 10796  29565.690564  29565.729818     29565.657382  29565.805967
#
#        Backhoe_Mounting    Blade_Type  Travel_Controls  Differential_Type  \
# 1278       36363.342979  30565.914016     69572.622464       29923.518661
# 1887       29815.899824  29831.619645     29832.178505       29923.518661
# 1898       29815.899824  29831.619645     29832.178505       29923.518661
# 10140      29815.899824  29831.619645     29832.178505       29923.518661
# 10796      36363.342979  30849.535474     33318.204182       29923.518661
#
#        Steering_Controls  PrimarySizeBasis    MachineAge
# 1278        29885.905642      37118.131466  38851.278783
# 1887        29885.905642      21100.720674  23812.767985
# 1898        29885.905642      35964.098622  33689.341183
# 10140       29885.905642      21100.720674  35567.880894
# 10796       29885.905642      37118.131466  35567.880894

# %%
# Change the row index
x_Test_RS.index = range(10000)

# %%
x_Test_RS.head()
# Out:
#    SalesID  MachineHoursCurrentMeter     UsageBand   fiBaseModel  \
# 0  4296762              40332.445579  44477.643344  52275.367048
# 1  4512705              30210.356930  30209.249944  21609.507549
# 2  4512869              30210.356930  30209.249944  28351.974975
# 3  6622232              30210.356930  30209.249944  20016.801596
# 4  6627715              30210.356930  30209.249944  52275.367048
#
#    fiSecondaryDesc  fiModelSeries   ProductSize         state  ProductGroup  \
# 0     27925.251703   29981.266010  45476.506680  34064.361160  36158.412221
# 1     29402.883487   29981.266010  23979.399753  32266.706269  20897.352553
# 2     36117.334760   29981.266010  47719.945952  31564.548130  35666.120622
# 3     44604.682355   47733.102257  23979.399753  29787.451256  20897.352553
# 4     27925.251703   29981.266010  45476.506680  31905.798344  36158.412221
#
#    ProductGroupDesc  Drive_System     Enclosure         Forks      Pad_Type  \
# 0      36158.412221  32505.851503  51777.326782  37194.246441  33537.031770
# 1      20897.352553  18310.681983  22558.387178  23512.603724  20201.640298
# 2      35666.120622  32505.851503  51777.326782  37194.246441  33537.031770
# 3      20897.352553  18310.681983  51777.326782  23512.603724  20201.640298
# 4      36158.412221  32505.851503  22558.387178  37194.246441  33537.031770
#
#    Ride_Control         Stick  Transmission  Turbocharged  Blade_Extension  \
# 0  32613.419521  33608.044520  28285.938765  33494.244034     30050.769561
# 1  20728.651001  19440.228819  28285.938765  20723.421654     30050.769561
# 2  32613.419521  33608.044520  31059.310766  33494.244034     30050.769561
# 3  20728.651001  23235.027883  28285.938765  20723.421654     30050.769561
# 4  32613.419521  33608.044520  28285.938765  33494.244034     30050.769561
#
#     Blade_Width  Enclosure_Type  Engine_Horsepower    Hydraulics  \
# 0  30073.083009    30450.183673       30207.876412  36620.753155
# 1  30073.083009    30450.183673       30207.876412  20978.169611
# 2  30073.083009    30450.183673       30207.876412  29274.054097
# 3  30073.083009    30450.183673       30207.876412  20978.169611
# 4  30073.083009    30450.183673       30207.876412  36620.753155
#
#       Pushblock        Ripper   Scarifier   Tip_Control     Tire_Size  \
# 0  30002.690135  49267.732215  30002.8219  30167.548774  28361.684325
# 1  30002.690135  28322.244623  30002.8219  30167.548774  28361.684325
# 2  30002.690135  28322.244623  30002.8219  30167.548774  28361.684325
# 3  30002.690135  28322.244623  30002.8219  30167.548774  28361.684325
# 4  30002.690135  35104.655155  30002.8219  30167.548774  28361.684325
#
#         Coupler  Coupler_System  Grouser_Tracks  Hydraulics_Flow  \
# 0  31103.994743    33411.977882    33427.318813     33558.342925
# 1  31103.994743    33411.977882    33427.318813     33558.342925
# 2  46793.387708    33411.977882    33427.318813     33558.342925
# 3  31103.994743    33411.977882    33427.318813     33558.342925
# 4  31103.994743    33411.977882    33427.318813     33558.342925
#
#      Track_Type  Undercarriage_Pad_Width  Stick_Length         Thumb  \
# 0  29565.657382             29570.555118  29565.690564  29565.729818
# 1  29565.657382             29570.555118  29565.690564  29565.729818
# 2  39139.034413             48916.573950  49711.692749  35165.333650
# 3  29565.657382             29570.555118  29565.690564  29565.729818
# 4  29565.657382             29570.555118  29565.690564  29565.729818
#
#    Pattern_Changer  Grouser_Type  Backhoe_Mounting    Blade_Type  \
# 0     29565.657382  29565.805967      36363.342979  30565.914016
# 1     29565.657382  29565.805967      29815.899824  29831.619645
# 2     34148.327361  34607.979753      29815.899824  29831.619645
# 3     29565.657382  29565.805967      29815.899824  29831.619645
# 4     29565.657382  29565.805967      36363.342979  30849.535474
#
#    Travel_Controls  Differential_Type  Steering_Controls  PrimarySizeBasis  \
# 0     69572.622464       29923.518661       29885.905642      37118.131466
# 1     29832.178505       29923.518661       29885.905642      21100.720674
# 2     29832.178505       29923.518661       29885.905642      35964.098622
# 3     29832.178505       29923.518661       29885.905642      21100.720674
# 4     33318.204182       29923.518661       29885.905642      37118.131466
#
#      MachineAge
# 0  38851.278783
# 1  23812.767985
# 2  33689.341183
# 3  35567.880894
# 4  35567.880894

# %%
x_Test_RS.shape
# Out:
# (10000, 45)

# %%
# Splitting the Training set in label and features
y_Train_RS = x_Train_RS['SalePrice']

# %%
#Extracting a set of candidate features to be used in estimating the various machine-learning models
training_vars = [var for var in x_Train_RS.columns if var not in ['SalesID', 'SalePrice']]

# %%
# fit scaler
scaler_RS = StandardScaler() # create an instance
scaler_RS.fit(x_Train_RS[training_vars]) #  fit  the scaler to the train set for later use
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# The scaler is now ready, we can use it in a machine learning algorithm when required. See below.
#
# ### Machine Learning algorithm building
#
# #### xgboost

# %%
xgb_model = xgb.XGBRegressor()
xgb_model.fit(x_Train_RS[training_vars], y_Train_RS, verbose=False)
pred = xgb_model.predict(x_Train_RS[training_vars])
print('xgb train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# xgb train mse: 121897992.63190039
# Prediction: [ 47270.984375    17340.9609375   24453.12890625 ...,  15841.46972656
#   67378.609375    14859.83203125]
# Rsquare :  0.772080826129

# %% [markdown]
# #### K-Fold Validation - xgboost

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator = xgb_model, X = x_Train_RS[training_vars], y = y_Train_RS, cv = 10)
print('mean Rsquare is: {}' .format(scores.mean()))
print('standard deviation of accuracy is: {}' .format(scores.std()))
# Out:
# mean Rsquare is: 0.7544766976080391
# standard deviation of accuracy is: 0.015993090258985442

# %% [markdown]
# #### Random Forests

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_Train_RS[training_vars], y_Train_RS)

pred = rf_model.predict(x_Train_RS[training_vars])
print('rf train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# rf train mse: 26031996.226808496
# Prediction: [ 36450.  18000.  25000. ...,  16450.  94500.   9775.]
# Rsquare :  0.951326589174

# %% [markdown]
# #### K-Fold Validation -Random Forest

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator = rf_model, X = x_Train_RS[training_vars], y = y_Train_RS, cv = 10)
print('mean Rsquare is: {}' .format(scores.mean()))
print('standard deviation of accuracy is: {}' .format(scores.std()))
# Out:
# mean Rsquare is: 0.7423587428658202
# standard deviation of accuracy is: 0.01869131356505399

# %% [markdown]
# #### Regularised linear regression

# %%
lin_model = Lasso(random_state=2909)
lin_model.fit(scaler_RS.transform(x_Train_RS[training_vars]), y_Train_RS)

pred = lin_model.predict(scaler_RS.transform(x_Train_RS[training_vars]))
print('linear train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# linear train mse: 182069106.6523973
# Prediction: [ 52149.43189179  14348.42958592  32637.89575524 ...,  14476.21636114
#   68340.7648553   18517.80108082]
# Rsquare :  0.659575687182

# %% [markdown]
# #### K-Fold Validation -Regularised linear regression

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator = lin_model, X = x_Train_RS[training_vars], y = y_Train_RS, cv = 10)
print('mean Rsquare is: {}' .format(scores.mean()))
print('standard deviation of accuracy is: {}' .format(scores.std()))
# Out:
# mean Rsquare is: 0.6550002124442045
# standard deviation of accuracy is: 0.010797221977317077

# %% [markdown]
# #### Support vector machine
# ##### Model 1 - SVR RBF

# %%
SVR_RBF_model = SVR(kernel = 'rbf',C=1e3, gamma=0.1) # Trick
#SVR_model = SVR()
SVR_RBF_model.fit(scaler_RS.transform(x_Train_RS[training_vars]), y_Train_RS)

pred = SVR_RBF_model.predict(scaler_RS.transform(x_Train_RS[training_vars]))
print('SVR_RBF train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# SVR_RBF train mse: 259381931.10683173
# Prediction: [ 40885.34624585  19796.67536055  24510.56692981 ...,  17968.78529408
#   37981.09228517  14165.56335442]
# Rsquare :  0.515019778599

# %% [markdown]
# ##### Model 2 - SVR Linear

# %%
SVR_Lin_model = SVR(kernel = 'linear',C=1e3)
#SVR_model = SVR()
SVR_Lin_model.fit(scaler_RS.transform(x_Train_RS[training_vars]), y_Train_RS)

pred = SVR_Lin_model.predict(scaler_RS.transform(x_Train_RS[training_vars]))
print('SVR_Lin train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# SVR_Lin train mse: 195187423.71407786
# Prediction: [ 46057.68474018  16159.98310712  30470.58968804 ...,  15517.52681154
#   62385.61823264  18561.02992044]
# Rsquare :  0.635047670578

# %% [markdown]
# ##### Model 3 - SVR Poly

# %%
SVR_Pol_model = SVR(kernel = 'poly',C=1e3, degree=2)
#SVR_model = SVR()
SVR_Pol_model.fit(scaler_RS.transform(x_Train_RS[training_vars]), y_Train_RS)

pred = SVR_Pol_model.predict(scaler_RS.transform(x_Train_RS[training_vars]))
print('SVR_Pol train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# SVR_Pol train mse: 268206362.96444657
# Prediction: [ 40837.65865073  23737.04160717  29184.98372324 ...,  19796.61273107
#   56874.90089228  22542.65103729]
# Rsquare :  0.498520268021

# %% [markdown]
# #### K-Fold Validation - Model 2 - SVR Linear

# %% [markdown]
# ** We will forego the k-fold validation for the SVR model given the very overhead involved in that computation.**

# %% [markdown]
# ### Submission to Kaggle

# %%
pred_ls = []
for model in [xgb_model, rf_model]:
    pred_ls.append(pd.Series(model.predict(x_Test_RS[training_vars])))

pred = SVR_Lin_model.predict(scaler_RS.transform(x_Test_RS[training_vars]))
pred_ls.append(pd.Series(pred))

pred = lin_model.predict(scaler_RS.transform(x_Test_RS[training_vars]))
pred_ls.append(pd.Series(pred))

final_pred = pd.concat(pred_ls, axis=1).mean(axis=1)

# %%
temp = pd.concat([x_Test_RS.SalesID, final_pred], axis=1)
temp.columns = ['SalesID', 'SalePrice']
temp.head()
# Out:
#    SalesID     SalePrice
# 0  4296762  80160.409422
# 1  4512705  11772.140424
# 2  4512869  52205.001187
# 3  6622232  34550.977535
# 4  6627715  54349.991266

# %%
temp.to_csv('submit_buldozer.csv', index=False)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Feature importance
# #### Random Forest Model

# %%
importances = rf_model.feature_importances_
indices = np.argsort(importances)[::-1]
print ("Random Forest - Top 10 Important Features\n")
for f in range(10): print("%d. %s (%f)" % (f + 1, x_Train_RS[training_vars].columns[indices[f]], importances[indices[f]])) 
#Plot the feature importances of the forest 
indices=indices[:10] 
plt.figure()
plt.title("Top 10 Feature importances")
plt.bar(range(10), importances[indices], 
        color="r", align="center") 
plt.xticks(range(10), x_Train_RS[training_vars].columns[indices], fontsize=14, rotation=90)
plt.xlim([-1, 10])
plt.show()
#Mean Feature Importance 
print("Mean Feature Importance %.6f" %np.mean(importances))
# Out:
# Random Forest - Top 10 Important Features
#
# 1. Enclosure (0.240147)
# 2. MachineAge (0.197698)
# 3. ProductSize (0.130352)
# 4. fiSecondaryDesc (0.098116)
# 5. fiBaseModel (0.075862)
# 6. state (0.053055)
# 7. ProductGroupDesc (0.022055)
# 8. ProductGroup (0.021112)
# 9. Blade_Type (0.018387)
# 10. Tire_Size (0.016901)
# Mean Feature Importance 0.022727

# %% [markdown]
# ##### Randm Forest Model - Importance > 0.01

# %%
imp = pd.Series(rf_model.feature_importances_)
imp.index = training_vars
df = pd.DataFrame(imp)
df =df[df[0]>0.01]
df =df.iloc[:,0]
imp = pd.Series.sort_values(df,ascending=False)
imp.plot.bar(figsize=(20,6))

# %% [markdown]
# #### XGBoost Model

# %%
importances = xgb_model.feature_importances_
indices = np.argsort(importances)[::-1]
print ("XGBoost - Top 10 Important Features\n")
for f in range(10): print("%d. %s (%f)" % (f + 1, x_Train_RS[training_vars].columns[indices[f]], importances[indices[f]])) 
#Plot the feature importances of the forest 
indices=indices[:10] 
plt.figure()
plt.title("Top 10 Feature importances")
plt.bar(range(10), importances[indices], 
        color="r", align="center") 
plt.xticks(range(10), x_Train_RS[training_vars].columns[indices], fontsize=14, rotation=90)
plt.xlim([-1, 10])
plt.show()
#Mean Feature Importance 
print("Mean Feature Importance %.6f" %np.mean(importances))
# Out:
# XGBoost - Top 10 Important Features
#
# 1. MachineAge (0.201149)
# 2. fiSecondaryDesc (0.149425)
# 3. ProductSize (0.112069)
# 4. Enclosure (0.087644)
# 5. fiBaseModel (0.077586)
# 6. ProductGroup (0.057471)
# 7. state (0.035920)
# 8. Blade_Type (0.033046)
# 9. Tire_Size (0.031609)
# 10. Ride_Control (0.027299)
# Mean Feature Importance 0.022727

# %% [markdown]
# ##### XGboost - Importance > 0.01

# %%
imp = pd.Series(xgb_model.feature_importances_)
imp.index = training_vars
df = pd.DataFrame(imp)
df =df[df[0]>0.01]
df =df.iloc[:,0]
imp = pd.Series.sort_values(df,ascending=False)
imp.plot.bar(figsize=(20,6))

# %% [markdown]
# #### Linear Regression Model

# %%
importances = pd.Series(np.abs(lin_model.coef_.ravel()))
indices = np.argsort(importances)[::-1]
indices = list(indices)
print ("Linear Regression - Top 10 Important Features\n")
for f in range(10): print("%d. %s (%f)" % (f + 1, x_Train_RS[training_vars].columns[indices[f]], importances[indices[f]])) 
#Plot the feature importances of the forest 
indices=indices[:10] 
plt.figure()
plt.title("Top 10 Feature importances")
plt.bar(range(10), importances[indices], 
        color="r", align="center") 
plt.xticks(range(10), x_Train_RS[training_vars].columns[indices], fontsize=14, rotation=90)
plt.xlim([-1, 10])
plt.show()
#Mean Feature Importance 
print("Mean Feature Importance %.6f" %np.mean(importances))
# Out:
# Linear Regression - Top 10 Important Features
#
# 1. MachineAge (9123.591246)
# 2. Scarifier (7475.038738)
# 3. ProductSize (6802.924187)
# 4. Enclosure (4692.446779)
# 5. Differential_Type (3624.219934)
# 6. Enclosure_Type (3176.228769)
# 7. Steering_Controls (2980.398068)
# 8. fiSecondaryDesc (2713.380079)
# 9. fiBaseModel (2671.701895)
# 10. Hydraulics_Flow (2660.149205)
# Mean Feature Importance 1787.419085

# %% [markdown]
# ##### Linear Regression Model - Importance > 1000

# %%
imp = pd.Series(np.abs(lin_model.coef_.ravel()))
imp.index = training_vars
df = pd.DataFrame(imp)
df =df[df[0]>1000]
df =df.iloc[:,0]
imp = pd.Series.sort_values(df,ascending=False)
imp.plot.bar(figsize=(20,6))

# %% [markdown]
# #### xgboost with Feature Selection

# %%
features_selected_xgb = ['MachineAge','fiSecondaryDesc','ProductSize','ProductGroup','Enclosure','Blade_Type','Tire_Size','state','fiBaseModel','Ride_Control']

# %%
xgb_model = xgb.XGBRegressor()
xgb_model.fit(x_Train_RS[features_selected_xgb], y_Train_RS, verbose=False)
pred = xgb_model.predict(x_Train_RS[features_selected_xgb])
print('xgb train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# xgb train mse: 126680154.09791245
# Prediction: [ 48740.296875    15700.14648438  24699.625      ...,  17348.68554688
#   68236.9921875   15090.05859375]
# Rsquare :  0.763139363951

# %% [markdown]
# #### K-Fold Validation - xgboost  with Feature Selection

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator = xgb_model, X = x_Train_RS[features_selected_xgb], y = y_Train_RS, cv = 10)
print('mean Rsquare is: {}' .format(scores.mean()))
print('standard deviation of accuracy is: {}' .format(scores.std()))
# Out:
# mean Rsquare is: 0.7493860940962584
# standard deviation of accuracy is: 0.016521386751090633

# %% [markdown]
# #### Random Forests  with Feature Selection

# %%
features_selected_rf = ['MachineAge','fiSecondaryDesc','ProductSize','ProductGroup','Enclosure','Blade_Type','Tire_Size','state','Ripper','ProductGroupDesc']

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_Train_RS[features_selected_rf], y_Train_RS)

pred = rf_model.predict(x_Train_RS[features_selected_rf])
print('rf train mse: {}'.format(mean_squared_error(y_Train_RS, pred)))
coefficient_of_dermination = r2_score(y_Train_RS, pred)
print('Prediction: {}' .format(pred))
print('Rsquare : ', coefficient_of_dermination)
# Out:
# rf train mse: 40486013.87270087
# Prediction: [ 51795.83333333  15789.16666667  21450.         ...,  19316.66666667
#   88450.          10045.83333333]
# Rsquare :  0.924301141996

# %% [markdown]
# #### K-Fold Validation -Random Forest with Feature Selection

# %%
# Applying k-Fold Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator = rf_model, X = x_Train_RS[features_selected_rf], y = y_Train_RS, cv = 10)
print('mean Rsquare is: {}' .format(scores.mean()))
print('standard deviation of accuracy is: {}' .format(scores.std()))
# Out:
# mean Rsquare is: 0.7119332510401349
# standard deviation of accuracy is: 0.02801591777848549

# %% [markdown]
# ## Summary of Results
#
# This project was aimed at estimating a suite of machine-learning models to predict the sale prices of used  buldozers. Notably, the Xgboost model proved to be the superior model in terms of performance. It is worth noting that the parsimonious model comprising features selected through the modeling process performed
# comparably( Rsquare of **74.93%** versus **75.44%**)  to the model with all features, including those with importance scores close to zero. The Random Forest model was the runner model with an Rsquare of approx. **71%**.
